# %% [markdown]
# <a href="https://colab.research.google.com/github/Nildk123/Deeplearning/blob/master/Week5/Assignment5___Resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#de# utility function 1


import numpy as np
from random import randint

def myFunc(input_img,p = 0.2, s_l=0.02, s_h=0.04, r_1=0.3, r_2=1/0.3,v_l=0, v_h=255, pixel_level=False):
    #image = np.array(image)
    x = randint(0,16)
    img_h, img_w, img_c = input_img.shape
    p_1 = np.random.rand()
    if p_1 > p:
      return input_img

    while True:
      s = np.random.uniform(s_l, s_h) * img_h * img_w
      r = np.random.uniform(r_1, r_2)
      w = int(np.sqrt(s / r))
      h = int(np.sqrt(s * r))
      left = np.random.randint(0, img_w)
      top = np.random.randint(0, img_h)
      if left + w <= img_w and top + h <= img_h:
        break
    if pixel_level:
      c = np.random.uniform(v_l, v_h, (h, w, img_c))
    else:
      c = np.random.uniform(v_l, v_h)
    input_img[top:top + h, left:left + w, :] = c
    return(input_img)

# %%
import tensorflow as tf
#import tensorflow.contrib.eager as tfe
#tf.enable_eager_execution()

# %%
from keras.callbacks import *
#Have taken this class from https://github.com/titu1994/keras-one-cycle
class OneCycleLR(Callback):
    def __init__(self,
                 epochs,
                 batch_size,
                 samples,
                 steps,
                 max_lr,
                 end_percentage=0.1,
                 scale_percentage=None,
                 maximum_momentum=0.95,
                 minimum_momentum=0.85,
                 verbose=True):
        """ This callback implements a cyclical learning rate policy (CLR).
        This is a special case of Cyclic Learning Rates, where we have only 1 cycle.
        After the completion of 1 cycle, the learning rate will decrease rapidly to
        100th its initial lowest value.
        # Arguments:
            max_lr: Float. Initial learning rate. This also sets the
                starting learning rate (which will be 10x smaller than
                this), and will increase to this value during the first cycle.
            end_percentage: Float. The percentage of all the epochs of training
                that will be dedicated to sharply decreasing the learning
                rate after the completion of 1 cycle. Must be between 0 and 1.
            scale_percentage: Float or None. If float, must be between 0 and 1.
                If None, it will compute the scale_percentage automatically
                based on the `end_percentage`.
            maximum_momentum: Optional. Sets the maximum momentum (initial)
                value, which gradually drops to its lowest value in half-cycle,
                then gradually increases again to stay constant at this max value.
                Can only be used with SGD Optimizer.
            minimum_momentum: Optional. Sets the minimum momentum at the end of
                the half-cycle. Can only be used with SGD Optimizer.
            verbose: Bool. Whether to print the current learning rate after every
                epoch.
        # Reference
            - [A disciplined approach to neural network hyper-parameters: Part 1 -- learning rate, batch size, weight_decay, and weight decay](https://arxiv.org/abs/1803.09820)
            - [Super-Convergence: Very Fast Training of Residual Networks Using Large Learning Rates](https://arxiv.org/abs/1708.07120)
        """
        super(OneCycleLR, self).__init__()

        if end_percentage < 0. or end_percentage > 1.:
            raise ValueError("`end_percentage` must be between 0 and 1")

        if scale_percentage is not None and (scale_percentage < 0. or scale_percentage > 1.):
            raise ValueError("`scale_percentage` must be between 0 and 1")

        self.initial_lr = max_lr
        self.end_percentage = end_percentage
        self.scale = float(scale_percentage) if scale_percentage is not None else float(end_percentage)
        self.max_momentum = maximum_momentum
        self.min_momentum = minimum_momentum
        self.verbose = verbose

        if self.max_momentum is not None and self.min_momentum is not None:
            self._update_momentum = True
        else:
            self._update_momentum = False

        self.clr_iterations = 0.
        self.history = {}

        self.epochs = epochs
        self.batch_size = batch_size
        self.samples = samples
        self.steps = steps
        self.num_iterations = None
        self.mid_cycle_id = None

    def _reset(self):
        """
        Reset the callback.
        """
        self.clr_iterations = 0.
        self.history = {}

    def compute_lr(self):
        """
        Compute the learning rate based on which phase of the cycle it is in.
        - If in the first half of training, the learning rate gradually increases.
        - If in the second half of training, the learning rate gradually decreases.
        - If in the final `end_percentage` portion of training, the learning rate
            is quickly reduced to near 100th of the original min learning rate.
        # Returns:
            the new learning rate
        """
        if self.clr_iterations > 2 * self.mid_cycle_id:
            current_percentage = (self.clr_iterations - 2 * self.mid_cycle_id)
            current_percentage /= float((self.num_iterations - 2 * self.mid_cycle_id))
            new_lr = self.initial_lr * (1. + (current_percentage *
                                              (1. - 100.) / 100.)) * self.scale

        elif self.clr_iterations > self.mid_cycle_id:
            current_percentage = 1. - (
                self.clr_iterations - self.mid_cycle_id) / self.mid_cycle_id
            new_lr = self.initial_lr * (1. + current_percentage *
                                        (self.scale * 100 - 1.)) * self.scale

        else:
            current_percentage = self.clr_iterations / self.mid_cycle_id
            new_lr = self.initial_lr * (1. + current_percentage *
                                        (self.scale * 100 - 1.)) * self.scale

        if self.clr_iterations == self.num_iterations:
            self.clr_iterations = 0

        return new_lr

    def compute_momentum(self):
        """
         Compute the momentum based on which phase of the cycle it is in.
        - If in the first half of training, the momentum gradually decreases.
        - If in the second half of training, the momentum gradually increases.
        - If in the final `end_percentage` portion of training, the momentum value
            is kept constant at the maximum initial value.
        # Returns:
            the new momentum value
        """
        if self.clr_iterations > 2 * self.mid_cycle_id:
            new_momentum = self.max_momentum

        elif self.clr_iterations > self.mid_cycle_id:
            current_percentage = 1. - ((self.clr_iterations - self.mid_cycle_id) / float(
                                        self.mid_cycle_id))
            new_momentum = self.max_momentum - current_percentage * (
                self.max_momentum - self.min_momentum)

        else:
            current_percentage = self.clr_iterations / float(self.mid_cycle_id)
            new_momentum = self.max_momentum - current_percentage * (
                self.max_momentum - self.min_momentum)

        return new_momentum

    def on_train_begin(self, logs={}):
        logs = logs or {}

        
        if self.steps is not None:
            self.num_iterations = self.epochs * self.steps
        else:
            if (self.samples % self.batch_size) == 0:
                remainder = 0
            else:
                remainder = 1
            self.num_iterations = (self.epochs + remainder) * self.samples // self.batch_size

        self.mid_cycle_id = int(self.num_iterations * ((1. - self.end_percentage)) / float(2))

        self._reset()
        K.set_value(self.model.optimizer.lr, self.compute_lr())

        if self._update_momentum:
            if not hasattr(self.model.optimizer, 'momentum'):
                raise ValueError("Momentum can be updated only on SGD optimizer !")

            new_momentum = self.compute_momentum()
            K.set_value(self.model.optimizer.momentum, new_momentum)

    def on_batch_end(self, epoch, logs=None):
        logs = logs or {}

        self.clr_iterations += 1
        new_lr = self.compute_lr()

        self.history.setdefault('lr', []).append(
            K.get_value(self.model.optimizer.lr))
        K.set_value(self.model.optimizer.lr, new_lr)

        if self._update_momentum:
            if not hasattr(self.model.optimizer, 'momentum'):
                raise ValueError("Momentum can be updated only on SGD optimizer !")

            new_momentum = self.compute_momentum()

            self.history.setdefault('momentum', []).append(
                K.get_value(self.model.optimizer.momentum))
            K.set_value(self.model.optimizer.momentum, new_momentum)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

    def on_epoch_end(self, epoch, logs=None):
        if self.verbose:
            if self._update_momentum:
                print(" - lr: %0.5f - momentum: %0.2f " %
                      (self.history['lr'][-1], self.history['momentum'][-1]))

            else:
                print(" - lr: %0.5f " % (self.history['lr'][-1]))


class LRFinder(Callback):
    def __init__(self,
                 num_samples,
                 batch_size,
                 minimum_lr=1e-5,
                 maximum_lr=10.,
                 lr_scale='exp',
                 validation_data=None,
                 validation_sample_rate=5,
                 stopping_criterion_factor=4.,
                 loss_smoothing_beta=0.98,
                 save_dir=None,
                 verbose=True):
        """
        This class uses the Cyclic Learning Rate history to find a
        set of learning rates that can be good initializations for the
        One-Cycle training proposed by Leslie Smith in the paper referenced
        below.
        A port of the Fast.ai implementation for Keras.
        # Note
        This requires that the model be trained for exactly 1 epoch. If the model
        is trained for more epochs, then the metric calculations are only done for
        the first epoch.
        # Interpretation
        Upon visualizing the loss plot, check where the loss starts to increase
        rapidly. Choose a learning rate at somewhat prior to the corresponding
        position in the plot for faster convergence. This will be the maximum_lr lr.
        Choose the max value as this value when passing the `max_val` argument
        to OneCycleLR callback.
        Since the plot is in log-scale, you need to compute 10 ^ (-k) of the x-axis
        # Arguments:
            num_samples: Integer. Number of samples in the dataset.
            batch_size: Integer. Batch size during training.
            minimum_lr: Float. Initial learning rate (and the minimum).
            maximum_lr: Float. Final learning rate (and the maximum).
            lr_scale: Can be one of ['exp', 'linear']. Chooses the type of
                scaling for each update to the learning rate during subsequent
                batches. Choose 'exp' for large range and 'linear' for small range.
            validation_data: Requires the validation dataset as a tuple of
                (X, y) belonging to the validation set. If provided, will use the
                validation set to compute the loss metrics. Else uses the training
                batch loss. Will warn if not provided to alert the user.
            validation_sample_rate: Positive or Negative Integer. Number of batches to sample from the
                validation set per iteration of the LRFinder. Larger number of
                samples will reduce the variance but will take longer time to execute
                per batch.
                If Positive > 0, will sample from the validation dataset
                If Megative, will use the entire dataset
            stopping_criterion_factor: Integer or None. A factor which is used
                to measure large increase in the loss value during training.
                Since callbacks cannot stop training of a model, it will simply
                stop logging the additional values from the epochs after this
                stopping criterion has been met.
                If None, this check will not be performed.
            loss_smoothing_beta: Float. The smoothing factor for the moving
                average of the loss function.
            save_dir: Optional, String. If passed a directory path, the callback
                will save the running loss and learning rates to two separate numpy
                arrays inside this directory. If the directory in this path does not
                exist, they will be created.
            verbose: Whether to print the learning rate after every batch of training.
        # References:
            - [A disciplined approach to neural network hyper-parameters: Part 1 -- learning rate, batch size, weight_decay, and weight decay](https://arxiv.org/abs/1803.09820)
        """
        super(LRFinder, self).__init__()

        if lr_scale not in ['exp', 'linear']:
            raise ValueError("`lr_scale` must be one of ['exp', 'linear']")

        if validation_data is not None:
            self.validation_data = validation_data
            self.use_validation_set = True

            if validation_sample_rate > 0 or validation_sample_rate < 0:
                self.validation_sample_rate = validation_sample_rate
            else:
                raise ValueError("`validation_sample_rate` must be a positive or negative integer other than o")
        else:
            self.use_validation_set = False
            self.validation_sample_rate = 0

        self.num_samples = num_samples
        self.batch_size = batch_size
        self.initial_lr = minimum_lr
        self.final_lr = maximum_lr
        self.lr_scale = lr_scale
        self.stopping_criterion_factor = stopping_criterion_factor
        self.loss_smoothing_beta = loss_smoothing_beta
        self.save_dir = save_dir
        self.verbose = verbose

        self.num_batches_ = num_samples // batch_size
        self.current_lr_ = minimum_lr

        if lr_scale == 'exp':
            self.lr_multiplier_ = (maximum_lr / float(minimum_lr)) ** (
                1. / float(self.num_batches_))
        else:
            extra_batch = int((num_samples % batch_size) != 0)
            self.lr_multiplier_ = np.linspace(
                minimum_lr, maximum_lr, num=self.num_batches_ + extra_batch)

        # If negative, use entire validation set
        if self.validation_sample_rate < 0:
            self.validation_sample_rate = self.validation_data[0].shape[0] // batch_size

        self.current_batch_ = 0
        self.current_epoch_ = 0
        self.best_loss_ = 1e6
        self.running_loss_ = 0.

        self.history = {}

    def on_train_begin(self, logs=None):

        self.current_epoch_ = 1
        K.set_value(self.model.optimizer.lr, self.initial_lr)

        warnings.simplefilter("ignore")

    def on_epoch_begin(self, epoch, logs=None):
        self.current_batch_ = 0

        if self.current_epoch_ > 1:
            warnings.warn(
                "\n\nLearning rate finder should be used only with a single epoch. "
                "Hereafter, the callback will not measure the losses.\n\n")

    def on_batch_begin(self, batch, logs=None):
        self.current_batch_ += 1

    def on_batch_end(self, batch, logs=None):
        if self.current_epoch_ > 1:
            return

        if self.use_validation_set:
            X, Y = self.validation_data[0], self.validation_data[1]

            # use 5 random batches from test set for fast approximate of loss
            num_samples = self.batch_size * self.validation_sample_rate

            if num_samples > X.shape[0]:
                num_samples = X.shape[0]

            idx = np.random.choice(X.shape[0], num_samples, replace=False)
            x = X[idx]
            y = Y[idx]

            values = self.model.evaluate(x, y, batch_size=self.batch_size, verbose=False)
            loss = values[0]
        else:
            loss = logs['loss']

        # smooth the loss value and bias correct
        running_loss = self.loss_smoothing_beta * loss + (
            1. - self.loss_smoothing_beta) * loss
        running_loss = running_loss / (
            1. - self.loss_smoothing_beta**self.current_batch_)

        # stop logging if loss is too large
        if self.current_batch_ > 1 and self.stopping_criterion_factor is not None and (
                running_loss >
                self.stopping_criterion_factor * self.best_loss_):

            if self.verbose:
                print(" - LRFinder: Skipping iteration since loss is %d times as large as best loss (%0.4f)"
                      % (self.stopping_criterion_factor, self.best_loss_))
            return

        if running_loss < self.best_loss_ or self.current_batch_ == 1:
            self.best_loss_ = running_loss

        current_lr = K.get_value(self.model.optimizer.lr)

        self.history.setdefault('running_loss_', []).append(running_loss)
        if self.lr_scale == 'exp':
            self.history.setdefault('log_lrs', []).append(np.log10(current_lr))
        else:
            self.history.setdefault('log_lrs', []).append(current_lr)

        # compute the lr for the next batch and update the optimizer lr
        if self.lr_scale == 'exp':
            current_lr *= self.lr_multiplier_
        else:
            current_lr = self.lr_multiplier_[self.current_batch_ - 1]

        K.set_value(self.model.optimizer.lr, current_lr)

        # save the other metrics as well
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        if self.verbose:
            if self.use_validation_set:
                print(" - LRFinder: val_loss: %1.4f - lr = %1.8f " %
                      (values[0], current_lr))
            else:
                print(" - LRFinder: lr = %1.8f " % current_lr)

    def on_epoch_end(self, epoch, logs=None):
        if self.save_dir is not None and self.current_epoch_ <= 1:
            if not os.path.exists(self.save_dir):
                os.makedirs(self.save_dir)

            losses_path = os.path.join(self.save_dir, 'losses.npy')
            lrs_path = os.path.join(self.save_dir, 'lrs.npy')

            np.save(losses_path, self.losses)
            np.save(lrs_path, self.lrs)

            if self.verbose:
                print("\tLR Finder : Saved the losses and learning rate values in path : {%s}"
                      % (self.save_dir))

        self.current_epoch_ += 1

        warnings.simplefilter("default")

    def plot_schedule(self, clip_beginning=None, clip_endding=None):
        """
        Plots the schedule from the callback itself.
        # Arguments:
            clip_beginning: Integer or None. If positive integer, it will
                remove the specified portion of the loss graph to remove the large
                loss values in the beginning of the graph.
            clip_endding: Integer or None. If negative integer, it will
                remove the specified portion of the ending of the loss graph to
                remove the sharp increase in the loss values at high learning rates.
        """
        try:
            import matplotlib.pyplot as plt
            plt.style.use('seaborn-white')
        except ImportError:
            print(
                "Matplotlib not found. Please use `pip install matplotlib` first."
            )
            return

        if clip_beginning is not None and clip_beginning < 0:
            clip_beginning = -clip_beginning

        if clip_endding is not None and clip_endding > 0:
            clip_endding = -clip_endding

        losses = self.losses
        lrs = self.lrs

        if clip_beginning:
            losses = losses[clip_beginning:]
            lrs = lrs[clip_beginning:]

        if clip_endding:
            losses = losses[:clip_endding]
            lrs = lrs[:clip_endding]

        plt.plot(lrs, losses)
        plt.title('Learning rate vs Loss')
        plt.xlabel('learning rate')
        plt.ylabel('loss')
        plt.show()

    @classmethod
    def restore_schedule_from_dir(cls,
                                  directory,
                                  clip_beginning=None,
                                  clip_endding=None):
        """
        Loads the training history from the saved numpy files in the given directory.
        # Arguments:
            directory: String. Path to the directory where the serialized numpy
                arrays of the loss and learning rates are saved.
            clip_beginning: Integer or None. If positive integer, it will
                remove the specified portion of the loss graph to remove the large
                loss values in the beginning of the graph.
            clip_endding: Integer or None. If negative integer, it will
                remove the specified portion of the ending of the loss graph to
                remove the sharp increase in the loss values at high learning rates.
        Returns:
            tuple of (losses, learning rates)
        """
        if clip_beginning is not None and clip_beginning < 0:
            clip_beginning = -clip_beginning

        if clip_endding is not None and clip_endding > 0:
            clip_endding = -clip_endding

        losses_path = os.path.join(directory, 'losses.npy')
        lrs_path = os.path.join(directory, 'lrs.npy')

        if not os.path.exists(losses_path) or not os.path.exists(lrs_path):
            print("%s and %s could not be found at directory : {%s}" %
                  (losses_path, lrs_path, directory))

            losses = None
            lrs = None

        else:
            losses = np.load(losses_path)
            lrs = np.load(lrs_path)

            if clip_beginning:
                losses = losses[clip_beginning:]
                lrs = lrs[clip_beginning:]

            if clip_endding:
                losses = losses[:clip_endding]
                lrs = lrs[:clip_endding]

        return losses, lrs

    @classmethod
    def plot_schedule_from_file(cls,
                                directory,
                                clip_beginning=None,
                                clip_endding=None):
        """
        Plots the schedule from the saved numpy arrays of the loss and learning
        rate values in the specified directory.
        # Arguments:
            directory: String. Path to the directory where the serialized numpy
                arrays of the loss and learning rates are saved.
            clip_beginning: Integer or None. If positive integer, it will
                remove the specified portion of the loss graph to remove the large
                loss values in the beginning of the graph.
            clip_endding: Integer or None. If negative integer, it will
                remove the specified portion of the ending of the loss graph to
                remove the sharp increase in the loss values at high learning rates.
        """
        try:
            import matplotlib.pyplot as plt
            plt.style.use('seaborn-white')
        except ImportError:
            print("Matplotlib not found. Please use `pip install matplotlib` first.")
            return

        losses, lrs = cls.restore_schedule_from_dir(
            directory,
            clip_beginning=clip_beginning,
            clip_endding=clip_endding)

        if losses is None or lrs is None:
            return
        else:
            plt.plot(lrs, losses)
            plt.title('Learning rate vs Loss')
            plt.xlabel('learning rate')
            plt.ylabel('loss')
            plt.show()

    @property
    def lrs(self):
        return np.array(self.history['log_lrs'])

    @property
    def losses(self):
        return np.array(self.history['running_loss_'])

# %%
# importing packages an dependencies
# %tensorflow_version 1.x

import cv2
import json
import os

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Add, BatchNormalization, Activation
from keras.layers import Convolution2D, MaxPooling2D

# %%
import os
import zipfile
from skimage import io
import tensorflow as tf

from keras.preprocessing import image
from keras import backend as K
from keras.applications.vgg16 import preprocess_input

# %%
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.layers import GlobalAveragePooling2D
from keras.layers import Dropout

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root_dir = "/content/drive/My Drive/EIP/hvc_data/"
os.chdir(root_dir)

# %%
df = pd.read_csv("./hvc_annotations.csv")
print(df.shape)
# Out:
# (13573, 10)

# %%
#display sample images
from google.colab.patches import cv2_imshow
ext_img = io.imread("resized/120.jpg")
cv2_imshow(ext_img)
print(ext_img.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0EE4E272B0>
# (224, 224, 3)

# %%
print((ext_img.shape))
data_aug = lambda x: (tf.image.random_flip_left_right(tf.random_crop(x, [8, 8,3])))
#tf.data.Dataset.from_tensor_slices(ext_img).map(data_aug).shape
# Out:
# (224, 224, 3)

# %%
#tf.data.Dataset.from_tensor_slices(ext_img).map(data_aug).shape

# %%
#tf.data.Dataset.from_tensor_slices(io.imread("resized/1200.jpg")).map(data_aug)
ext_image = io.imread("resized/1200.jpg")
ext_image = tf.image.random_flip_left_right(tf.random_crop(ext_image,[32,32,3]))
print(ext_image.shape)
# Out:
# (32, 32, 3)

# %%
tf.random_crop(io.imread("resized/1200.jpg"),[220,220,3]).shape
# Out:
# TensorShape([Dimension(220), Dimension(220), Dimension(3)])

# %%
one_hot_df = pd.concat([
                        df[['image_path']],
                        pd.get_dummies(df['gender'], prefix = "gender"),
                        pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose")
                        ], axis = 1)
one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import keras
import numpy as np
import tensorflow as tf

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=16,shuffle=True, augmentation = None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation = augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        try:
          batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
          
          items = self.df.iloc[batch_slice]
          #image = np.stack([io.imread(item["image_path"]) for _, item in items.iterrows()])
          #if self.augmentation is not None:
          #  images = self.augmentation.flow(images, shuffle = False)

          image = np.stack([myFunc(io.imread(item["image_path"]), p = 0.5) for _, item in items.iterrows()])
          #print(image.shape)
          '''
          
          print("checking images")
          for _,item in items.iterrows():
            
            imageTemp = io.imread(item["image_path"])
            print("data aug images")
            imageTemp = imageTemp.map(data_aug)
            print("data aug images end")
            print(imageTemp.shape)
            image = np.stack(imageTemp)
          '''
            


          #image aug
          
          

          if image is None:
            pass
          target = {
              "gender_output": items[_gender_cols_].values,
              "image_quality_output": items[_imagequality_cols_].values,
              "age_output": items[_age_cols_].values,
              "weight_output": items[_weight_cols_].values,
              "bag_output": items[_carryingbag_cols_].values,
              "pose_output": items[_bodypose_cols_].values,
              "footwear_output": items[_footwear_cols_].values,
              "emotion_output": items[_emotion_cols_].values,
          }
          
          return (image, target)
        except:
            print("exception")
          
            pass

        #print(image.shape)
        

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
x = None
if x is not None:
  print('tada')

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15, random_state = 111)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
# create train and validation data generators
#root_dir = "/content/mydrive/My Drive/colabProjects/EPIP/hvc_data/"
#os.chdir(root_dir)

train_gen = PersonDataGenerator(train_df, batch_size=32)
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False)

# %%
train_gen

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = {k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %% [markdown]
# # Model Creation

# %% [markdown]
# ## Model inception type

# %%
import time, math
def init_pytorch(shape, dtype=tf.float32, partition_info=None):
  fan = np.prod(shape[:-1])
  bound = 1 / math.sqrt(fan)
  return tf.random.uniform(shape, minval=-bound, maxval=bound, dtype=dtype)

# %%
n = 2

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# Computed depth from supplied model parameter n
if version == 1:
  depth = n * 6 + 2
elif version == 2:
  depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)
input_shape = (224,224,3)
#input_shape = (55,55,256)
# (53,53,512)

# %%
version=2
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_uniform',
                  kernel_regularizer=l2(1e-2))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
            #x = Dropout(0.015)(x)
           
        if activation is not None:
            x = Activation(activation)(x)
            #x = Dropout(0.015)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
            #x = Dropout(0.015)(x)
            
        if activation is not None:
            x = Activation(activation)(x)
            #x = Dropout(0.015)(x)
        x = conv(x)
    return x

# %%
def resnet_v2(input_shape, depth, num_classes=8):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 128
    num_res_blocks = int((depth - 2) / 9)

    # adding strides to reduce the size
    conv = Conv2D(filters = 16,
                  kernel_size=(3,3),
                  strides=(1,1),
                  padding='same',
                  kernel_initializer='he_uniform',
                  kernel_regularizer=l2(1e-2))
    
    inputs = Input(shape=input_shape)
    x1 = conv(inputs)
    x1 = BatchNormalization()(x1)
    x1 = MaxPooling2D(pool_size=(2, 2))(x1)
    x1= Conv2D(filters = 32,kernel_size=(3,3),strides=(1,1))(x1)
    x1 = BatchNormalization()(x1)
    x1 = MaxPooling2D(pool_size=(2, 2))(x1)
    x1 = Conv2D(filters = 64,kernel_size=(3,3),strides=(1,1))(x1)
    x1 = BatchNormalization()(x1)
    x1 = MaxPooling2D(pool_size=(2, 2))(x1)
    x1 = Conv2D(filters = 128,kernel_size=(3,3),strides=(1,1))(x1)
    x1 = BatchNormalization()(x1)

    x2 = conv(inputs)
    x2 = BatchNormalization()(x2)
    x2 = MaxPooling2D(pool_size=(2, 2))(x2)
    x2 = Conv2D(filters = 32,kernel_size=(3,3),strides=(1,1))(x2)
    x2 = BatchNormalization()(x2)
    x2 = MaxPooling2D(pool_size=(2, 2))(x2)
    x2 = Conv2D(filters = 64,kernel_size=(3,3),strides=(1,1))(x2)
    x2 = BatchNormalization()(x2)
    x2 = MaxPooling2D(pool_size=(2, 2))(x2)
    x2 = Conv2D(filters = 128,kernel_size=(3,3),strides=(1,1))(x2)
    x2 = BatchNormalization()(x2)
    
    x3 = conv(inputs)
    x3 = BatchNormalization()(x3)
    x3 = MaxPooling2D(pool_size=(2, 2))(x3)
    x3 = Conv2D(filters = 32,kernel_size=(3,3),strides=(1,1))(x3)
    x3 = BatchNormalization()(x3)
    x3 = MaxPooling2D(pool_size=(2, 2))(x3)
    x3 = Conv2D(filters = 64,kernel_size=(3,3),strides=(1,1))(x3)
    x3 = BatchNormalization()(x3)
    x3 = MaxPooling2D(pool_size=(2, 2))(x3)
    x3 = Conv2D(filters = 128,kernel_size=(3,3),strides=(1,1))(x3)
    x3 = BatchNormalization()(x3)

    x4 = conv(inputs)
    x4 = BatchNormalization()(x4)
    x4 = MaxPooling2D(pool_size=(2, 2))(x4)
    x4 = Conv2D(filters = 32,kernel_size=(3,3),strides=(1,1))(x4)
    x4 = BatchNormalization()(x4)
    x4 = MaxPooling2D(pool_size=(2, 2))(x4)
    x4 = Conv2D(filters = 64,kernel_size=(3,3),strides=(1,1))(x4)
    x4 = BatchNormalization()(x4)
    x4 = MaxPooling2D(pool_size=(2, 2))(x4)
    x4 = Conv2D(filters = 128,kernel_size=(3,3),strides=(1,1))(x4)
    x4 = BatchNormalization()(x4)

    x = keras.layers.Add()([x1,x2,x3,x4])


    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    '''
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)
    '''

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.Add()([x, y])
            #x  = keras.layers.concatenate([x,y])
            #x = Conv2D(filters = num_filters_out,kernel_size= (1,1))(x)

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters = 256,kernel_size=(1,1))(x)
    #x = Conv2D(filters = 256,kernel_size=(1,1))(x)
    #x = Conv2D(filters = 64,kernel_size=(8,8))(x)
    
    #x = AveragePooling2D(pool_size=8)(x)
    #y = GlobalAveragePooling2D()(x)
   
    #y = Flatten()(x)
    #outputs = Dense(num_classes,
    #                activation='softmax',
    #                kernel_initializer=init_pytorch)(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=x)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)

# %%
'''
neck = model.output
#neck = Flatten(name="flatten")(neck)
#neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = Dropout(0.2)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.3)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))

'''
def build_tower(layer,numclasses):
  x = Dropout(0.2)(layer)
  x = Convolution2D(filters=numclasses,kernel_size = (1,1),activation='relu',use_bias=False,kernel_initializer='he_uniform')(x)
  x = GlobalAveragePooling2D()(x)
  return x
  #x = Activation('softmax')

neck = model.output

def build_head(name, in_layer):
    return Activation(activation="softmax", name=f"{name}_output")(in_layer)

gender = build_head("gender", build_tower(neck,2))
image_quality = build_head("image_quality", build_tower(neck,3))
age = build_head("age", build_tower(neck,5))
weight = build_head("weight", build_tower(neck,4))
bag = build_head("bag", build_tower(neck,3))
footwear = build_head("footwear", build_tower(neck,3))
emotion = build_head("emotion", build_tower(neck,4))
pose = build_head("pose", build_tower(neck,3))



model2 = Model(
    inputs=model.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)

# %%
losses = {
	"gender_output": "binary_crossentropy",
	"image_quality_output": "categorical_crossentropy",
  "age_output":"categorical_crossentropy",
  "weight_output":"categorical_crossentropy",
  "bag_output":"categorical_crossentropy",
  "footwear_output":"categorical_crossentropy",
  "pose_output":"categorical_crossentropy","emotion_output":"categorical_crossentropy"
}

lossWeights = {"gender_output": 1.0,"image_quality_output": 1.0,
               "age_output": 1.0,"weight_output": 1.0,
               "bag_output": 1.0,"footwear_output": 1.0,
               "pose_output": 1.0,
               "emotion_output": 1.0}

# %%
from keras.utils import plot_model
plot_model(model2)

# %%
model2.compile(loss=losses,
              optimizer=SGD(lr=0.005, momentum = 0.009),loss_weights=lossWeights,
              metrics=['accuracy'])
model2.summary()
#print(model_type)


'''
model2.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model2.summary()
print(model_type)

'''
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 224, 224, 16) 448         input_2[0][0]
#                                                                  input_2[0][0]
#                                                                  input_2[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 224, 224, 16) 64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 224, 224, 16) 64          conv2d_44[1][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 224, 224, 16) 64          conv2d_44[2][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 224, 224, 16) 64          conv2d_44[3][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 112, 112, 16) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 112, 112, 16) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 112, 112, 16) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 112, 112, 16) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 110, 110, 32) 4640        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 110, 110, 32) 4640        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 110, 110, 32) 4640        max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 110, 110, 32) 4640        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 110, 110, 32) 128         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 110, 110, 32) 128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 110, 110, 32) 128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 110, 110, 32) 128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 55, 55, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 55, 55, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 55, 55, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 55, 55, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 53, 53, 64)   18496       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 53, 53, 64)   18496       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 53, 53, 64)   18496       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 53, 53, 64)   18496       max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 53, 53, 64)   256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 53, 53, 64)   256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 53, 53, 64)   256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 53, 53, 64)   256         conv2d_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 26, 26, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 26, 26, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 26, 26, 64)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 26, 26, 64)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 24, 24, 128)  73856       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 24, 24, 128)  73856       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 24, 24, 128)  73856       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 24, 24, 128)  73856       max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 24, 24, 128)  512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 24, 24, 128)  512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 24, 24, 128)  512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 24, 24, 128)  512         conv2d_56[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 24, 24, 128)  0           batch_normalization_38[0][0]
#                                                                  batch_normalization_42[0][0]
#                                                                  batch_normalization_46[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 24, 24, 128)  16512       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 24, 24, 128)  512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 24, 24, 128)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 24, 24, 128)  147584      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 24, 24, 128)  512         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 24, 24, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 24, 24, 512)  66048       add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 24, 24, 512)  66048       activation_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 24, 24, 512)  0           conv2d_60[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 24, 24, 512)  2048        add_9[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 24, 24, 512)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 24, 24, 128)  65664       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 24, 24, 128)  512         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 24, 24, 128)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 24, 24, 128)  147584      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 24, 24, 128)  512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 24, 24, 128)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 24, 24, 512)  66048       activation_23[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 24, 24, 512)  0           add_9[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 24, 24, 512)  2048        add_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 24, 24, 512)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 12, 12, 512)  262656      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 12, 12, 512)  2048        conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 12, 12, 512)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 12, 12, 512)  2359808     activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 12, 512)  2048        conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 12, 512)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 12, 12, 1024) 525312      add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 12, 12, 1024) 525312      activation_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 12, 12, 1024) 0           conv2d_67[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 12, 1024) 4096        add_11[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 1024) 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 12, 12, 512)  524800      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 12, 12, 512)  2048        conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 512)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 12, 12, 512)  2359808     activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 512)  2048        conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 512)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 12, 12, 1024) 525312      activation_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 1024) 0           add_11[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 1024) 4096        add_12[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 1024) 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 6, 6, 1024)   1049600     activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 6, 6, 1024)   4096        conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 6, 6, 1024)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 6, 6, 1024)   9438208     activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 6, 6, 1024)   4096        conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 6, 6, 1024)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 6, 6, 2048)   2099200     add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 6, 6, 2048)   2099200     activation_32[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 6, 6, 2048)   0           conv2d_74[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 6, 6, 2048)   8192        add_13[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 6, 6, 2048)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 6, 6, 1024)   2098176     activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 6, 6, 1024)   4096        conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 6, 6, 1024)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 6, 6, 1024)   9438208     activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 6, 6, 1024)   4096        conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 6, 6, 1024)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 6, 6, 2048)   2099200     activation_35[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 6, 6, 2048)   0           add_13[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 6, 6, 2048)   8192        add_14[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 6, 6, 2048)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 6, 6, 256)    524544      activation_36[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 6, 6, 256)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 6, 6, 256)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 6, 6, 256)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 6, 6, 256)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 6, 6, 256)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 6, 6, 256)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 6, 6, 256)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 6, 6, 256)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 6, 6, 2)      512         dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 6, 6, 3)      768         dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 6, 6, 5)      1280        dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 6, 6, 4)      1024        dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 6, 6, 3)      768         dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 6, 6, 3)      768         dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 6, 6, 3)      768         dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 6, 6, 4)      1024        dropout_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 2)            0           conv2d_79[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 3)            0           conv2d_80[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 5)            0           conv2d_81[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 4)            0           conv2d_82[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_13 (Gl (None, 3)            0           conv2d_83[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_14 (Gl (None, 3)            0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_16 (Gl (None, 3)            0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_15 (Gl (None, 4)            0           conv2d_85[0][0]
# __________________________________________________________________________________________________
# gender_output (Activation)      (None, 2)            0           global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Activatio (None, 3)            0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# age_output (Activation)         (None, 5)            0           global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# weight_output (Activation)      (None, 4)            0           global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# bag_output (Activation)         (None, 3)            0           global_average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# footwear_output (Activation)    (None, 3)            0           global_average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# pose_output (Activation)        (None, 3)            0           global_average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# emotion_output (Activation)     (None, 4)            0           global_average_pooling2d_15[0][0]
# ==================================================================================================
# Total params: 36,959,296
# Trainable params: 36,929,728
# Non-trainable params: 29,568
# __________________________________________________________________________________________________
# "\nmodel2.compile(loss='categorical_crossentropy',\n              optimizer=Adam(lr=lr_schedule(0)),\n              metrics=['accuracy'])\nmodel2.summary()\nprint(model_type)\n\n"

# %%
lr_callback = LRFinder(num_samples=train_df.shape[0], batch_size=128,
                       minimum_lr=0.00002, maximum_lr=1.0,verbose=False,
                       lr_scale='exp', save_dir='./LR_LOGS/')


# Need to have the epochs = 1 here.
train_history = model2.fit_generator(train_gen,#   datagen.flow(x_train, 
                                              #   y_train, 
                                              #   batch_size = batch_size),
                                    #samples_per_epoch = x_train.shape[0], 
                                    epochs=1, 
                                    validation_data = valid_gen,# (x_test, y_test), 
                                    callbacks=[lr_callback],
                                    verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
#  18/360 [>.............................] - ETA: 1:21:48 - loss: 357.7190 - gender_output_loss: 0.6862 - image_quality_output_loss: 1.1829 - age_output_loss: 1.7691 - weight_output_loss: 1.1451 - bag_output_loss: 0.9905 - footwear_output_loss: 1.2415 - pose_output_loss: 1.0871 - emotion_output_loss: 1.3100 - gender_output_acc: 0.5764 - image_quality_output_acc: 0.1858 - age_output_acc: 0.0972 - weight_output_acc: 0.6354 - bag_output_acc: 0.6094 - footwear_output_acc: 0.3854 - pose_output_acc: 0.3472 - emotion_output_acc: 0.2726
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-372fec121885> in <module>()
#      12                                     validation_data = valid_gen,# (x_test, y_test),
#      13                                     callbacks=[lr_callback],
# ---> 14                                     verbose=1)
#      15
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1656             use_multiprocessing=use_multiprocessing,
#    1657             shuffle=shuffle,
# -> 1658             initial_epoch=initial_epoch)
#    1659
#    1660     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py in get(self)
#     601                 try:
#     602                     future = self.queue.get(block=True)
# --> 603                     inputs = future.get(timeout=30)
#     604                     self.queue.task_done()
#     605                 except mp.TimeoutError:
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
lr_callback.plot_schedule(clip_beginning=5)

# %%
#best -1.9 ~ 0.0125
lr_callback.plot_schedule( clip_beginning = 5, clip_endding=10)

# %% [markdown]
# Save and Run Model

# %%
ckpt_callback = ModelCheckpoint(filepath='test_curr.h5', monitor='val_loss',save_best_only=True , save_weights_only=True, mode='auto',period=10)
lr_manager = OneCycleLR(samples=train_df.shape[0], epochs=10, batch_size=16,
                    steps=16, max_lr=0.0125,
                    end_percentage=0.1, scale_percentage=None,
                    maximum_momentum=None, minimum_momentum=None)

# %%
model2.compile(loss=losses,
              optimizer=SGD(lr=0.01, momentum = 0.009),loss_weights=lossWeights,
              metrics=['accuracy'])

# %%
model2.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=10,
    verbose=1,callbacks=[ckpt_callback]
   # preprocessing_function=get_random_eraser(v_l=0, v_h=16),
)
# Out:
# Epoch 1/10
# 360/360 [==============================] - 90s 250ms/step - loss: 77.9199 - gender_output_loss: 0.3700 - image_quality_output_loss: 0.7819 - age_output_loss: 1.2439 - weight_output_loss: 0.8629 - bag_output_loss: 0.7506 - footwear_output_loss: 0.7017 - pose_output_loss: 0.4762 - emotion_output_loss: 0.7813 - gender_output_acc: 0.8344 - image_quality_output_acc: 0.6476 - age_output_acc: 0.4836 - weight_output_acc: 0.6641 - bag_output_acc: 0.6827 - footwear_output_acc: 0.6961 - pose_output_acc: 0.8133 - emotion_output_acc: 0.7225 - val_loss: 74.8528 - val_gender_output_loss: 0.4386 - val_image_quality_output_loss: 1.5354 - val_age_output_loss: 1.5011 - val_weight_output_loss: 0.9581 - val_bag_output_loss: 0.8697 - val_footwear_output_loss: 1.1410 - val_pose_output_loss: 0.5579 - val_emotion_output_loss: 0.8680 - val_gender_output_acc: 0.8006 - val_image_quality_output_acc: 0.3606 - val_age_output_acc: 0.4058 - val_weight_output_acc: 0.6275 - val_bag_output_acc: 0.6022 - val_footwear_output_acc: 0.5025 - val_pose_output_acc: 0.7817 - val_emotion_output_acc: 0.7093
# Epoch 2/10
# 360/360 [==============================] - 81s 224ms/step - loss: 68.0710 - gender_output_loss: 0.3204 - image_quality_output_loss: 0.7454 - age_output_loss: 1.1725 - weight_output_loss: 0.8101 - bag_output_loss: 0.7139 - footwear_output_loss: 0.6482 - pose_output_loss: 0.3903 - emotion_output_loss: 0.7427 - gender_output_acc: 0.8647 - image_quality_output_acc: 0.6678 - age_output_acc: 0.5205 - weight_output_acc: 0.6855 - bag_output_acc: 0.6982 - footwear_output_acc: 0.7235 - pose_output_acc: 0.8470 - emotion_output_acc: 0.7332 - val_loss: 69.3704 - val_gender_output_loss: 3.2070 - val_image_quality_output_loss: 1.6309 - val_age_output_loss: 1.3871 - val_weight_output_loss: 1.1346 - val_bag_output_loss: 1.1788 - val_footwear_output_loss: 0.9032 - val_pose_output_loss: 0.7335 - val_emotion_output_loss: 0.9208 - val_gender_output_acc: 0.5536 - val_image_quality_output_acc: 0.3313 - val_age_output_acc: 0.3889 - val_weight_output_acc: 0.5585 - val_bag_output_acc: 0.5640 - val_footwear_output_acc: 0.6319 - val_pose_output_acc: 0.7336 - val_emotion_output_acc: 0.6781
# Epoch 3/10
# Epoch 2/10
# 360/360 [==============================] - 80s 223ms/step - loss: 59.5786 - gender_output_loss: 0.2792 - image_quality_output_loss: 0.6854 - age_output_loss: 1.0822 - weight_output_loss: 0.7590 - bag_output_loss: 0.6682 - footwear_output_loss: 0.5839 - pose_output_loss: 0.3464 - emotion_output_loss: 0.6967 - gender_output_acc: 0.8809 - image_quality_output_acc: 0.7069 - age_output_acc: 0.5632 - weight_output_acc: 0.7010 - bag_output_acc: 0.7228 - footwear_output_acc: 0.7589 - pose_output_acc: 0.8661 - emotion_output_acc: 0.7502 - val_loss: 60.1269 - val_gender_output_loss: 0.5296 - val_image_quality_output_loss: 1.8172 - val_age_output_loss: 1.5300 - val_weight_output_loss: 0.9995 - val_bag_output_loss: 0.8495 - val_footwear_output_loss: 0.9904 - val_pose_output_loss: 1.6559 - val_emotion_output_loss: 0.8979 - val_gender_output_acc: 0.7321 - val_image_quality_output_acc: 0.3447 - val_age_output_acc: 0.3219 - val_weight_output_acc: 0.6210 - val_bag_output_acc: 0.6176 - val_footwear_output_acc: 0.6012 - val_pose_output_acc: 0.3690 - val_emotion_output_acc: 0.7093
# Epoch 4/10
# 360/360 [==============================] - 81s 224ms/step - loss: 52.2749 - gender_output_loss: 0.2580 - image_quality_output_loss: 0.6300 - age_output_loss: 0.9848 - weight_output_loss: 0.6937 - bag_output_loss: 0.6062 - footwear_output_loss: 0.5279 - pose_output_loss: 0.3007 - emotion_output_loss: 0.6484 - gender_output_acc: 0.8944 - image_quality_output_acc: 0.7291 - age_output_acc: 0.6089 - weight_output_acc: 0.7312 - bag_output_acc: 0.7546 - footwear_output_acc: 0.7780 - pose_output_acc: 0.8820 - emotion_output_acc: 0.7652 - val_loss: 54.9837 - val_gender_output_loss: 0.5025 - val_image_quality_output_loss: 1.3052 - val_age_output_loss: 1.4792 - val_weight_output_loss: 1.4171 - val_bag_output_loss: 1.0797 - val_footwear_output_loss: 1.1778 - val_pose_output_loss: 2.3727 - val_emotion_output_loss: 1.0984 - val_gender_output_acc: 0.7733 - val_image_quality_output_acc: 0.4663 - val_age_output_acc: 0.3547 - val_weight_output_acc: 0.3686 - val_bag_output_acc: 0.5704 - val_footwear_output_acc: 0.4598 - val_pose_output_acc: 0.3616 - val_emotion_output_acc: 0.5308
# Epoch 5/10
# 360/360 [==============================] - 80s 224ms/step - loss: 45.9969 - gender_output_loss: 0.2376 - image_quality_output_loss: 0.5645 - age_output_loss: 0.8844 - weight_output_loss: 0.6280 - bag_output_loss: 0.5630 - footwear_output_loss: 0.4753 - pose_output_loss: 0.2632 - emotion_output_loss: 0.5809 - gender_output_acc: 0.8962 - image_quality_output_acc: 0.7637 - age_output_acc: 0.6559 - weight_output_acc: 0.7581 - bag_output_acc: 0.7740 - footwear_output_acc: 0.8076 - pose_output_acc: 0.9006 - emotion_output_acc: 0.7865 - val_loss: 51.1583 - val_gender_output_loss: 1.4879 - val_image_quality_output_loss: 2.2936 - val_age_output_loss: 2.1825 - val_weight_output_loss: 1.6839 - val_bag_output_loss: 1.1297 - val_footwear_output_loss: 1.2016 - val_pose_output_loss: 0.9095 - val_emotion_output_loss: 1.0760 - val_gender_output_acc: 0.5992 - val_image_quality_output_acc: 0.3472 - val_age_output_acc: 0.2867 - val_weight_output_acc: 0.4762 - val_bag_output_acc: 0.5640 - val_footwear_output_acc: 0.5531 - val_pose_output_acc: 0.7326 - val_emotion_output_acc: 0.6811
# Epoch 6/10
# 360/360 [==============================] - 81s 224ms/step - loss: 40.6017 - gender_output_loss: 0.2250 - image_quality_output_loss: 0.5086 - age_output_loss: 0.7811 - weight_output_loss: 0.5556 - bag_output_loss: 0.4982 - footwear_output_loss: 0.4261 - pose_output_loss: 0.2412 - emotion_output_loss: 0.5208 - gender_output_acc: 0.9058 - image_quality_output_acc: 0.7921 - age_output_acc: 0.7002 - weight_output_acc: 0.7881 - bag_output_acc: 0.8003 - footwear_output_acc: 0.8240 - pose_output_acc: 0.9080 - emotion_output_acc: 0.8132 - val_loss: 47.4529 - val_gender_output_loss: 0.5605 - val_image_quality_output_loss: 1.6543 - val_age_output_loss: 1.9143 - val_weight_output_loss: 1.1939 - val_bag_output_loss: 2.0729 - val_footwear_output_loss: 1.1240 - val_pose_output_loss: 1.0113 - val_emotion_output_loss: 3.2808 - val_gender_output_acc: 0.7520 - val_image_quality_output_acc: 0.3666 - val_age_output_acc: 0.3889 - val_weight_output_acc: 0.5689 - val_bag_output_acc: 0.5630 - val_footwear_output_acc: 0.5883 - val_pose_output_acc: 0.6280 - val_emotion_output_acc: 0.3328
# Epoch 7/10
# 360/360 [==============================] - 81s 224ms/step - loss: 40.6017 - gender_output_loss: 0.2250 - image_quality_output_loss: 0.5086 - age_output_loss: 0.7811 - weight_output_loss: 0.5556 - bag_output_loss: 0.4982 - footwear_output_loss: 0.4261 - pose_output_loss: 0.2412 - emotion_output_loss: 0.5208 - gender_output_acc: 0.9058 - image_quality_output_acc: 0.7921 - age_output_acc: 0.7002 - weight_output_acc: 0.7881 - bag_output_acc: 0.8003 - footwear_output_acc: 0.8240 - pose_output_acc: 0.9080 - emotion_output_acc: 0.8132 - val_loss: 47.4529 - val_gender_output_loss: 0.5605 - val_image_quality_output_loss: 1.6543 - val_age_output_loss: 1.9143 - val_weight_output_loss: 1.1939 - val_bag_output_loss: 2.0729 - val_footwear_output_loss: 1.1240 - val_pose_output_loss: 1.0113 - val_emotion_output_loss: 3.2808 - val_gender_output_acc: 0.7520 - val_image_quality_output_acc: 0.3666 - val_age_output_acc: 0.3889 - val_weight_output_acc: 0.5689 - val_bag_output_acc: 0.5630 - val_footwear_output_acc: 0.5883 - val_pose_output_acc: 0.6280 - val_emotion_output_acc: 0.3328
# Epoch 7/10
# 360/360 [==============================] - 80s 223ms/step - loss: 36.0352 - gender_output_loss: 0.2018 - image_quality_output_loss: 0.4705 - age_output_loss: 0.7073 - weight_output_loss: 0.4802 - bag_output_loss: 0.4465 - footwear_output_loss: 0.3937 - pose_output_loss: 0.2344 - emotion_output_loss: 0.4706 - gender_output_acc: 0.9170 - image_quality_output_acc: 0.8089 - age_output_acc: 0.7273 - weight_output_acc: 0.8143 - bag_output_acc: 0.8242 - footwear_output_acc: 0.8435 - pose_output_acc: 0.9108 - emotion_output_acc: 0.8291 - val_loss: 46.3199 - val_gender_output_loss: 0.6103 - val_image_quality_output_loss: 2.5903 - val_age_output_loss: 2.5092 - val_weight_output_loss: 2.0943 - val_bag_output_loss: 1.0014 - val_footwear_output_loss: 1.6354 - val_pose_output_loss: 0.7536 - val_emotion_output_loss: 4.3653 - val_gender_output_acc: 0.7589 - val_image_quality_output_acc: 0.2237 - val_age_output_acc: 0.2713 - val_weight_output_acc: 0.2912 - val_bag_output_acc: 0.5526 - val_footwear_output_acc: 0.4861 - val_pose_output_acc: 0.7202 - val_emotion_output_acc: 0.1349
# Epoch 8/10
# 360/360 [==============================] - 80s 223ms/step - loss: 32.0435 - gender_output_loss: 0.1905 - image_quality_output_loss: 0.4066 - age_output_loss: 0.6080 - weight_output_loss: 0.4233 - bag_output_loss: 0.3985 - footwear_output_loss: 0.3582 - pose_output_loss: 0.2204 - emotion_output_loss: 0.4115 - gender_output_acc: 0.9237 - image_quality_output_acc: 0.8357 - age_output_acc: 0.7727 - weight_output_acc: 0.8370 - bag_output_acc: 0.8432 - footwear_output_acc: 0.8602 - pose_output_acc: 0.9171 - emotion_output_acc: 0.8497 - val_loss: 43.6194 - val_gender_output_loss: 0.8282 - val_image_quality_output_loss: 2.3571 - val_age_output_loss: 4.0389 - val_weight_output_loss: 1.7818 - val_bag_output_loss: 1.2346 - val_footwear_output_loss: 1.3371 - val_pose_output_loss: 3.0108 - val_emotion_output_loss: 1.6023 - val_gender_output_acc: 0.7396 - val_image_quality_output_acc: 0.5218 - val_age_output_acc: 0.3695 - val_weight_output_acc: 0.4311 - val_bag_output_acc: 0.5893 - val_footwear_output_acc: 0.5903 - val_pose_output_acc: 0.3571 - val_emotion_output_acc: 0.6830
# Epoch 9/10
# 359/360 [============================>.] - ETA: 0s - loss: 28.6955 - gender_output_loss: 0.1800 - image_quality_output_loss: 0.3740 - age_output_loss: 0.5527 - weight_output_loss: 0.3920 - bag_output_loss: 0.3606 - footwear_output_loss: 0.3232 - pose_output_loss: 0.2104 - emotion_output_loss: 0.3681 - gender_output_acc: 0.9260 - image_quality_output_acc: 0.8515 - age_output_acc: 0.7949 - weight_output_acc: 0.8534 - bag_output_acc: 0.8599 - footwear_output_acc: 0.8740 - pose_output_acc: 0.9224 - emotion_output_acc: 0.8646Epoch 9/10
# 360/360 [==============================] - 81s 224ms/step - loss: 28.6937 - gender_output_loss: 0.1801 - image_quality_output_loss: 0.3744 - age_output_loss: 0.5532 - weight_output_loss: 0.3924 - bag_output_loss: 0.3609 - footwear_output_loss: 0.3236 - pose_output_loss: 0.2105 - emotion_output_loss: 0.3680 - gender_output_acc: 0.9260 - image_quality_output_acc: 0.8511 - age_output_acc: 0.7947 - weight_output_acc: 0.8531 - bag_output_acc: 0.8598 - footwear_output_acc: 0.8736 - pose_output_acc: 0.9223 - emotion_output_acc: 0.8646 - val_loss: 41.6584 - val_gender_output_loss: 1.3471 - val_image_quality_output_loss: 2.4734 - val_age_output_loss: 2.9635 - val_weight_output_loss: 1.7429 - val_bag_output_loss: 2.5983 - val_footwear_output_loss: 2.1100 - val_pose_output_loss: 1.0617 - val_emotion_output_loss: 2.7927 - val_gender_output_acc: 0.6771 - val_image_quality_output_acc: 0.5506 - val_age_output_acc: 0.2728 - val_weight_output_acc: 0.4335 - val_bag_output_acc: 0.5645 - val_footwear_output_acc: 0.4484 - val_pose_output_acc: 0.7138 - val_emotion_output_acc: 0.1761
# Epoch 10/10
# 360/360 [==============================] - 80s 223ms/step - loss: 25.7771 - gender_output_loss: 0.1664 - image_quality_output_loss: 0.3619 - age_output_loss: 0.4975 - weight_output_loss: 0.3417 - bag_output_loss: 0.3148 - footwear_output_loss: 0.3063 - pose_output_loss: 0.1873 - emotion_output_loss: 0.3338 - gender_output_acc: 0.9328 - image_quality_output_acc: 0.8554 - age_output_acc: 0.8140 - weight_output_acc: 0.8729 - bag_output_acc: 0.8790 - footwear_output_acc: 0.8808 - pose_output_acc: 0.9306 - emotion_output_acc: 0.8800 - val_loss: 39.6242 - val_gender_output_loss: 1.0544 - val_image_quality_output_loss: 1.9643 - val_age_output_loss: 2.4430 - val_weight_output_loss: 3.6383 - val_bag_output_loss: 2.2993 - val_footwear_output_loss: 1.9364 - val_pose_output_loss: 2.3545 - val_emotion_output_loss: 1.8400 - val_gender_output_acc: 0.6925 - val_image_quality_output_acc: 0.5521 - val_age_output_acc: 0.3690 - val_weight_output_acc: 0.4306 - val_bag_output_acc: 0.4028 - val_footwear_output_acc: 0.4400 - val_pose_output_acc: 0.4990 - val_emotion_output_acc: 0.6905
# Epoch 10/10

# %%
ckpt_callback = ModelCheckpoint(filepath='test_curr_1.h5', monitor='val_loss',save_best_only=True , save_weights_only=True, mode='auto',period=10)
lr_manager = OneCycleLR(samples=train_df.shape[0], epochs=10, batch_size=16,
                    steps=16, max_lr=0.0125,
                    end_percentage=0.1, scale_percentage=None,
                    maximum_momentum=None, minimum_momentum=None)

model2.load_weights('test_curr.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.005, momentum = 0.00009),loss_weights=lossWeights,
              metrics=['accuracy'])


model2.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=10,
    verbose=1,callbacks=[ckpt_callback,lr_manager]
   # preprocessing_function=get_random_eraser(v_l=0, v_h=16),
)
# Out:
# Epoch 1/10
#   3/360 [..............................] - ETA: 19:06 - loss: 24.0832 - gender_output_loss: 0.1690 - image_quality_output_loss: 0.3471 - age_output_loss: 0.3240 - weight_output_loss: 0.2469 - bag_output_loss: 0.2482 - footwear_output_loss: 0.2355 - pose_output_loss: 0.1228 - emotion_output_loss: 0.2968 - gender_output_acc: 0.9375 - image_quality_output_acc: 0.8542 - age_output_acc: 0.8854 - weight_output_acc: 0.9479 - bag_output_acc: 0.9271 - footwear_output_acc: 0.9167 - pose_output_acc: 0.9583 - emotion_output_acc: 0.8854
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.291614). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 360/360 [==============================] - 90s 250ms/step - loss: 22.7743 - gender_output_loss: 0.1033 - image_quality_output_loss: 0.2146 - age_output_loss: 0.2825 - weight_output_loss: 0.2031 - bag_output_loss: 0.1859 - footwear_output_loss: 0.1846 - pose_output_loss: 0.1178 - emotion_output_loss: 0.1927 - gender_output_acc: 0.9611 - image_quality_output_acc: 0.9215 - age_output_acc: 0.9033 - weight_output_acc: 0.9293 - bag_output_acc: 0.9323 - footwear_output_acc: 0.9352 - pose_output_acc: 0.9572 - emotion_output_acc: 0.9349 - val_loss: 33.1642 - val_gender_output_loss: 0.6344 - val_image_quality_output_loss: 1.8351 - val_age_output_loss: 2.2501 - val_weight_output_loss: 1.4536 - val_bag_output_loss: 1.7480 - val_footwear_output_loss: 2.0360 - val_pose_output_loss: 0.9723 - val_emotion_output_loss: 1.6210 - val_gender_output_acc: 0.7723 - val_image_quality_output_acc: 0.4097 - val_age_output_acc: 0.2837 - val_weight_output_acc: 0.5074 - val_bag_output_acc: 0.5868 - val_footwear_output_acc: 0.4043 - val_pose_output_acc: 0.7252 - val_emotion_output_acc: 0.6806
#  - lr: 0.00734
# Epoch 2/10
# 360/360 [==============================] - 81s 226ms/step - loss: 21.3027 - gender_output_loss: 0.0981 - image_quality_output_loss: 0.2058 - age_output_loss: 0.2733 - weight_output_loss: 0.1962 - bag_output_loss: 0.1803 - footwear_output_loss: 0.1876 - pose_output_loss: 0.1143 - emotion_output_loss: 0.1801 - gender_output_acc: 0.9622 - image_quality_output_acc: 0.9214 - age_output_acc: 0.9016 - weight_output_acc: 0.9319 - bag_output_acc: 0.9347 - footwear_output_acc: 0.9317 - pose_output_acc: 0.9589 - emotion_output_acc: 0.9367 - val_loss: 58.1769 - val_gender_output_loss: 1.6045 - val_image_quality_output_loss: 8.0169 - val_age_output_loss: 9.8636 - val_weight_output_loss: 3.8234 - val_bag_output_loss: 4.4291 - val_footwear_output_loss: 3.5081 - val_pose_output_loss: 3.7688 - val_emotion_output_loss: 3.9225 - val_gender_output_acc: 0.6930 - val_image_quality_output_acc: 0.3031 - val_age_output_acc: 0.2530 - val_weight_output_acc: 0.3998 - val_bag_output_acc: 0.5456 - val_footwear_output_acc: 0.4167 - val_pose_output_acc: 0.3938 - val_emotion_output_acc: 0.7078
#  - lr: 0.01141
# Epoch 3/10
# 360/360 [==============================] - 82s 227ms/step - loss: 20.2330 - gender_output_loss: 0.1218 - image_quality_output_loss: 0.2374 - age_output_loss: 0.2914 - weight_output_loss: 0.2163 - bag_output_loss: 0.2016 - footwear_output_loss: 0.2072 - pose_output_loss: 0.1285 - emotion_output_loss: 0.1944 - gender_output_acc: 0.9546 - image_quality_output_acc: 0.9101 - age_output_acc: 0.8962 - weight_output_acc: 0.9208 - bag_output_acc: 0.9264 - footwear_output_acc: 0.9232 - pose_output_acc: 0.9539 - emotion_output_acc: 0.9312 - val_loss: 32.4907 - val_gender_output_loss: 2.3471 - val_image_quality_output_loss: 1.5872 - val_age_output_loss: 2.6262 - val_weight_output_loss: 2.4909 - val_bag_output_loss: 1.6186 - val_footwear_output_loss: 1.3962 - val_pose_output_loss: 0.8779 - val_emotion_output_loss: 1.5156 - val_gender_output_acc: 0.5853 - val_image_quality_output_acc: 0.4722 - val_age_output_acc: 0.2589 - val_weight_output_acc: 0.3497 - val_bag_output_acc: 0.5878 - val_footwear_output_acc: 0.6032 - val_pose_output_acc: 0.7500 - val_emotion_output_acc: 0.5665
#  - lr: 0.00516
# Epoch 4/10
# 360/360 [==============================] - 82s 227ms/step - loss: 18.9934 - gender_output_loss: 0.1135 - image_quality_output_loss: 0.2019 - age_output_loss: 0.2718 - weight_output_loss: 0.2079 - bag_output_loss: 0.1907 - footwear_output_loss: 0.1860 - pose_output_loss: 0.1235 - emotion_output_loss: 0.1867 - gender_output_acc: 0.9591 - image_quality_output_acc: 0.9258 - age_output_acc: 0.9024 - weight_output_acc: 0.9244 - bag_output_acc: 0.9294 - footwear_output_acc: 0.9312 - pose_output_acc: 0.9576 - emotion_output_acc: 0.9352 - val_loss: 28.3464 - val_gender_output_loss: 0.6622 - val_image_quality_output_loss: 1.7467 - val_age_output_loss: 2.3852 - val_weight_output_loss: 1.4654 - val_bag_output_loss: 1.2162 - val_footwear_output_loss: 1.4656 - val_pose_output_loss: 0.8507 - val_emotion_output_loss: 1.5367 - val_gender_output_acc: 0.7649 - val_image_quality_output_acc: 0.5501 - val_age_output_acc: 0.2778 - val_weight_output_acc: 0.5317 - val_bag_output_acc: 0.5446 - val_footwear_output_acc: 0.5878 - val_pose_output_acc: 0.7470 - val_emotion_output_acc: 0.6518
# 360/360 [==============================] - lr: 0.00009
# Epoch 5/10
# 360/360 [==============================] - 82s 227ms/step - loss: 17.8787 - gender_output_loss: 0.1069 - image_quality_output_loss: 0.1979 - age_output_loss: 0.2683 - weight_output_loss: 0.1874 - bag_output_loss: 0.1805 - footwear_output_loss: 0.1817 - pose_output_loss: 0.1143 - emotion_output_loss: 0.1696 - gender_output_acc: 0.9589 - image_quality_output_acc: 0.9249 - age_output_acc: 0.9052 - weight_output_acc: 0.9329 - bag_output_acc: 0.9341 - footwear_output_acc: 0.9341 - pose_output_acc: 0.9595 - emotion_output_acc: 0.9415 - val_loss: 27.6738 - val_gender_output_loss: 0.5898 - val_image_quality_output_loss: 1.7001 - val_age_output_loss: 2.2477 - val_weight_output_loss: 1.5820 - val_bag_output_loss: 1.2530 - val_footwear_output_loss: 1.3813 - val_pose_output_loss: 0.8612 - val_emotion_output_loss: 2.0336 - val_gender_output_acc: 0.7604 - val_image_quality_output_acc: 0.4945 - val_age_output_acc: 0.3090 - val_weight_output_acc: 0.4544 - val_bag_output_acc: 0.5640 - val_footwear_output_acc: 0.5605 - val_pose_output_acc: 0.6925 - val_emotion_output_acc: 0.7049
#  - lr: 0.00734
# Epoch 6/10
# 360/360 [==============================] - 82s 227ms/step - loss: 17.0018 - gender_output_loss: 0.1095 - image_quality_output_loss: 0.2052 - age_output_loss: 0.2989 - weight_output_loss: 0.2032 - bag_output_loss: 0.1950 - footwear_output_loss: 0.1798 - pose_output_loss: 0.1197 - emotion_output_loss: 0.1800 - gender_output_acc: 0.9601 - image_quality_output_acc: 0.9223 - age_output_acc: 0.8931 - weight_output_acc: 0.9297 - bag_output_acc: 0.9276 - footwear_output_acc: 0.9341 - pose_output_acc: 0.9563 - emotion_output_acc: 0.9377 - val_loss: 36.4494 - val_gender_output_loss: 0.9351 - val_image_quality_output_loss: 2.9679 - val_age_output_loss: 4.6035 - val_weight_output_loss: 2.2201 - val_bag_output_loss: 2.9579 - val_footwear_output_loss: 2.7223 - val_pose_output_loss: 2.1063 - val_emotion_output_loss: 2.8422 - val_gender_output_acc: 0.6954 - val_image_quality_output_acc: 0.3943 - val_age_output_acc: 0.2282 - val_weight_output_acc: 0.5977 - val_bag_output_acc: 0.2520 - val_footwear_output_acc: 0.5134 - val_pose_output_acc: 0.5099 - val_emotion_output_acc: 0.5734
#  - lr: 0.01141
# Epoch 7/10
#  - lr: 0.00734
# 360/360 [==============================] - 82s 227ms/step - loss: 16.2341 - gender_output_loss: 0.1095 - image_quality_output_loss: 0.2307 - age_output_loss: 0.2952 - weight_output_loss: 0.2050 - bag_output_loss: 0.1946 - footwear_output_loss: 0.1970 - pose_output_loss: 0.1399 - emotion_output_loss: 0.1944 - gender_output_acc: 0.9612 - image_quality_output_acc: 0.9146 - age_output_acc: 0.8938 - weight_output_acc: 0.9257 - bag_output_acc: 0.9298 - footwear_output_acc: 0.9294 - pose_output_acc: 0.9508 - emotion_output_acc: 0.9278 - val_loss: 32.2991 - val_gender_output_loss: 2.4385 - val_image_quality_output_loss: 1.7432 - val_age_output_loss: 3.4716 - val_weight_output_loss: 1.9725 - val_bag_output_loss: 2.9854 - val_footwear_output_loss: 1.7308 - val_pose_output_loss: 1.4442 - val_emotion_output_loss: 2.2536 - val_gender_output_acc: 0.6052 - val_image_quality_output_acc: 0.4673 - val_age_output_acc: 0.2515 - val_weight_output_acc: 0.4881 - val_bag_output_acc: 0.5377 - val_footwear_output_acc: 0.5595 - val_pose_output_acc: 0.6696 - val_emotion_output_acc: 0.6845
#  - lr: 0.00516
# Epoch 8/10
# 360/360 [==============================] - 81s 225ms/step - loss: 15.2987 - gender_output_loss: 0.1071 - image_quality_output_loss: 0.1990 - age_output_loss: 0.2697 - weight_output_loss: 0.1889 - bag_output_loss: 0.1930 - footwear_output_loss: 0.1693 - pose_output_loss: 0.1237 - emotion_output_loss: 0.1632 - gender_output_acc: 0.9598 - image_quality_output_acc: 0.9266 - age_output_acc: 0.9030 - weight_output_acc: 0.9300 - bag_output_acc: 0.9318 - footwear_output_acc: 0.9394 - pose_output_acc: 0.9569 - emotion_output_acc: 0.9439 - val_loss: 25.0436 - val_gender_output_loss: 0.6424 - val_image_quality_output_loss: 1.5978 - val_age_output_loss: 2.3606 - val_weight_output_loss: 1.7621 - val_bag_output_loss: 1.4567 - val_footwear_output_loss: 1.5598 - val_pose_output_loss: 0.7812 - val_emotion_output_loss: 1.3486 - val_gender_output_acc: 0.7584 - val_image_quality_output_acc: 0.4554 - val_age_output_acc: 0.3814 - val_weight_output_acc: 0.6200 - val_bag_output_acc: 0.5317 - val_footwear_output_acc: 0.6265 - val_pose_output_acc: 0.7312 - val_emotion_output_acc: 0.6339
#  - lr: 0.00009
# Epoch 9/10
#  - lr: 0.00516
# Epoch 8/10
# 360/360 [==============================] - 82s 227ms/step - loss: 14.4282 - gender_output_loss: 0.1004 - image_quality_output_loss: 0.1888 - age_output_loss: 0.2395 - weight_output_loss: 0.1607 - bag_output_loss: 0.1586 - footwear_output_loss: 0.1737 - pose_output_loss: 0.1093 - emotion_output_loss: 0.1601 - gender_output_acc: 0.9623 - image_quality_output_acc: 0.9312 - age_output_acc: 0.9184 - weight_output_acc: 0.9436 - bag_output_acc: 0.9423 - footwear_output_acc: 0.9345 - pose_output_acc: 0.9593 - emotion_output_acc: 0.9441 - val_loss: 24.2185 - val_gender_output_loss: 0.6246 - val_image_quality_output_loss: 1.3895 - val_age_output_loss: 2.6170 - val_weight_output_loss: 1.5881 - val_bag_output_loss: 1.6363 - val_footwear_output_loss: 1.2325 - val_pose_output_loss: 0.8256 - val_emotion_output_loss: 1.4935 - val_gender_output_acc: 0.7569 - val_image_quality_output_acc: 0.5238 - val_age_output_acc: 0.2867 - val_weight_output_acc: 0.5615 - val_bag_output_acc: 0.5883 - val_footwear_output_acc: 0.6066 - val_pose_output_acc: 0.6979 - val_emotion_output_acc: 0.6830
#  - lr: 0.00734
# Epoch 10/10
# 360/360 [==============================] - 81s 226ms/step - loss: 13.7601 - gender_output_loss: 0.1028 - image_quality_output_loss: 0.1891 - age_output_loss: 0.2457 - weight_output_loss: 0.1843 - bag_output_loss: 0.1733 - footwear_output_loss: 0.1633 - pose_output_loss: 0.1141 - emotion_output_loss: 0.1603 - gender_output_acc: 0.9616 - image_quality_output_acc: 0.9301 - age_output_acc: 0.9116 - weight_output_acc: 0.9332 - bag_output_acc: 0.9378 - footwear_output_acc: 0.9403 - pose_output_acc: 0.9592 - emotion_output_acc: 0.9454 - val_loss: 44.7179 - val_gender_output_loss: 2.4052 - val_image_quality_output_loss: 4.9755 - val_age_output_loss: 5.1322 - val_weight_output_loss: 4.1880 - val_bag_output_loss: 3.4810 - val_footwear_output_loss: 3.0575 - val_pose_output_loss: 1.9808 - val_emotion_output_loss: 7.3393 - val_gender_output_acc: 0.5947 - val_image_quality_output_acc: 0.2128 - val_age_output_acc: 0.1419 - val_weight_output_acc: 0.4058 - val_bag_output_acc: 0.5744 - val_footwear_output_acc: 0.5451 - val_pose_output_acc: 0.5868 - val_emotion_output_acc: 0.0933
#  - lr: 0.01141

# %%
from keras.models import load_model

model2.load_weights('test_curr_1.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.01, momentum = 0.009),loss_weights=lossWeights,
              metrics=['accuracy'])

results = model2.evaluate(valid_gen)
print(dict(zip(model2.metrics_names,results)))
# Out:
# 63/63 [==============================] - 11s 181ms/step
# {'loss': 44.73192493499271, 'gender_output_loss': 2.3900606215946256, 'image_quality_output_loss': 4.986669267926898, 'age_output_loss': 5.143558661142985, 'weight_output_loss': 4.180270444779169, 'bag_output_loss': 3.496041227900793, 'footwear_output_loss': 3.053635451528761, 'pose_output_loss': 1.987956200327192, 'emotion_output_loss': 7.335521660153828, 'gender_output_acc': 0.5942460317460317, 'image_quality_output_acc': 0.21329365079365079, 'age_output_acc': 0.13938492063492064, 'weight_output_acc': 0.4087301587301587, 'bag_output_acc': 0.5729166666666666, 'footwear_output_acc': 0.5416666666666666, 'pose_output_acc': 0.5853174603174603, 'emotion_output_acc': 0.09077380952380952}

# %%
ckpt_callback = ModelCheckpoint(filepath='test_curr_2.h5', monitor='val_loss',save_best_only=True , save_weights_only=True, mode= 'min',period=10)
lr_manager = OneCycleLR(samples=train_df.shape[0], epochs=10, batch_size=16,
                    steps=16, max_lr=0.0125,
                    end_percentage=0.1, scale_percentage=None,
                    maximum_momentum=None, minimum_momentum=None)

model2.load_weights('test_curr_1.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.005, momentum = 0.00009),loss_weights=lossWeights,
              metrics=['accuracy'])


model2.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=20,
    verbose=1,callbacks=[ckpt_callback,lr_manager]
   # preprocessing_function=get_random_eraser(v_l=0, v_h=16),
)
# Out:
# Epoch 1/20
#   3/360 [..............................] - ETA: 19:14 - loss: 14.5535 - gender_output_loss: 0.1412 - image_quality_output_loss: 0.3142 - age_output_loss: 0.5915 - weight_output_loss: 0.3974 - bag_output_loss: 0.2058 - footwear_output_loss: 0.3112 - pose_output_loss: 0.1787 - emotion_output_loss: 0.2558 - gender_output_acc: 0.9688 - image_quality_output_acc: 0.8438 - age_output_acc: 0.8438 - weight_output_acc: 0.8854 - bag_output_acc: 0.9271 - footwear_output_acc: 0.8958 - pose_output_acc: 0.9479 - emotion_output_acc: 0.9167
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.338999). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 360/360 [==============================] - 90s 249ms/step - loss: 13.4088 - gender_output_loss: 0.1145 - image_quality_output_loss: 0.2113 - age_output_loss: 0.2995 - weight_output_loss: 0.2071 - bag_output_loss: 0.2038 - footwear_output_loss: 0.1973 - pose_output_loss: 0.1285 - emotion_output_loss: 0.1903 - gender_output_acc: 0.9568 - image_quality_output_acc: 0.9200 - age_output_acc: 0.8936 - weight_output_acc: 0.9242 - bag_output_acc: 0.9213 - footwear_output_acc: 0.9265 - pose_output_acc: 0.9545 - emotion_output_acc: 0.9316 - val_loss: 27.0284 - val_gender_output_loss: 0.6822 - val_image_quality_output_loss: 2.0382 - val_age_output_loss: 3.4415 - val_weight_output_loss: 2.3756 - val_bag_output_loss: 1.4505 - val_footwear_output_loss: 1.7881 - val_pose_output_loss: 0.8971 - val_emotion_output_loss: 2.7562 - val_gender_output_acc: 0.7639 - val_image_quality_output_acc: 0.4861 - val_age_output_acc: 0.4018 - val_weight_output_acc: 0.6186 - val_bag_output_acc: 0.5516 - val_footwear_output_acc: 0.5952 - val_pose_output_acc: 0.7406 - val_emotion_output_acc: 0.4182
#  - lr: 0.00734
# Epoch 2/20
# 360/360 [==============================] - 81s 226ms/step - loss: 12.6647 - gender_output_loss: 0.1051 - image_quality_output_loss: 0.1950 - age_output_loss: 0.2592 - weight_output_loss: 0.1887 - bag_output_loss: 0.1730 - footwear_output_loss: 0.1706 - pose_output_loss: 0.1195 - emotion_output_loss: 0.1695 - gender_output_acc: 0.9623 - image_quality_output_acc: 0.9283 - age_output_acc: 0.9076 - weight_output_acc: 0.9319 - bag_output_acc: 0.9375 - footwear_output_acc: 0.9391 - pose_output_acc: 0.9565 - emotion_output_acc: 0.9413 - val_loss: 47.5695 - val_gender_output_loss: 0.7513 - val_image_quality_output_loss: 6.5209 - val_age_output_loss: 3.0804 - val_weight_output_loss: 4.9410 - val_bag_output_loss: 4.9595 - val_footwear_output_loss: 5.8479 - val_pose_output_loss: 1.3673 - val_emotion_output_loss: 9.0444 - val_gender_output_acc: 0.7401 - val_image_quality_output_acc: 0.3135 - val_age_output_acc: 0.2356 - val_weight_output_acc: 0.2034 - val_bag_output_acc: 0.1776 - val_footwear_output_acc: 0.3844 - val_pose_output_acc: 0.7049 - val_emotion_output_acc: 0.1146
#  - lr: 0.01141
# Epoch 3/20
# 360/360 [==============================] - 81s 225ms/step - loss: 12.2189 - gender_output_loss: 0.0978 - image_quality_output_loss: 0.1997 - age_output_loss: 0.2751 - weight_output_loss: 0.1969 - bag_output_loss: 0.1838 - footwear_output_loss: 0.1884 - pose_output_loss: 0.1190 - emotion_output_loss: 0.1694 - gender_output_acc: 0.9634 - image_quality_output_acc: 0.9268 - age_output_acc: 0.9021 - weight_output_acc: 0.9293 - bag_output_acc: 0.9326 - footwear_output_acc: 0.9308 - pose_output_acc: 0.9567 - emotion_output_acc: 0.9425 - val_loss: 31.9846 - val_gender_output_loss: 1.0131 - val_image_quality_output_loss: 2.3116 - val_age_output_loss: 5.3039 - val_weight_output_loss: 4.5233 - val_bag_output_loss: 2.3314 - val_footwear_output_loss: 2.3591 - val_pose_output_loss: 1.3303 - val_emotion_output_loss: 2.2578 - val_gender_output_acc: 0.6994 - val_image_quality_output_acc: 0.3552 - val_age_output_acc: 0.2192 - val_weight_output_acc: 0.1186 - val_bag_output_acc: 0.4861 - val_footwear_output_acc: 0.4221 - val_pose_output_acc: 0.6012 - val_emotion_output_acc: 0.4807
#  - lr: 0.00516
# Epoch 4/20
# 360/360 [==============================] - 81s 225ms/step - loss: 11.5791 - gender_output_loss: 0.1026 - image_quality_output_loss: 0.1762 - age_output_loss: 0.2293 - weight_output_loss: 0.1711 - bag_output_loss: 0.1560 - footwear_output_loss: 0.1647 - pose_output_loss: 0.1127 - emotion_output_loss: 0.1506 - gender_output_acc: 0.9611 - image_quality_output_acc: 0.9338 - age_output_acc: 0.9207 - weight_output_acc: 0.9369 - bag_output_acc: 0.9424 - footwear_output_acc: 0.9368 - pose_output_acc: 0.9602 - emotion_output_acc: 0.9473 - val_loss: 22.0846 - val_gender_output_loss: 0.6971 - val_image_quality_output_loss: 1.5271 - val_age_output_loss: 2.4857 - val_weight_output_loss: 1.7983 - val_bag_output_loss: 1.4456 - val_footwear_output_loss: 1.5468 - val_pose_output_loss: 0.8632 - val_emotion_output_loss: 1.6000 - val_gender_output_acc: 0.7669 - val_image_quality_output_acc: 0.4782 - val_age_output_acc: 0.3636 - val_weight_output_acc: 0.5064 - val_bag_output_acc: 0.5561 - val_footwear_output_acc: 0.5779 - val_pose_output_acc: 0.7485 - val_emotion_output_acc: 0.6210
#  - lr: 0.00009
# Epoch 5/20
# 360/360 [==============================] - 81s 226ms/step - loss: 11.1369 - gender_output_loss: 0.0972 - image_quality_output_loss: 0.1702 - age_output_loss: 0.2471 - weight_output_loss: 0.1582 - bag_output_loss: 0.1663 - footwear_output_loss: 0.1633 - pose_output_loss: 0.1095 - emotion_output_loss: 0.1457 - gender_output_acc: 0.9635 - image_quality_output_acc: 0.9418 - age_output_acc: 0.9127 - weight_output_acc: 0.9431 - bag_output_acc: 0.9396 - footwear_output_acc: 0.9396 - pose_output_acc: 0.9595 - emotion_output_acc: 0.9502 - val_loss: 22.4507 - val_gender_output_loss: 0.7505 - val_image_quality_output_loss: 1.8708 - val_age_output_loss: 2.3112 - val_weight_output_loss: 1.9898 - val_bag_output_loss: 1.8038 - val_footwear_output_loss: 1.3168 - val_pose_output_loss: 1.0773 - val_emotion_output_loss: 1.6500 - val_gender_output_acc: 0.7411 - val_image_quality_output_acc: 0.5179 - val_age_output_acc: 0.3294 - val_weight_output_acc: 0.5521 - val_bag_output_acc: 0.5317 - val_footwear_output_acc: 0.5813 - val_pose_output_acc: 0.6538 - val_emotion_output_acc: 0.4955
#  - lr: 0.00734
# Epoch 6/20
# 360/360 [==============================] - 81s 225ms/step - loss: 10.7372 - gender_output_loss: 0.0929 - image_quality_output_loss: 0.2105 - age_output_loss: 0.2397 - weight_output_loss: 0.1687 - bag_output_loss: 0.1594 - footwear_output_loss: 0.1516 - pose_output_loss: 0.1032 - emotion_output_loss: 0.1586 - gender_output_acc: 0.9654 - image_quality_output_acc: 0.9194 - age_output_acc: 0.9160 - weight_output_acc: 0.9405 - bag_output_acc: 0.9423 - footwear_output_acc: 0.9462 - pose_output_acc: 0.9644 - emotion_output_acc: 0.9449 - val_loss: 49.6180 - val_gender_output_loss: 0.9404 - val_image_quality_output_loss: 3.5401 - val_age_output_loss: 10.3703 - val_weight_output_loss: 3.1793 - val_bag_output_loss: 2.4168 - val_footwear_output_loss: 2.3470 - val_pose_output_loss: 9.4954 - val_emotion_output_loss: 8.0239 - val_gender_output_acc: 0.7331 - val_image_quality_output_acc: 0.4519 - val_age_output_acc: 0.1979 - val_weight_output_acc: 0.4187 - val_bag_output_acc: 0.5749 - val_footwear_output_acc: 0.5174 - val_pose_output_acc: 0.2227 - val_emotion_output_acc: 0.1503
#  - lr: 0.01141
# Epoch 7/20
# 360/360 [==============================] - 81s 225ms/step - loss: 10.5040 - gender_output_loss: 0.1058 - image_quality_output_loss: 0.1896 - age_output_loss: 0.2725 - weight_output_loss: 0.1784 - bag_output_loss: 0.1829 - footwear_output_loss: 0.1735 - pose_output_loss: 0.1203 - emotion_output_loss: 0.1699 - gender_output_acc: 0.9587 - image_quality_output_acc: 0.9294 - age_output_acc: 0.9009 - weight_output_acc: 0.9388 - bag_output_acc: 0.9320 - footwear_output_acc: 0.9362 - pose_output_acc: 0.9554 - emotion_output_acc: 0.9398 - val_loss: 27.4880 - val_gender_output_loss: 0.8960 - val_image_quality_output_loss: 1.9782 - val_age_output_loss: 4.9930 - val_weight_output_loss: 2.7434 - val_bag_output_loss: 2.3747 - val_footwear_output_loss: 2.3759 - val_pose_output_loss: 1.2703 - val_emotion_output_loss: 1.9031 - val_gender_output_acc: 0.7406 - val_image_quality_output_acc: 0.4668 - val_age_output_acc: 0.3938 - val_weight_output_acc: 0.4628 - val_bag_output_acc: 0.4807 - val_footwear_output_acc: 0.4464 - val_pose_output_acc: 0.6205 - val_emotion_output_acc: 0.6364
#  - lr: 0.00516
# Epoch 8/20
#
# Epoch 7/20
# 360/360 [==============================] - 81s 226ms/step - loss: 9.9649 - gender_output_loss: 0.0977 - image_quality_output_loss: 0.1607 - age_output_loss: 0.2231 - weight_output_loss: 0.1707 - bag_output_loss: 0.1552 - footwear_output_loss: 0.1472 - pose_output_loss: 0.1013 - emotion_output_loss: 0.1381 - gender_output_acc: 0.9625 - image_quality_output_acc: 0.9411 - age_output_acc: 0.9223 - weight_output_acc: 0.9402 - bag_output_acc: 0.9461 - footwear_output_acc: 0.9445 - pose_output_acc: 0.9635 - emotion_output_acc: 0.9519 - val_loss: 23.1208 - val_gender_output_loss: 1.0826 - val_image_quality_output_loss: 1.8445 - val_age_output_loss: 2.8459 - val_weight_output_loss: 2.6666 - val_bag_output_loss: 1.6377 - val_footwear_output_loss: 1.5460 - val_pose_output_loss: 1.1812 - val_emotion_output_loss: 1.6862 - val_gender_output_acc: 0.7188 - val_image_quality_output_acc: 0.4400 - val_age_output_acc: 0.3065 - val_weight_output_acc: 0.6305 - val_bag_output_acc: 0.5789 - val_footwear_output_acc: 0.5670 - val_pose_output_acc: 0.7460 - val_emotion_output_acc: 0.5372
#  - lr: 0.00009
# Epoch 9/20
# 360/360 [==============================] - 82s 228ms/step - loss: 9.6809 - gender_output_loss: 0.0856 - image_quality_output_loss: 0.1753 - age_output_loss: 0.2264 - weight_output_loss: 0.1827 - bag_output_loss: 0.1453 - footwear_output_loss: 0.1576 - pose_output_loss: 0.1095 - emotion_output_loss: 0.1425 - gender_output_acc: 0.9694 - image_quality_output_acc: 0.9353 - age_output_acc: 0.9196 - weight_output_acc: 0.9359 - bag_output_acc: 0.9465 - footwear_output_acc: 0.9412 - pose_output_acc: 0.9605 - emotion_output_acc: 0.9506 - val_loss: 21.9860 - val_gender_output_loss: 0.7146 - val_image_quality_output_loss: 2.0131 - val_age_output_loss: 2.5203 - val_weight_output_loss: 2.0664 - val_bag_output_loss: 1.6612 - val_footwear_output_loss: 1.7171 - val_pose_output_loss: 1.0984 - val_emotion_output_loss: 1.8734 - val_gender_output_acc: 0.7560 - val_image_quality_output_acc: 0.3963 - val_age_output_acc: 0.3502 - val_weight_output_acc: 0.4296 - val_bag_output_acc: 0.5660 - val_footwear_output_acc: 0.5600 - val_pose_output_acc: 0.7292 - val_emotion_output_acc: 0.6498
#  - lr: 0.00734
# Epoch 10/20
# 360/360 [==============================] - 81s 226ms/step - loss: 9.3862 - gender_output_loss: 0.0929 - image_quality_output_loss: 0.1805 - age_output_loss: 0.2214 - weight_output_loss: 0.1615 - bag_output_loss: 0.1657 - footwear_output_loss: 0.1528 - pose_output_loss: 0.1151 - emotion_output_loss: 0.1404 - gender_output_acc: 0.9661 - image_quality_output_acc: 0.9317 - age_output_acc: 0.9209 - weight_output_acc: 0.9417 - bag_output_acc: 0.9389 - footwear_output_acc: 0.9451 - pose_output_acc: 0.9599 - emotion_output_acc: 0.9507 - val_loss: 36.4568 - val_gender_output_loss: 1.7890 - val_image_quality_output_loss: 2.7378 - val_age_output_loss: 5.6053 - val_weight_output_loss: 2.7240 - val_bag_output_loss: 3.7852 - val_footwear_output_loss: 2.7080 - val_pose_output_loss: 1.7745 - val_emotion_output_loss: 7.2798 - val_gender_output_acc: 0.6275 - val_image_quality_output_acc: 0.3626 - val_age_output_acc: 0.3438 - val_weight_output_acc: 0.4152 - val_bag_output_acc: 0.3656 - val_footwear_output_acc: 0.4499 - val_pose_output_acc: 0.6166 - val_emotion_output_acc: 0.1627
#  - lr: 0.01141
# Epoch 11/20
# 360/360 [==============================] - 80s 222ms/step - loss: 9.2368 - gender_output_loss: 0.0957 - image_quality_output_loss: 0.1923 - age_output_loss: 0.2554 - weight_output_loss: 0.1619 - bag_output_loss: 0.1633 - footwear_output_loss: 0.1672 - pose_output_loss: 0.1194 - emotion_output_loss: 0.1672 - gender_output_acc: 0.9648 - image_quality_output_acc: 0.9312 - age_output_acc: 0.9110 - weight_output_acc: 0.9427 - bag_output_acc: 0.9409 - footwear_output_acc: 0.9391 - pose_output_acc: 0.9556 - emotion_output_acc: 0.9412 - val_loss: 23.7594 - val_gender_output_loss: 0.9171 - val_image_quality_output_loss: 2.7781 - val_age_output_loss: 3.6655 - val_weight_output_loss: 2.1483 - val_bag_output_loss: 2.3423 - val_footwear_output_loss: 1.5842 - val_pose_output_loss: 0.9111 - val_emotion_output_loss: 1.6054 - val_gender_output_acc: 0.7197 - val_image_quality_output_acc: 0.2996 - val_age_output_acc: 0.2688 - val_weight_output_acc: 0.6042 - val_bag_output_acc: 0.5868 - val_footwear_output_acc: 0.5332 - val_pose_output_acc: 0.7316 - val_emotion_output_acc: 0.5491
#  - lr: 0.00516
# Epoch 12/20
# 360/360 [==============================] - 82s 226ms/step - loss: 8.8854 - gender_output_loss: 0.0955 - image_quality_output_loss: 0.1656 - age_output_loss: 0.2306 - weight_output_loss: 0.1675 - bag_output_loss: 0.1593 - footwear_output_loss: 0.1486 - pose_output_loss: 0.1078 - emotion_output_loss: 0.1353 - gender_output_acc: 0.9638 - image_quality_output_acc: 0.9381 - age_output_acc: 0.9189 - weight_output_acc: 0.9396 - bag_output_acc: 0.9408 - footwear_output_acc: 0.9461 - pose_output_acc: 0.9618 - emotion_output_acc: 0.9550 - val_loss: 19.7340 - val_gender_output_loss: 0.7289 - val_image_quality_output_loss: 1.6051 - val_age_output_loss: 2.3998 - val_weight_output_loss: 1.9134 - val_bag_output_loss: 1.6236 - val_footwear_output_loss: 1.4192 - val_pose_output_loss: 0.9000 - val_emotion_output_loss: 1.5645 - val_gender_output_acc: 0.7485 - val_image_quality_output_acc: 0.5149 - val_age_output_acc: 0.3368 - val_weight_output_acc: 0.6136 - val_bag_output_acc: 0.5823 - val_footwear_output_acc: 0.5858 - val_pose_output_acc: 0.7267 - val_emotion_output_acc: 0.5992
#  - lr: 0.00009
# Epoch 13/20
# 360/360 [==============================] - 82s 226ms/step - loss: 8.4940 - gender_output_loss: 0.0872 - image_quality_output_loss: 0.1599 - age_output_loss: 0.1870 - weight_output_loss: 0.1466 - bag_output_loss: 0.1242 - footwear_output_loss: 0.1432 - pose_output_loss: 0.0905 - emotion_output_loss: 0.1299 - gender_output_acc: 0.9673 - image_quality_output_acc: 0.9441 - age_output_acc: 0.9342 - weight_output_acc: 0.9480 - bag_output_acc: 0.9565 - footwear_output_acc: 0.9486 - pose_output_acc: 0.9674 - emotion_output_acc: 0.9542 - val_loss: 26.4687 - val_gender_output_loss: 1.0253 - val_image_quality_output_loss: 3.5838 - val_age_output_loss: 2.8102 - val_weight_output_loss: 4.4896 - val_bag_output_loss: 2.1029 - val_footwear_output_loss: 1.6974 - val_pose_output_loss: 0.9623 - val_emotion_output_loss: 2.4895 - val_gender_output_acc: 0.7113 - val_image_quality_output_acc: 0.5437 - val_age_output_acc: 0.3507 - val_weight_output_acc: 0.1964 - val_bag_output_acc: 0.4360 - val_footwear_output_acc: 0.4955 - val_pose_output_acc: 0.6979 - val_emotion_output_acc: 0.4172
#  - lr: 0.00734
# Epoch 14/20
# 360/360 [==============================] - 81s 226ms/step - loss: 8.2814 - gender_output_loss: 0.0783 - image_quality_output_loss: 0.1536 - age_output_loss: 0.2081 - weight_output_loss: 0.1488 - bag_output_loss: 0.1451 - footwear_output_loss: 0.1337 - pose_output_loss: 0.1100 - emotion_output_loss: 0.1312 - gender_output_acc: 0.9701 - image_quality_output_acc: 0.9460 - age_output_acc: 0.9277 - weight_output_acc: 0.9473 - bag_output_acc: 0.9457 - footwear_output_acc: 0.9516 - pose_output_acc: 0.9614 - emotion_output_acc: 0.9548 - val_loss: 44.1688 - val_gender_output_loss: 1.1260 - val_image_quality_output_loss: 4.6287 - val_age_output_loss: 6.5708 - val_weight_output_loss: 11.9008 - val_bag_output_loss: 3.5261 - val_footwear_output_loss: 3.8300 - val_pose_output_loss: 2.5888 - val_emotion_output_loss: 2.8925 - val_gender_output_acc: 0.7247 - val_image_quality_output_acc: 0.5441 - val_age_output_acc: 0.1245 - val_weight_output_acc: 0.2197 - val_bag_output_acc: 0.2783 - val_footwear_output_acc: 0.4955 - val_pose_output_acc: 0.6791 - val_emotion_output_acc: 0.6265
#  - lr: 0.01141
# Epoch 15/20
# 360/360 [==============================] - 81s 226ms/step - loss: 8.3414 - gender_output_loss: 0.0938 - image_quality_output_loss: 0.1973 - age_output_loss: 0.2544 - weight_output_loss: 0.1751 - bag_output_loss: 0.1732 - footwear_output_loss: 0.1622 - pose_output_loss: 0.1176 - emotion_output_loss: 0.1589 - gender_output_acc: 0.9659 - image_quality_output_acc: 0.9281 - age_output_acc: 0.9099 - weight_output_acc: 0.9356 - bag_output_acc: 0.9359 - footwear_output_acc: 0.9410 - pose_output_acc: 0.9563 - emotion_output_acc: 0.9458 - val_loss: 26.3685 - val_gender_output_loss: 0.8690 - val_image_quality_output_loss: 2.7883 - val_age_output_loss: 4.0801 - val_weight_output_loss: 2.0417 - val_bag_output_loss: 3.1244 - val_footwear_output_loss: 2.1531 - val_pose_output_loss: 1.6524 - val_emotion_output_loss: 2.6970 - val_gender_output_acc: 0.7326 - val_image_quality_output_acc: 0.5233 - val_age_output_acc: 0.2351 - val_weight_output_acc: 0.5809 - val_bag_output_acc: 0.4082 - val_footwear_output_acc: 0.5898 - val_pose_output_acc: 0.7321 - val_emotion_output_acc: 0.6845
#  - lr: 0.00516
# Epoch 16/20
# 360/360 [==============================] - 81s 226ms/step - loss: 8.0098 - gender_output_loss: 0.0867 - image_quality_output_loss: 0.1537 - age_output_loss: 0.2091 - weight_output_loss: 0.1568 - bag_output_loss: 0.1566 - footwear_output_loss: 0.1527 - pose_output_loss: 0.0990 - emotion_output_loss: 0.1443 - gender_output_acc: 0.9671 - image_quality_output_acc: 0.9443 - age_output_acc: 0.9247 - weight_output_acc: 0.9439 - bag_output_acc: 0.9406 - footwear_output_acc: 0.9464 - pose_output_acc: 0.9641 - emotion_output_acc: 0.9522 - val_loss: 20.1912 - val_gender_output_loss: 0.6767 - val_image_quality_output_loss: 1.7013 - val_age_output_loss: 2.3955 - val_weight_output_loss: 2.4210 - val_bag_output_loss: 1.5758 - val_footwear_output_loss: 1.5377 - val_pose_output_loss: 1.1980 - val_emotion_output_loss: 1.9067 - val_gender_output_acc: 0.7634 - val_image_quality_output_acc: 0.4504 - val_age_output_acc: 0.3189 - val_weight_output_acc: 0.4499 - val_bag_output_acc: 0.5898 - val_footwear_output_acc: 0.5565 - val_pose_output_acc: 0.6577 - val_emotion_output_acc: 0.4623
#  - lr: 0.00009
# Epoch 17/20
#  - lr: 0.00516
# Epoch 16/20
# 360/360 [==============================] - 81s 226ms/step - loss: 7.6930 - gender_output_loss: 0.0865 - image_quality_output_loss: 0.1471 - age_output_loss: 0.1871 - weight_output_loss: 0.1312 - bag_output_loss: 0.1324 - footwear_output_loss: 0.1365 - pose_output_loss: 0.0910 - emotion_output_loss: 0.1250 - gender_output_acc: 0.9672 - image_quality_output_acc: 0.9456 - age_output_acc: 0.9329 - weight_output_acc: 0.9546 - bag_output_acc: 0.9523 - footwear_output_acc: 0.9495 - pose_output_acc: 0.9685 - emotion_output_acc: 0.9559 - val_loss: 21.2298 - val_gender_output_loss: 0.7559 - val_image_quality_output_loss: 2.1278 - val_age_output_loss: 2.9011 - val_weight_output_loss: 2.0028 - val_bag_output_loss: 1.4949 - val_footwear_output_loss: 2.2677 - val_pose_output_loss: 0.9904 - val_emotion_output_loss: 2.1188 - val_gender_output_acc: 0.7594 - val_image_quality_output_acc: 0.3636 - val_age_output_acc: 0.3666 - val_weight_output_acc: 0.4608 - val_bag_output_acc: 0.5689 - val_footwear_output_acc: 0.5035 - val_pose_output_acc: 0.7336 - val_emotion_output_acc: 0.4439
#  - lr: 0.00734
# Epoch 18/20
# 359/360 [============================>.] - ETA: 0s - loss: 7.5340 - gender_output_loss: 0.0773 - image_quality_output_loss: 0.1570 - age_output_loss: 0.2145 - weight_output_loss: 0.1505 - bag_output_loss: 0.1351 - footwear_output_loss: 0.1300 - pose_output_loss: 0.0869 - emotion_output_loss: 0.1153 - gender_output_acc: 0.9721 - image_quality_output_acc: 0.9426 - age_output_acc: 0.9255 - weight_output_acc: 0.9468 - bag_output_acc: 0.9508 - footwear_output_acc: 0.9536 - pose_output_acc: 0.9701 - emotion_output_acc: 0.9595
# Epoch 18/20
# 360/360 [==============================] - 82s 227ms/step - loss: 7.5378 - gender_output_loss: 0.0776 - image_quality_output_loss: 0.1577 - age_output_loss: 0.2145 - weight_output_loss: 0.1508 - bag_output_loss: 0.1354 - footwear_output_loss: 0.1300 - pose_output_loss: 0.0879 - emotion_output_loss: 0.1165 - gender_output_acc: 0.9721 - image_quality_output_acc: 0.9425 - age_output_acc: 0.9254 - weight_output_acc: 0.9468 - bag_output_acc: 0.9508 - footwear_output_acc: 0.9535 - pose_output_acc: 0.9698 - emotion_output_acc: 0.9592 - val_loss: 33.6365 - val_gender_output_loss: 1.3057 - val_image_quality_output_loss: 2.8914 - val_age_output_loss: 10.3279 - val_weight_output_loss: 2.5232 - val_bag_output_loss: 2.2304 - val_footwear_output_loss: 1.8694 - val_pose_output_loss: 3.3529 - val_emotion_output_loss: 2.7025 - val_gender_output_acc: 0.6796 - val_image_quality_output_acc: 0.5114 - val_age_output_acc: 0.0531 - val_weight_output_acc: 0.4673 - val_bag_output_acc: 0.3919 - val_footwear_output_acc: 0.5699 - val_pose_output_acc: 0.3924 - val_emotion_output_acc: 0.4975
#  - lr: 0.01141
# Epoch 19/20
# 360/360 [==============================] - 82s 227ms/step - loss: 7.6274 - gender_output_loss: 0.0852 - image_quality_output_loss: 0.1912 - age_output_loss: 0.2391 - weight_output_loss: 0.1694 - bag_output_loss: 0.1505 - footwear_output_loss: 0.1606 - pose_output_loss: 0.1166 - emotion_output_loss: 0.1557 - gender_output_acc: 0.9683 - image_quality_output_acc: 0.9282 - age_output_acc: 0.9160 - weight_output_acc: 0.9390 - bag_output_acc: 0.9447 - footwear_output_acc: 0.9420 - pose_output_acc: 0.9590 - emotion_output_acc: 0.9445 - val_loss: 25.3031 - val_gender_output_loss: 2.2147 - val_image_quality_output_loss: 2.1535 - val_age_output_loss: 3.1283 - val_weight_output_loss: 2.8900 - val_bag_output_loss: 2.4294 - val_footwear_output_loss: 2.1294 - val_pose_output_loss: 1.2236 - val_emotion_output_loss: 2.7980 - val_gender_output_acc: 0.6230 - val_image_quality_output_acc: 0.4196 - val_age_output_acc: 0.3343 - val_weight_output_acc: 0.5283 - val_bag_output_acc: 0.4330 - val_footwear_output_acc: 0.5541 - val_pose_output_acc: 0.7118 - val_emotion_output_acc: 0.3393
#  - lr: 0.00516
# Epoch 20/20
#  - lr: 0.01141
# Epoch 19/20
# 359/360 [============================>.] - ETA: 0s - loss: 7.2999 - gender_output_loss: 0.0818 - image_quality_output_loss: 0.1517 - age_output_loss: 0.2066 - weight_output_loss: 0.1434 - bag_output_loss: 0.1321 - footwear_output_loss: 0.1289 - pose_output_loss: 0.0948 - emotion_output_loss: 0.1218 - gender_output_acc: 0.9688 - image_quality_output_acc: 0.9439 - age_output_acc: 0.9281 - weight_output_acc: 0.9496 - bag_output_acc: 0.9510 - footwear_output_acc: 0.9548 - pose_output_acc: 0.9678 - emotion_output_acc: 0.9580 - lr: 0.00516
# 360/360 [==============================] - 82s 227ms/step - loss: 7.2992 - gender_output_loss: 0.0817 - image_quality_output_loss: 0.1517 - age_output_loss: 0.2063 - weight_output_loss: 0.1433 - bag_output_loss: 0.1323 - footwear_output_loss: 0.1290 - pose_output_loss: 0.0947 - emotion_output_loss: 0.1217 - gender_output_acc: 0.9689 - image_quality_output_acc: 0.9439 - age_output_acc: 0.9283 - weight_output_acc: 0.9497 - bag_output_acc: 0.9510 - footwear_output_acc: 0.9548 - pose_output_acc: 0.9678 - emotion_output_acc: 0.9582 - val_loss: 22.4620 - val_gender_output_loss: 0.8113 - val_image_quality_output_loss: 1.8509 - val_age_output_loss: 4.6529 - val_weight_output_loss: 2.4024 - val_bag_output_loss: 1.8501 - val_footwear_output_loss: 1.6284 - val_pose_output_loss: 0.8747 - val_emotion_output_loss: 2.2164 - val_gender_output_acc: 0.7614 - val_image_quality_output_acc: 0.4901 - val_age_output_acc: 0.2262 - val_weight_output_acc: 0.6156 - val_bag_output_acc: 0.5903 - val_footwear_output_acc: 0.5446 - val_pose_output_acc: 0.7217 - val_emotion_output_acc: 0.4846
#  - lr: 0.00009

# %%
from keras.models import load_model

model2.load_weights('test_curr_2.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.01, momentum = 0.009),loss_weights=lossWeights,
              metrics=['accuracy'])

results = model2.evaluate(valid_gen)
print(dict(zip(model2.metrics_names,results)))
# Out:
# 63/63 [==============================] - 763s 12s/step
# {'loss': 10.434503858051603, 'gender_output_loss': 0.18276735970247832, 'image_quality_output_loss': 0.3887781331108676, 'age_output_loss': 1.6311490403281317, 'weight_output_loss': 0.5153919111878152, 'bag_output_loss': 0.3425654869467493, 'footwear_output_loss': 0.3840886874804421, 'pose_output_loss': 0.19478214229826654, 'emotion_output_loss': 0.6200616593871798, 'gender_output_acc': 0.9399801587301587, 'image_quality_output_acc': 0.8933531746031746, 'age_output_acc': 0.5912698412698413, 'weight_output_acc': 0.8864087301587301, 'bag_output_acc': 0.9017857142857143, 'footwear_output_acc': 0.8903769841269841, 'pose_output_acc': 0.9370039682539683, 'emotion_output_acc': 0.8100198412698413}

# %% [markdown]
# # Run while data leak, Leads to higher accuracy

# %%
ckpt_callback = ModelCheckpoint(filepath='test_curr_3.h5', monitor='val_loss',save_best_only=True , save_weights_only=True, mode='auto',period=10)
lr_manager = OneCycleLR(samples=train_df.shape[0], epochs=10, batch_size=16,
                    steps=16, max_lr=0.0125,
                    end_percentage=0.1, scale_percentage=None,
                    maximum_momentum=None, minimum_momentum=None)

model2.load_weights('test_curr_2.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.0005, momentum = 0.0000009),loss_weights=lossWeights,
              metrics=['accuracy'])


model2.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=30,
    verbose=1,callbacks=[ckpt_callback]
   # preprocessing_function=get_random_eraser(v_l=0, v_h=16),
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/30
# 360/360 [==============================] - 752s 2s/step - loss: 8.4230 - gender_output_loss: 0.1554 - image_quality_output_loss: 0.3109 - age_output_loss: 0.4381 - weight_output_loss: 0.3188 - bag_output_loss: 0.2887 - footwear_output_loss: 0.2773 - pose_output_loss: 0.1724 - emotion_output_loss: 0.3071 - gender_output_acc: 0.9533 - image_quality_output_acc: 0.9027 - age_output_acc: 0.8747 - weight_output_acc: 0.9146 - bag_output_acc: 0.9160 - footwear_output_acc: 0.9193 - pose_output_acc: 0.9484 - emotion_output_acc: 0.9277 - val_loss: 8.3287 - val_gender_output_loss: 0.1391 - val_image_quality_output_loss: 0.2963 - val_age_output_loss: 0.4366 - val_weight_output_loss: 0.3066 - val_bag_output_loss: 0.2529 - val_footwear_output_loss: 0.3022 - val_pose_output_loss: 0.1690 - val_emotion_output_loss: 0.2925 - val_gender_output_acc: 0.9519 - val_image_quality_output_acc: 0.9048 - val_age_output_acc: 0.8795 - val_weight_output_acc: 0.9147 - val_bag_output_acc: 0.9187 - val_footwear_output_acc: 0.9177 - val_pose_output_acc: 0.9454 - val_emotion_output_acc: 0.9315
# Epoch 2/30
# 359/360 [============================>.] - ETA: 0s - loss: 7.6472 - gender_output_loss: 0.0982 - image_quality_output_loss: 0.2111 - age_output_loss: 0.2950 - weight_output_loss: 0.2195 - bag_output_loss: 0.1968 - footwear_output_loss: 0.1877 - pose_output_loss: 0.1196 - emotion_output_loss: 0.2075 - gender_output_acc: 0.9683 - image_quality_output_acc: 0.9307 - age_output_acc: 0.9062 - weight_output_acc: 0.9365 - bag_output_acc: 0.9376 - footwear_output_acc: 0.9420 - pose_output_acc: 0.9630 - emotion_output_acc: 0.9461Epoch 2/30
# 360/360 [==============================] - 81s 226ms/step - loss: 7.6479 - gender_output_loss: 0.0989 - image_quality_output_loss: 0.2110 - age_output_loss: 0.2947 - weight_output_loss: 0.2199 - bag_output_loss: 0.1964 - footwear_output_loss: 0.1874 - pose_output_loss: 0.1197 - emotion_output_loss: 0.2081 - gender_output_acc: 0.9683 - image_quality_output_acc: 0.9307 - age_output_acc: 0.9063 - weight_output_acc: 0.9365 - bag_output_acc: 0.9377 - footwear_output_acc: 0.9421 - pose_output_acc: 0.9629 - emotion_output_acc: 0.9460 - val_loss: 8.2109 - val_gender_output_loss: 0.1296 - val_image_quality_output_loss: 0.2996 - val_age_output_loss: 0.4234 - val_weight_output_loss: 0.2915 - val_bag_output_loss: 0.2406 - val_footwear_output_loss: 0.2900 - val_pose_output_loss: 0.1657 - val_emotion_output_loss: 0.2801 - val_gender_output_acc: 0.9559 - val_image_quality_output_acc: 0.9072 - val_age_output_acc: 0.8889 - val_weight_output_acc: 0.9231 - val_bag_output_acc: 0.9281 - val_footwear_output_acc: 0.9216 - val_pose_output_acc: 0.9474 - val_emotion_output_acc: 0.9330
# Epoch 3/30
# 360/360 [==============================] - 81s 224ms/step - loss: 7.2104 - gender_output_loss: 0.0718 - image_quality_output_loss: 0.1616 - age_output_loss: 0.2220 - weight_output_loss: 0.1650 - bag_output_loss: 0.1401 - footwear_output_loss: 0.1428 - pose_output_loss: 0.0820 - emotion_output_loss: 0.1562 - gender_output_acc: 0.9777 - image_quality_output_acc: 0.9459 - age_output_acc: 0.9305 - weight_output_acc: 0.9527 - bag_output_acc: 0.9546 - footwear_output_acc: 0.9543 - pose_output_acc: 0.9751 - emotion_output_acc: 0.9584 - val_loss: 8.1883 - val_gender_output_loss: 0.1453 - val_image_quality_output_loss: 0.3105 - val_age_output_loss: 0.4309 - val_weight_output_loss: 0.3026 - val_bag_output_loss: 0.2348 - val_footwear_output_loss: 0.2762 - val_pose_output_loss: 0.1623 - val_emotion_output_loss: 0.2782 - val_gender_output_acc: 0.9514 - val_image_quality_output_acc: 0.9062 - val_age_output_acc: 0.8844 - val_weight_output_acc: 0.9162 - val_bag_output_acc: 0.9301 - val_footwear_output_acc: 0.9266 - val_pose_output_acc: 0.9474 - val_emotion_output_acc: 0.9345
# Epoch 4/30
# 360/360 [==============================] - 81s 225ms/step - loss: 6.8714 - gender_output_loss: 0.0517 - image_quality_output_loss: 0.1221 - age_output_loss: 0.1647 - weight_output_loss: 0.1244 - bag_output_loss: 0.1012 - footwear_output_loss: 0.1042 - pose_output_loss: 0.0619 - emotion_output_loss: 0.1153 - gender_output_acc: 0.9849 - image_quality_output_acc: 0.9590 - age_output_acc: 0.9505 - weight_output_acc: 0.9620 - bag_output_acc: 0.9702 - footwear_output_acc: 0.9687 - pose_output_acc: 0.9822 - emotion_output_acc: 0.9682 - val_loss: 8.1848 - val_gender_output_loss: 0.1397 - val_image_quality_output_loss: 0.3181 - val_age_output_loss: 0.4340 - val_weight_output_loss: 0.3037 - val_bag_output_loss: 0.2542 - val_footwear_output_loss: 0.2716 - val_pose_output_loss: 0.1646 - val_emotion_output_loss: 0.2946 - val_gender_output_acc: 0.9573 - val_image_quality_output_acc: 0.9003 - val_age_output_acc: 0.8874 - val_weight_output_acc: 0.9276 - val_bag_output_acc: 0.9246 - val_footwear_output_acc: 0.9211 - val_pose_output_acc: 0.9514 - val_emotion_output_acc: 0.9286
# Epoch 5/30
# 360/360 [==============================] - 80s 222ms/step - loss: 6.6054 - gender_output_loss: 0.0406 - image_quality_output_loss: 0.0862 - age_output_loss: 0.1188 - weight_output_loss: 0.0888 - bag_output_loss: 0.0787 - footwear_output_loss: 0.0766 - pose_output_loss: 0.0480 - emotion_output_loss: 0.0847 - gender_output_acc: 0.9882 - image_quality_output_acc: 0.9732 - age_output_acc: 0.9658 - weight_output_acc: 0.9749 - bag_output_acc: 0.9762 - footwear_output_acc: 0.9780 - pose_output_acc: 0.9869 - emotion_output_acc: 0.9773 - val_loss: 8.1611 - val_gender_output_loss: 0.1367 - val_image_quality_output_loss: 0.3149 - val_age_output_loss: 0.4487 - val_weight_output_loss: 0.3079 - val_bag_output_loss: 0.2565 - val_footwear_output_loss: 0.2775 - val_pose_output_loss: 0.1585 - val_emotion_output_loss: 0.2987 - val_gender_output_acc: 0.9578 - val_image_quality_output_acc: 0.9097 - val_age_output_acc: 0.8844 - val_weight_output_acc: 0.9216 - val_bag_output_acc: 0.9251 - val_footwear_output_acc: 0.9216 - val_pose_output_acc: 0.9494 - val_emotion_output_acc: 0.9335
# Epoch 6/30
# 360/360 [==============================] - 81s 224ms/step - loss: 6.4166 - gender_output_loss: 0.0325 - image_quality_output_loss: 0.0663 - age_output_loss: 0.0884 - weight_output_loss: 0.0672 - bag_output_loss: 0.0593 - footwear_output_loss: 0.0597 - pose_output_loss: 0.0411 - emotion_output_loss: 0.0618 - gender_output_acc: 0.9918 - image_quality_output_acc: 0.9817 - age_output_acc: 0.9760 - weight_output_acc: 0.9817 - bag_output_acc: 0.9839 - footwear_output_acc: 0.9839 - pose_output_acc: 0.9894 - emotion_output_acc: 0.9839 - val_loss: 8.1658 - val_gender_output_loss: 0.1347 - val_image_quality_output_loss: 0.3250 - val_age_output_loss: 0.4666 - val_weight_output_loss: 0.3161 - val_bag_output_loss: 0.2603 - val_footwear_output_loss: 0.2800 - val_pose_output_loss: 0.1684 - val_emotion_output_loss: 0.2956 - val_gender_output_acc: 0.9598 - val_image_quality_output_acc: 0.9067 - val_age_output_acc: 0.8814 - val_weight_output_acc: 0.9221 - val_bag_output_acc: 0.9221 - val_footwear_output_acc: 0.9276 - val_pose_output_acc: 0.9484 - val_emotion_output_acc: 0.9291
# Epoch 7/30
# 360/360 [==============================] - 80s 224ms/step - loss: 6.2743 - gender_output_loss: 0.0266 - image_quality_output_loss: 0.0568 - age_output_loss: 0.0660 - weight_output_loss: 0.0506 - bag_output_loss: 0.0476 - footwear_output_loss: 0.0470 - pose_output_loss: 0.0350 - emotion_output_loss: 0.0468 - gender_output_acc: 0.9931 - image_quality_output_acc: 0.9851 - age_output_acc: 0.9834 - weight_output_acc: 0.9870 - bag_output_acc: 0.9868 - footwear_output_acc: 0.9880 - pose_output_acc: 0.9899 - emotion_output_acc: 0.9886 - val_loss: 8.1894 - val_gender_output_loss: 0.1360 - val_image_quality_output_loss: 0.3379 - val_age_output_loss: 0.4677 - val_weight_output_loss: 0.3281 - val_bag_output_loss: 0.2795 - val_footwear_output_loss: 0.2863 - val_pose_output_loss: 0.1651 - val_emotion_output_loss: 0.3120 - val_gender_output_acc: 0.9613 - val_image_quality_output_acc: 0.9087 - val_age_output_acc: 0.8874 - val_weight_output_acc: 0.9246 - val_bag_output_acc: 0.9187 - val_footwear_output_acc: 0.9266 - val_pose_output_acc: 0.9484 - val_emotion_output_acc: 0.9311
# Epoch 8/30
# 360/360 [==============================] - 81s 224ms/step - loss: 6.1500 - gender_output_loss: 0.0207 - image_quality_output_loss: 0.0434 - age_output_loss: 0.0516 - weight_output_loss: 0.0403 - bag_output_loss: 0.0394 - footwear_output_loss: 0.0354 - pose_output_loss: 0.0270 - emotion_output_loss: 0.0365 - gender_output_acc: 0.9950 - image_quality_output_acc: 0.9897 - age_output_acc: 0.9879 - weight_output_acc: 0.9905 - bag_output_acc: 0.9899 - footwear_output_acc: 0.9921 - pose_output_acc: 0.9935 - emotion_output_acc: 0.9917 - val_loss: 8.1945 - val_gender_output_loss: 0.1462 - val_image_quality_output_loss: 0.3562 - val_age_output_loss: 0.4788 - val_weight_output_loss: 0.3189 - val_bag_output_loss: 0.2806 - val_footwear_output_loss: 0.3053 - val_pose_output_loss: 0.1630 - val_emotion_output_loss: 0.3108 - val_gender_output_acc: 0.9583 - val_image_quality_output_acc: 0.9122 - val_age_output_acc: 0.8864 - val_weight_output_acc: 0.9231 - val_bag_output_acc: 0.9221 - val_footwear_output_acc: 0.9236 - val_pose_output_acc: 0.9539 - val_emotion_output_acc: 0.9355
# Epoch 9/30
# 360/360 [==============================] - 81s 224ms/step - loss: 6.0626 - gender_output_loss: 0.0227 - image_quality_output_loss: 0.0343 - age_output_loss: 0.0434 - weight_output_loss: 0.0357 - bag_output_loss: 0.0298 - footwear_output_loss: 0.0345 - pose_output_loss: 0.0217 - emotion_output_loss: 0.0267 - gender_output_acc: 0.9944 - image_quality_output_acc: 0.9923 - age_output_acc: 0.9904 - weight_output_acc: 0.9905 - bag_output_acc: 0.9924 - footwear_output_acc: 0.9914 - pose_output_acc: 0.9946 - emotion_output_acc: 0.9947 - val_loss: 8.1579 - val_gender_output_loss: 0.1475 - val_image_quality_output_loss: 0.3540 - val_age_output_loss: 0.4959 - val_weight_output_loss: 0.3230 - val_bag_output_loss: 0.2641 - val_footwear_output_loss: 0.2946 - val_pose_output_loss: 0.1659 - val_emotion_output_loss: 0.3199 - val_gender_output_acc: 0.9544 - val_image_quality_output_acc: 0.9082 - val_age_output_acc: 0.8805 - val_weight_output_acc: 0.9271 - val_bag_output_acc: 0.9320 - val_footwear_output_acc: 0.9286 - val_pose_output_acc: 0.9519 - val_emotion_output_acc: 0.9315
# Epoch 10/30
# 360/360 [==============================] - 80s 224ms/step - loss: 5.9852 - gender_output_loss: 0.0186 - image_quality_output_loss: 0.0325 - age_output_loss: 0.0337 - weight_output_loss: 0.0269 - bag_output_loss: 0.0275 - footwear_output_loss: 0.0265 - pose_output_loss: 0.0240 - emotion_output_loss: 0.0234 - gender_output_acc: 0.9959 - image_quality_output_acc: 0.9925 - age_output_acc: 0.9924 - weight_output_acc: 0.9941 - bag_output_acc: 0.9932 - footwear_output_acc: 0.9932 - pose_output_acc: 0.9945 - emotion_output_acc: 0.9950 - val_loss: 8.1266 - val_gender_output_loss: 0.1417 - val_image_quality_output_loss: 0.3630 - val_age_output_loss: 0.4900 - val_weight_output_loss: 0.3248 - val_bag_output_loss: 0.2626 - val_footwear_output_loss: 0.3014 - val_pose_output_loss: 0.1652 - val_emotion_output_loss: 0.3264 - val_gender_output_acc: 0.9588 - val_image_quality_output_acc: 0.9152 - val_age_output_acc: 0.8839 - val_weight_output_acc: 0.9191 - val_bag_output_acc: 0.9306 - val_footwear_output_acc: 0.9286 - val_pose_output_acc: 0.9534 - val_emotion_output_acc: 0.9350
# Epoch 11/30
# 360/360 [==============================] - 79s 220ms/step - loss: 5.9285 - gender_output_loss: 0.0184 - image_quality_output_loss: 0.0250 - age_output_loss: 0.0361 - weight_output_loss: 0.0274 - bag_output_loss: 0.0250 - footwear_output_loss: 0.0231 - pose_output_loss: 0.0224 - emotion_output_loss: 0.0201 - gender_output_acc: 0.9952 - image_quality_output_acc: 0.9945 - age_output_acc: 0.9918 - weight_output_acc: 0.9926 - bag_output_acc: 0.9932 - footwear_output_acc: 0.9953 - pose_output_acc: 0.9948 - emotion_output_acc: 0.9959 - val_loss: 8.1600 - val_gender_output_loss: 0.1461 - val_image_quality_output_loss: 0.3608 - val_age_output_loss: 0.5124 - val_weight_output_loss: 0.3285 - val_bag_output_loss: 0.2794 - val_footwear_output_loss: 0.3191 - val_pose_output_loss: 0.1729 - val_emotion_output_loss: 0.3304 - val_gender_output_acc: 0.9568 - val_image_quality_output_acc: 0.9117 - val_age_output_acc: 0.8834 - val_weight_output_acc: 0.9216 - val_bag_output_acc: 0.9266 - val_footwear_output_acc: 0.9246 - val_pose_output_acc: 0.9499 - val_emotion_output_acc: 0.9291
# Epoch 12/30
# 360/360 [==============================] - 80s 222ms/step - loss: 5.8711 - gender_output_loss: 0.0172 - image_quality_output_loss: 0.0238 - age_output_loss: 0.0316 - weight_output_loss: 0.0243 - bag_output_loss: 0.0226 - footwear_output_loss: 0.0226 - pose_output_loss: 0.0201 - emotion_output_loss: 0.0187 - gender_output_acc: 0.9961 - image_quality_output_acc: 0.9951 - age_output_acc: 0.9927 - weight_output_acc: 0.9937 - bag_output_acc: 0.9946 - footwear_output_acc: 0.9948 - pose_output_acc: 0.9944 - emotion_output_acc: 0.9960 - val_loss: 8.0932 - val_gender_output_loss: 0.1529 - val_image_quality_output_loss: 0.3718 - val_age_output_loss: 0.4958 - val_weight_output_loss: 0.3261 - val_bag_output_loss: 0.2704 - val_footwear_output_loss: 0.3051 - val_pose_output_loss: 0.1727 - val_emotion_output_loss: 0.3288 - val_gender_output_acc: 0.9568 - val_image_quality_output_acc: 0.9092 - val_age_output_acc: 0.8899 - val_weight_output_acc: 0.9291 - val_bag_output_acc: 0.9251 - val_footwear_output_acc: 0.9311 - val_pose_output_acc: 0.9524 - val_emotion_output_acc: 0.9320
# Epoch 13/30
# 360/360 [==============================] - 80s 222ms/step - loss: 5.8075 - gender_output_loss: 0.0153 - image_quality_output_loss: 0.0218 - age_output_loss: 0.0284 - weight_output_loss: 0.0203 - bag_output_loss: 0.0196 - footwear_output_loss: 0.0192 - pose_output_loss: 0.0176 - emotion_output_loss: 0.0160 - gender_output_acc: 0.9961 - image_quality_output_acc: 0.9945 - age_output_acc: 0.9937 - weight_output_acc: 0.9944 - bag_output_acc: 0.9951 - footwear_output_acc: 0.9956 - pose_output_acc: 0.9955 - emotion_output_acc: 0.9967 - val_loss: 8.1081 - val_gender_output_loss: 0.1491 - val_image_quality_output_loss: 0.3747 - val_age_output_loss: 0.5016 - val_weight_output_loss: 0.3360 - val_bag_output_loss: 0.2846 - val_footwear_output_loss: 0.3242 - val_pose_output_loss: 0.1743 - val_emotion_output_loss: 0.3346 - val_gender_output_acc: 0.9593 - val_image_quality_output_acc: 0.9127 - val_age_output_acc: 0.8844 - val_weight_output_acc: 0.9216 - val_bag_output_acc: 0.9281 - val_footwear_output_acc: 0.9281 - val_pose_output_acc: 0.9534 - val_emotion_output_acc: 0.9325
# Epoch 14/30
# 360/360 [==============================] - 81s 224ms/step - loss: 5.7498 - gender_output_loss: 0.0145 - image_quality_output_loss: 0.0188 - age_output_loss: 0.0246 - weight_output_loss: 0.0164 - bag_output_loss: 0.0177 - footwear_output_loss: 0.0178 - pose_output_loss: 0.0161 - emotion_output_loss: 0.0147 - gender_output_acc: 0.9963 - image_quality_output_acc: 0.9963 - age_output_acc: 0.9943 - weight_output_acc: 0.9963 - bag_output_acc: 0.9957 - footwear_output_acc: 0.9964 - pose_output_acc: 0.9961 - emotion_output_acc: 0.9977 - val_loss: 8.1119 - val_gender_output_loss: 0.1474 - val_image_quality_output_loss: 0.3838 - val_age_output_loss: 0.5075 - val_weight_output_loss: 0.3472 - val_bag_output_loss: 0.2902 - val_footwear_output_loss: 0.3263 - val_pose_output_loss: 0.1707 - val_emotion_output_loss: 0.3498 - val_gender_output_acc: 0.9613 - val_image_quality_output_acc: 0.9092 - val_age_output_acc: 0.8844 - val_weight_output_acc: 0.9226 - val_bag_output_acc: 0.9296 - val_footwear_output_acc: 0.9271 - val_pose_output_acc: 0.9549 - val_emotion_output_acc: 0.9311
# Epoch 15/30
# 360/360 [==============================] - 81s 224ms/step - loss: 5.7054 - gender_output_loss: 0.0128 - image_quality_output_loss: 0.0207 - age_output_loss: 0.0236 - weight_output_loss: 0.0169 - bag_output_loss: 0.0170 - footwear_output_loss: 0.0149 - pose_output_loss: 0.0151 - emotion_output_loss: 0.0153 - gender_output_acc: 0.9966 - image_quality_output_acc: 0.9951 - age_output_acc: 0.9943 - weight_output_acc: 0.9957 - bag_output_acc: 0.9954 - footwear_output_acc: 0.9971 - pose_output_acc: 0.9964 - emotion_output_acc: 0.9959 - val_loss: 8.0690 - val_gender_output_loss: 0.1433 - val_image_quality_output_loss: 0.3884 - val_age_output_loss: 0.5314 - val_weight_output_loss: 0.3351 - val_bag_output_loss: 0.2781 - val_footwear_output_loss: 0.3322 - val_pose_output_loss: 0.1699 - val_emotion_output_loss: 0.3415 - val_gender_output_acc: 0.9583 - val_image_quality_output_acc: 0.9072 - val_age_output_acc: 0.8814 - val_weight_output_acc: 0.9246 - val_bag_output_acc: 0.9281 - val_footwear_output_acc: 0.9231 - val_pose_output_acc: 0.9544 - val_emotion_output_acc: 0.9330
# Epoch 16/30
# 360/360 [==============================] - 80s 222ms/step - loss: 5.6643 - gender_output_loss: 0.0135 - image_quality_output_loss: 0.0165 - age_output_loss: 0.0220 - weight_output_loss: 0.0176 - bag_output_loss: 0.0186 - footwear_output_loss: 0.0163 - pose_output_loss: 0.0167 - emotion_output_loss: 0.0141 - gender_output_acc: 0.9969 - image_quality_output_acc: 0.9964 - age_output_acc: 0.9948 - weight_output_acc: 0.9955 - bag_output_acc: 0.9954 - footwear_output_acc: 0.9956 - pose_output_acc: 0.9949 - emotion_output_acc: 0.9968 - val_loss: 8.0678 - val_gender_output_loss: 0.1529 - val_image_quality_output_loss: 0.3862 - val_age_output_loss: 0.5286 - val_weight_output_loss: 0.3374 - val_bag_output_loss: 0.2899 - val_footwear_output_loss: 0.3262 - val_pose_output_loss: 0.1808 - val_emotion_output_loss: 0.3564 - val_gender_output_acc: 0.9608 - val_image_quality_output_acc: 0.9097 - val_age_output_acc: 0.8844 - val_weight_output_acc: 0.9286 - val_bag_output_acc: 0.9276 - val_footwear_output_acc: 0.9246 - val_pose_output_acc: 0.9519 - val_emotion_output_acc: 0.9311
# Epoch 17/30
# 360/360 [==============================] - 81s 224ms/step - loss: 5.6081 - gender_output_loss: 0.0128 - image_quality_output_loss: 0.0144 - age_output_loss: 0.0214 - weight_output_loss: 0.0141 - bag_output_loss: 0.0150 - footwear_output_loss: 0.0144 - pose_output_loss: 0.0150 - emotion_output_loss: 0.0112 - gender_output_acc: 0.9972 - image_quality_output_acc: 0.9968 - age_output_acc: 0.9951 - weight_output_acc: 0.9966 - bag_output_acc: 0.9960 - footwear_output_acc: 0.9970 - pose_output_acc: 0.9962 - emotion_output_acc: 0.9977 - val_loss: 8.0410 - val_gender_output_loss: 0.1530 - val_image_quality_output_loss: 0.3956 - val_age_output_loss: 0.5429 - val_weight_output_loss: 0.3422 - val_bag_output_loss: 0.2881 - val_footwear_output_loss: 0.3253 - val_pose_output_loss: 0.1745 - val_emotion_output_loss: 0.3495 - val_gender_output_acc: 0.9568 - val_image_quality_output_acc: 0.9117 - val_age_output_acc: 0.8814 - val_weight_output_acc: 0.9246 - val_bag_output_acc: 0.9291 - val_footwear_output_acc: 0.9301 - val_pose_output_acc: 0.9509 - val_emotion_output_acc: 0.9350
# Epoch 17/30
# Epoch 18/30
# 359/360 [============================>.] - ETA: 0s - loss: 5.5684 - gender_output_loss: 0.0131 - image_quality_output_loss: 0.0152 - age_output_loss: 0.0205 - weight_output_loss: 0.0139 - bag_output_loss: 0.0163 - footwear_output_loss: 0.0129 - pose_output_loss: 0.0143 - emotion_output_loss: 0.0114 - gender_output_acc: 0.9964 - image_quality_output_acc: 0.9963 - age_output_acc: 0.9951 - weight_output_acc: 0.9968 - bag_output_acc: 0.9954 - footwear_output_acc: 0.9973 - pose_output_acc: 0.9962 - emotion_output_acc: 0.9977Epoch 18/30
# 360/360 [==============================] - 81s 225ms/step - loss: 5.5681 - gender_output_loss: 0.0131 - image_quality_output_loss: 0.0152 - age_output_loss: 0.0204 - weight_output_loss: 0.0139 - bag_output_loss: 0.0163 - footwear_output_loss: 0.0129 - pose_output_loss: 0.0143 - emotion_output_loss: 0.0114 - gender_output_acc: 0.9964 - image_quality_output_acc: 0.9964 - age_output_acc: 0.9951 - weight_output_acc: 0.9968 - bag_output_acc: 0.9954 - footwear_output_acc: 0.9973 - pose_output_acc: 0.9962 - emotion_output_acc: 0.9977 - val_loss: 8.0000 - val_gender_output_loss: 0.1454 - val_image_quality_output_loss: 0.3863 - val_age_output_loss: 0.5372 - val_weight_output_loss: 0.3436 - val_bag_output_loss: 0.2946 - val_footwear_output_loss: 0.3287 - val_pose_output_loss: 0.1852 - val_emotion_output_loss: 0.3479 - val_gender_output_acc: 0.9623 - val_image_quality_output_acc: 0.9117 - val_age_output_acc: 0.8805 - val_weight_output_acc: 0.9201 - val_bag_output_acc: 0.9276 - val_footwear_output_acc: 0.9311 - val_pose_output_acc: 0.9524 - val_emotion_output_acc: 0.9330
# Epoch 19/30
# 360/360 [==============================] - 80s 222ms/step - loss: 5.5174 - gender_output_loss: 0.0104 - image_quality_output_loss: 0.0138 - age_output_loss: 0.0173 - weight_output_loss: 0.0129 - bag_output_loss: 0.0121 - footwear_output_loss: 0.0144 - pose_output_loss: 0.0127 - emotion_output_loss: 0.0121 - gender_output_acc: 0.9977 - image_quality_output_acc: 0.9966 - age_output_acc: 0.9960 - weight_output_acc: 0.9965 - bag_output_acc: 0.9970 - footwear_output_acc: 0.9961 - pose_output_acc: 0.9966 - emotion_output_acc: 0.9976 - val_loss: 7.9674 - val_gender_output_loss: 0.1515 - val_image_quality_output_loss: 0.3849 - val_age_output_loss: 0.5377 - val_weight_output_loss: 0.3533 - val_bag_output_loss: 0.2976 - val_footwear_output_loss: 0.3332 - val_pose_output_loss: 0.1696 - val_emotion_output_loss: 0.3473 - val_gender_output_acc: 0.9593 - val_image_quality_output_acc: 0.9147 - val_age_output_acc: 0.8824 - val_weight_output_acc: 0.9206 - val_bag_output_acc: 0.9271 - val_footwear_output_acc: 0.9325 - val_pose_output_acc: 0.9573 - val_emotion_output_acc: 0.9365
# Epoch 19/30
# Epoch 20/30
# 360/360 [==============================] - 80s 223ms/step - loss: 5.4697 - gender_output_loss: 0.0086 - image_quality_output_loss: 0.0138 - age_output_loss: 0.0154 - weight_output_loss: 0.0135 - bag_output_loss: 0.0137 - footwear_output_loss: 0.0113 - pose_output_loss: 0.0123 - emotion_output_loss: 0.0081 - gender_output_acc: 0.9982 - image_quality_output_acc: 0.9968 - age_output_acc: 0.9966 - weight_output_acc: 0.9965 - bag_output_acc: 0.9963 - footwear_output_acc: 0.9977 - pose_output_acc: 0.9973 - emotion_output_acc: 0.9985 - val_loss: 7.9128 - val_gender_output_loss: 0.1517 - val_image_quality_output_loss: 0.3911 - val_age_output_loss: 0.5172 - val_weight_output_loss: 0.3474 - val_bag_output_loss: 0.2969 - val_footwear_output_loss: 0.3287 - val_pose_output_loss: 0.1702 - val_emotion_output_loss: 0.3560 - val_gender_output_acc: 0.9603 - val_image_quality_output_acc: 0.9102 - val_age_output_acc: 0.8824 - val_weight_output_acc: 0.9201 - val_bag_output_acc: 0.9261 - val_footwear_output_acc: 0.9296 - val_pose_output_acc: 0.9593 - val_emotion_output_acc: 0.9311
# Epoch 20/30
# Epoch 21/30
# 360/360 [==============================] - 80s 221ms/step - loss: 5.4416 - gender_output_loss: 0.0116 - image_quality_output_loss: 0.0138 - age_output_loss: 0.0170 - weight_output_loss: 0.0106 - bag_output_loss: 0.0145 - footwear_output_loss: 0.0114 - pose_output_loss: 0.0168 - emotion_output_loss: 0.0113 - gender_output_acc: 0.9969 - image_quality_output_acc: 0.9968 - age_output_acc: 0.9959 - weight_output_acc: 0.9977 - bag_output_acc: 0.9962 - footwear_output_acc: 0.9972 - pose_output_acc: 0.9954 - emotion_output_acc: 0.9969 - val_loss: 7.9598 - val_gender_output_loss: 0.1630 - val_image_quality_output_loss: 0.4086 - val_age_output_loss: 0.5502 - val_weight_output_loss: 0.3495 - val_bag_output_loss: 0.2981 - val_footwear_output_loss: 0.3379 - val_pose_output_loss: 0.1690 - val_emotion_output_loss: 0.3679 - val_gender_output_acc: 0.9563 - val_image_quality_output_acc: 0.9102 - val_age_output_acc: 0.8810 - val_weight_output_acc: 0.9236 - val_bag_output_acc: 0.9311 - val_footwear_output_acc: 0.9301 - val_pose_output_acc: 0.9578 - val_emotion_output_acc: 0.9306
# Epoch 22/30
# 359/360 [============================>.] - ETA: 0s - loss: 5.3931 - gender_output_loss: 0.0086 - image_quality_output_loss: 0.0118 - age_output_loss: 0.0150 - weight_output_loss: 0.0126 - bag_output_loss: 0.0128 - footwear_output_loss: 0.0112 - pose_output_loss: 0.0145 - emotion_output_loss: 0.0098 - gender_output_acc: 0.9980 - image_quality_output_acc: 0.9966 - age_output_acc: 0.9963 - weight_output_acc: 0.9967 - bag_output_acc: 0.9971 - footwear_output_acc: 0.9968 - pose_output_acc: 0.9960 - emotion_output_acc: 0.9973Epoch 22/30
# 360/360 [==============================] - 80s 223ms/step - loss: 5.3932 - gender_output_loss: 0.0088 - image_quality_output_loss: 0.0118 - age_output_loss: 0.0150 - weight_output_loss: 0.0127 - bag_output_loss: 0.0128 - footwear_output_loss: 0.0112 - pose_output_loss: 0.0145 - emotion_output_loss: 0.0098 - gender_output_acc: 0.9979 - image_quality_output_acc: 0.9966 - age_output_acc: 0.9964 - weight_output_acc: 0.9966 - bag_output_acc: 0.9971 - footwear_output_acc: 0.9968 - pose_output_acc: 0.9960 - emotion_output_acc: 0.9973 - val_loss: 7.8726 - val_gender_output_loss: 0.1489 - val_image_quality_output_loss: 0.3999 - val_age_output_loss: 0.5549 - val_weight_output_loss: 0.3500 - val_bag_output_loss: 0.2908 - val_footwear_output_loss: 0.3259 - val_pose_output_loss: 0.1717 - val_emotion_output_loss: 0.3529 - val_gender_output_acc: 0.9603 - val_image_quality_output_acc: 0.9147 - val_age_output_acc: 0.8834 - val_weight_output_acc: 0.9281 - val_bag_output_acc: 0.9286 - val_footwear_output_acc: 0.9306 - val_pose_output_acc: 0.9544 - val_emotion_output_acc: 0.9340
# Epoch 23/30
# 360/360 [==============================] - 80s 223ms/step - loss: 5.3505 - gender_output_loss: 0.0079 - image_quality_output_loss: 0.0146 - age_output_loss: 0.0137 - weight_output_loss: 0.0106 - bag_output_loss: 0.0124 - footwear_output_loss: 0.0109 - pose_output_loss: 0.0125 - emotion_output_loss: 0.0092 - gender_output_acc: 0.9981 - image_quality_output_acc: 0.9951 - age_output_acc: 0.9969 - weight_output_acc: 0.9975 - bag_output_acc: 0.9967 - footwear_output_acc: 0.9978 - pose_output_acc: 0.9964 - emotion_output_acc: 0.9977 - val_loss: 7.8544 - val_gender_output_loss: 0.1514 - val_image_quality_output_loss: 0.3977 - val_age_output_loss: 0.5380 - val_weight_output_loss: 0.3423 - val_bag_output_loss: 0.3051 - val_footwear_output_loss: 0.3334 - val_pose_output_loss: 0.1891 - val_emotion_output_loss: 0.3575 - val_gender_output_acc: 0.9598 - val_image_quality_output_acc: 0.9117 - val_age_output_acc: 0.8889 - val_weight_output_acc: 0.9261 - val_bag_output_acc: 0.9236 - val_footwear_output_acc: 0.9281 - val_pose_output_acc: 0.9509 - val_emotion_output_acc: 0.9330
# Epoch 24/30
# 360/360 [==============================] - 81s 224ms/step - loss: 5.3107 - gender_output_loss: 0.0104 - image_quality_output_loss: 0.0111 - age_output_loss: 0.0128 - weight_output_loss: 0.0113 - bag_output_loss: 0.0119 - footwear_output_loss: 0.0118 - pose_output_loss: 0.0123 - emotion_output_loss: 0.0078 - gender_output_acc: 0.9972 - image_quality_output_acc: 0.9976 - age_output_acc: 0.9966 - weight_output_acc: 0.9970 - bag_output_acc: 0.9970 - footwear_output_acc: 0.9970 - pose_output_acc: 0.9972 - emotion_output_acc: 0.9984 - val_loss: 7.7966 - val_gender_output_loss: 0.1519 - val_image_quality_output_loss: 0.3992 - val_age_output_loss: 0.5382 - val_weight_output_loss: 0.3676 - val_bag_output_loss: 0.2929 - val_footwear_output_loss: 0.3237 - val_pose_output_loss: 0.1719 - val_emotion_output_loss: 0.3486 - val_gender_output_acc: 0.9603 - val_image_quality_output_acc: 0.9087 - val_age_output_acc: 0.8884 - val_weight_output_acc: 0.9266 - val_bag_output_acc: 0.9276 - val_footwear_output_acc: 0.9266 - val_pose_output_acc: 0.9544 - val_emotion_output_acc: 0.9355
# Epoch 25/30Epoch 24/30
#
# 360/360 [==============================] - 82s 228ms/step - loss: 5.2820 - gender_output_loss: 0.0101 - image_quality_output_loss: 0.0124 - age_output_loss: 0.0140 - weight_output_loss: 0.0120 - bag_output_loss: 0.0127 - footwear_output_loss: 0.0115 - pose_output_loss: 0.0145 - emotion_output_loss: 0.0108 - gender_output_acc: 0.9975 - image_quality_output_acc: 0.9967 - age_output_acc: 0.9966 - weight_output_acc: 0.9968 - bag_output_acc: 0.9961 - footwear_output_acc: 0.9972 - pose_output_acc: 0.9956 - emotion_output_acc: 0.9969 - val_loss: 7.8347 - val_gender_output_loss: 0.1531 - val_image_quality_output_loss: 0.3915 - val_age_output_loss: 0.5519 - val_weight_output_loss: 0.3729 - val_bag_output_loss: 0.3049 - val_footwear_output_loss: 0.3446 - val_pose_output_loss: 0.1805 - val_emotion_output_loss: 0.3697 - val_gender_output_acc: 0.9598 - val_image_quality_output_acc: 0.9117 - val_age_output_acc: 0.8844 - val_weight_output_acc: 0.9172 - val_bag_output_acc: 0.9281 - val_footwear_output_acc: 0.9301 - val_pose_output_acc: 0.9544 - val_emotion_output_acc: 0.9330
# Epoch 26/30
#
# 360/360 [==============================] - 81s 225ms/step - loss: 5.2308 - gender_output_loss: 0.0091 - image_quality_output_loss: 0.0094 - age_output_loss: 0.0144 - weight_output_loss: 0.0109 - bag_output_loss: 0.0098 - footwear_output_loss: 0.0094 - pose_output_loss: 0.0123 - emotion_output_loss: 0.0085 - gender_output_acc: 0.9975 - image_quality_output_acc: 0.9978 - age_output_acc: 0.9963 - weight_output_acc: 0.9972 - bag_output_acc: 0.9974 - footwear_output_acc: 0.9976 - pose_output_acc: 0.9964 - emotion_output_acc: 0.9979 - val_loss: 7.8205 - val_gender_output_loss: 0.1589 - val_image_quality_output_loss: 0.4184 - val_age_output_loss: 0.5563 - val_weight_output_loss: 0.3653 - val_bag_output_loss: 0.3086 - val_footwear_output_loss: 0.3357 - val_pose_output_loss: 0.1710 - val_emotion_output_loss: 0.3774 - val_gender_output_acc: 0.9563 - val_image_quality_output_acc: 0.9097 - val_age_output_acc: 0.8805 - val_weight_output_acc: 0.9216 - val_bag_output_acc: 0.9261 - val_footwear_output_acc: 0.9296 - val_pose_output_acc: 0.9549 - val_emotion_output_acc: 0.9286
# Epoch 27/30
# 360/360 [==============================] - 81s 225ms/step - loss: 5.1901 - gender_output_loss: 0.0085 - image_quality_output_loss: 0.0103 - age_output_loss: 0.0104 - weight_output_loss: 0.0108 - bag_output_loss: 0.0090 - footwear_output_loss: 0.0089 - pose_output_loss: 0.0136 - emotion_output_loss: 0.0083 - gender_output_acc: 0.9978 - image_quality_output_acc: 0.9970 - age_output_acc: 0.9979 - weight_output_acc: 0.9970 - bag_output_acc: 0.9977 - footwear_output_acc: 0.9981 - pose_output_acc: 0.9958 - emotion_output_acc: 0.9979 - val_loss: 7.7425 - val_gender_output_loss: 0.1555 - val_image_quality_output_loss: 0.3979 - val_age_output_loss: 0.5537 - val_weight_output_loss: 0.3622 - val_bag_output_loss: 0.3004 - val_footwear_output_loss: 0.3380 - val_pose_output_loss: 0.1849 - val_emotion_output_loss: 0.3578 - val_gender_output_acc: 0.9554 - val_image_quality_output_acc: 0.9097 - val_age_output_acc: 0.8874 - val_weight_output_acc: 0.9231 - val_bag_output_acc: 0.9291 - val_footwear_output_acc: 0.9301 - val_pose_output_acc: 0.9529 - val_emotion_output_acc: 0.9296
# Epoch 28/30
# 360/360 [==============================] - 83s 231ms/step - loss: 5.1564 - gender_output_loss: 0.0083 - image_quality_output_loss: 0.0119 - age_output_loss: 0.0120 - weight_output_loss: 0.0103 - bag_output_loss: 0.0101 - footwear_output_loss: 0.0098 - pose_output_loss: 0.0120 - emotion_output_loss: 0.0080 - gender_output_acc: 0.9978 - image_quality_output_acc: 0.9967 - age_output_acc: 0.9969 - weight_output_acc: 0.9971 - bag_output_acc: 0.9977 - footwear_output_acc: 0.9976 - pose_output_acc: 0.9966 - emotion_output_acc: 0.9978 - val_loss: 7.7250 - val_gender_output_loss: 0.1455 - val_image_quality_output_loss: 0.4132 - val_age_output_loss: 0.5534 - val_weight_output_loss: 0.3530 - val_bag_output_loss: 0.3115 - val_footwear_output_loss: 0.3396 - val_pose_output_loss: 0.1876 - val_emotion_output_loss: 0.3654 - val_gender_output_acc: 0.9608 - val_image_quality_output_acc: 0.9107 - val_age_output_acc: 0.8839 - val_weight_output_acc: 0.9216 - val_bag_output_acc: 0.9281 - val_footwear_output_acc: 0.9271 - val_pose_output_acc: 0.9504 - val_emotion_output_acc: 0.9365
# Epoch 29/30
# 360/360 [==============================] - 81s 224ms/step - loss: 5.1155 - gender_output_loss: 0.0098 - image_quality_output_loss: 0.0084 - age_output_loss: 0.0126 - weight_output_loss: 0.0098 - bag_output_loss: 0.0107 - footwear_output_loss: 0.0088 - pose_output_loss: 0.0107 - emotion_output_loss: 0.0070 - gender_output_acc: 0.9969 - image_quality_output_acc: 0.9980 - age_output_acc: 0.9974 - weight_output_acc: 0.9973 - bag_output_acc: 0.9974 - footwear_output_acc: 0.9976 - pose_output_acc: 0.9968 - emotion_output_acc: 0.9989 - val_loss: 7.7032 - val_gender_output_loss: 0.1605 - val_image_quality_output_loss: 0.4129 - val_age_output_loss: 0.5623 - val_weight_output_loss: 0.3657 - val_bag_output_loss: 0.3063 - val_footwear_output_loss: 0.3351 - val_pose_output_loss: 0.1782 - val_emotion_output_loss: 0.3624 - val_gender_output_acc: 0.9563 - val_image_quality_output_acc: 0.9102 - val_age_output_acc: 0.8829 - val_weight_output_acc: 0.9241 - val_bag_output_acc: 0.9276 - val_footwear_output_acc: 0.9306 - val_pose_output_acc: 0.9554 - val_emotion_output_acc: 0.9286
# Epoch 30/30
# 360/360 [==============================] - 81s 224ms/step - loss: 5.0815 - gender_output_loss: 0.0087 - image_quality_output_loss: 0.0087 - age_output_loss: 0.0150 - weight_output_loss: 0.0100 - bag_output_loss: 0.0093 - footwear_output_loss: 0.0092 - pose_output_loss: 0.0103 - emotion_output_loss: 0.0085 - gender_output_acc: 0.9974 - image_quality_output_acc: 0.9978 - age_output_acc: 0.9961 - weight_output_acc: 0.9973 - bag_output_acc: 0.9977 - footwear_output_acc: 0.9975 - pose_output_acc: 0.9972 - emotion_output_acc: 0.9976 - val_loss: 7.6550 - val_gender_output_loss: 0.1628 - val_image_quality_output_loss: 0.4088 - val_age_output_loss: 0.5532 - val_weight_output_loss: 0.3427 - val_bag_output_loss: 0.3094 - val_footwear_output_loss: 0.3398 - val_pose_output_loss: 0.1820 - val_emotion_output_loss: 0.3722 - val_gender_output_acc: 0.9559 - val_image_quality_output_acc: 0.9122 - val_age_output_acc: 0.8810 - val_weight_output_acc: 0.9281 - val_bag_output_acc: 0.9281 - val_footwear_output_acc: 0.9246 - val_pose_output_acc: 0.9549 - val_emotion_output_acc: 0.9335

# %%
from keras.models import load_model

model2.load_weights('test_curr_3.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.01, momentum = 0.009),loss_weights=lossWeights,
              metrics=['accuracy'])

results = model2.evaluate(valid_gen)
print(dict(zip(model2.metrics_names,results)))
# Out:
# 63/63 [==============================] - 9s 149ms/step
# {'loss': 7.637236595153809, 'gender_output_loss': 0.15459064949703002, 'image_quality_output_loss': 0.4040761701762676, 'age_output_loss': 0.5587317375318398, 'weight_output_loss': 0.3522960921557295, 'bag_output_loss': 0.3101986877450217, 'footwear_output_loss': 0.33766952922774685, 'pose_output_loss': 0.17122954716684208, 'emotion_output_loss': 0.3644447237593196, 'gender_output_acc': 0.9588293650793651, 'image_quality_output_acc': 0.9122023809523809, 'age_output_acc': 0.8844246031746031, 'weight_output_acc': 0.9241071428571429, 'bag_output_acc': 0.9236111111111112, 'footwear_output_acc': 0.9270833333333334, 'pose_output_acc': 0.9563492063492064, 'emotion_output_acc': 0.9305555555555556}

# %%
ckpt_callback = ModelCheckpoint(filepath='test_curr_3.h5', monitor='val_loss',save_best_only=True , save_weights_only=True, mode='auto',period=10)
lr_manager = OneCycleLR(samples=train_df.shape[0], epochs=10, batch_size=16,
                    steps=16, max_lr=0.0125,
                    end_percentage=0.1, scale_percentage=None,
                    maximum_momentum=None, minimum_momentum=None)

model2.load_weights('test_curr_2.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.0005, momentum = 0.0000009),loss_weights=lossWeights,
              metrics=['accuracy'])


model2.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=30,
    verbose=1,callbacks=[ckpt_callback]
   # preprocessing_function=get_random_eraser(v_l=0, v_h=16),
)
# Out:
# Epoch 1/30
# 359/360 [============================>.] - ETA: 0s - loss: 6.7180 - gender_output_loss: 0.0459 - image_quality_output_loss: 0.0767 - age_output_loss: 0.1052 - weight_output_loss: 0.0778 - bag_output_loss: 0.0725 - footwear_output_loss: 0.0703 - pose_output_loss: 0.0556 - emotion_output_loss: 0.0607 - gender_output_acc: 0.9851 - image_quality_output_acc: 0.9756 - age_output_acc: 0.9668 - weight_output_acc: 0.9749 - bag_output_acc: 0.9771 - footwear_output_acc: 0.9794 - pose_output_acc: 0.9823 - emotion_output_acc: 0.9825
# 360/360 [==============================] - 94s 261ms/step - loss: 6.7170 - gender_output_loss: 0.0459 - image_quality_output_loss: 0.0766 - age_output_loss: 0.1050 - weight_output_loss: 0.0776 - bag_output_loss: 0.0724 - footwear_output_loss: 0.0702 - pose_output_loss: 0.0555 - emotion_output_loss: 0.0606 - gender_output_acc: 0.9852 - image_quality_output_acc: 0.9757 - age_output_acc: 0.9669 - weight_output_acc: 0.9750 - bag_output_acc: 0.9772 - footwear_output_acc: 0.9794 - pose_output_acc: 0.9824 - emotion_output_acc: 0.9826 - val_loss: 18.9771 - val_gender_output_loss: 0.7505 - val_image_quality_output_loss: 1.7450 - val_age_output_loss: 2.5951 - val_weight_output_loss: 1.8499 - val_bag_output_loss: 1.5528 - val_footwear_output_loss: 1.6431 - val_pose_output_loss: 0.8563 - val_emotion_output_loss: 1.8531 - val_gender_output_acc: 0.7753 - val_image_quality_output_acc: 0.4985 - val_age_output_acc: 0.3522 - val_weight_output_acc: 0.5625 - val_bag_output_acc: 0.5799 - val_footwear_output_acc: 0.5947 - val_pose_output_acc: 0.7361 - val_emotion_output_acc: 0.6463
# Epoch 2/30
#
# 360/360 [==============================] - 82s 227ms/step - loss: 6.4345 - gender_output_loss: 0.0291 - image_quality_output_loss: 0.0461 - age_output_loss: 0.0585 - weight_output_loss: 0.0428 - bag_output_loss: 0.0420 - footwear_output_loss: 0.0426 - pose_output_loss: 0.0322 - emotion_output_loss: 0.0317 - gender_output_acc: 0.9924 - image_quality_output_acc: 0.9860 - age_output_acc: 0.9860 - weight_output_acc: 0.9889 - bag_output_acc: 0.9885 - footwear_output_acc: 0.9891 - pose_output_acc: 0.9927 - emotion_output_acc: 0.9919 - val_loss: 19.0543 - val_gender_output_loss: 0.7643 - val_image_quality_output_loss: 1.7766 - val_age_output_loss: 2.5971 - val_weight_output_loss: 1.8793 - val_bag_output_loss: 1.6179 - val_footwear_output_loss: 1.6059 - val_pose_output_loss: 0.8771 - val_emotion_output_loss: 1.8484 - val_gender_output_acc: 0.7753 - val_image_quality_output_acc: 0.4990 - val_age_output_acc: 0.3547 - val_weight_output_acc: 0.5739 - val_bag_output_acc: 0.5913 - val_footwear_output_acc: 0.5843 - val_pose_output_acc: 0.7326 - val_emotion_output_acc: 0.6438
# Epoch 3/30
# 360/360 [==============================] - 81s 225ms/step - loss: 6.3043 - gender_output_loss: 0.0245 - image_quality_output_loss: 0.0326 - age_output_loss: 0.0418 - weight_output_loss: 0.0292 - bag_output_loss: 0.0318 - footwear_output_loss: 0.0290 - pose_output_loss: 0.0261 - emotion_output_loss: 0.0234 - gender_output_acc: 0.9941 - image_quality_output_acc: 0.9930 - age_output_acc: 0.9897 - weight_output_acc: 0.9936 - bag_output_acc: 0.9924 - footwear_output_acc: 0.9929 - pose_output_acc: 0.9932 - emotion_output_acc: 0.9951 - val_loss: 19.2225 - val_gender_output_loss: 0.7626 - val_image_quality_output_loss: 1.8143 - val_age_output_loss: 2.6234 - val_weight_output_loss: 1.9219 - val_bag_output_loss: 1.6423 - val_footwear_output_loss: 1.5983 - val_pose_output_loss: 0.8857 - val_emotion_output_loss: 1.9300 - val_gender_output_acc: 0.7763 - val_image_quality_output_acc: 0.5035 - val_age_output_acc: 0.3547 - val_weight_output_acc: 0.5818 - val_bag_output_acc: 0.5774 - val_footwear_output_acc: 0.5903 - val_pose_output_acc: 0.7455 - val_emotion_output_acc: 0.6478
# Epoch 4/30
# 360/360 [==============================] - 81s 226ms/step - loss: 6.2022 - gender_output_loss: 0.0202 - image_quality_output_loss: 0.0244 - age_output_loss: 0.0321 - weight_output_loss: 0.0228 - bag_output_loss: 0.0213 - footwear_output_loss: 0.0224 - pose_output_loss: 0.0192 - emotion_output_loss: 0.0172 - gender_output_acc: 0.9951 - image_quality_output_acc: 0.9941 - age_output_acc: 0.9933 - weight_output_acc: 0.9953 - bag_output_acc: 0.9961 - footwear_output_acc: 0.9960 - pose_output_acc: 0.9958 - emotion_output_acc: 0.9969 - val_loss: 19.5230 - val_gender_output_loss: 0.7648 - val_image_quality_output_loss: 1.9269 - val_age_output_loss: 2.6820 - val_weight_output_loss: 1.9559 - val_bag_output_loss: 1.6982 - val_footwear_output_loss: 1.6542 - val_pose_output_loss: 0.9131 - val_emotion_output_loss: 1.9269 - val_gender_output_acc: 0.7753 - val_image_quality_output_acc: 0.5035 - val_age_output_acc: 0.3467 - val_weight_output_acc: 0.5605 - val_bag_output_acc: 0.5873 - val_footwear_output_acc: 0.5952 - val_pose_output_acc: 0.7450 - val_emotion_output_acc: 0.6329
# Epoch 5/30
# 360/360 [==============================] - 82s 227ms/step - loss: 6.1532 - gender_output_loss: 0.0192 - image_quality_output_loss: 0.0222 - age_output_loss: 0.0291 - weight_output_loss: 0.0195 - bag_output_loss: 0.0229 - footwear_output_loss: 0.0213 - pose_output_loss: 0.0217 - emotion_output_loss: 0.0177 - gender_output_acc: 0.9951 - image_quality_output_acc: 0.9957 - age_output_acc: 0.9939 - weight_output_acc: 0.9951 - bag_output_acc: 0.9938 - footwear_output_acc: 0.9953 - pose_output_acc: 0.9946 - emotion_output_acc: 0.9959 - val_loss: 19.5998 - val_gender_output_loss: 0.7895 - val_image_quality_output_loss: 1.9026 - val_age_output_loss: 2.6691 - val_weight_output_loss: 1.9975 - val_bag_output_loss: 1.7181 - val_footwear_output_loss: 1.6620 - val_pose_output_loss: 0.9214 - val_emotion_output_loss: 1.9815 - val_gender_output_acc: 0.7684 - val_image_quality_output_acc: 0.5119 - val_age_output_acc: 0.3457 - val_weight_output_acc: 0.5749 - val_bag_output_acc: 0.5898 - val_footwear_output_acc: 0.6002 - val_pose_output_acc: 0.7440 - val_emotion_output_acc: 0.6508
# Epoch 6/30
# 360/360 [==============================] - 82s 226ms/step - loss: 6.0870 - gender_output_loss: 0.0139 - image_quality_output_loss: 0.0200 - age_output_loss: 0.0265 - weight_output_loss: 0.0176 - bag_output_loss: 0.0195 - footwear_output_loss: 0.0184 - pose_output_loss: 0.0184 - emotion_output_loss: 0.0160 - gender_output_acc: 0.9974 - image_quality_output_acc: 0.9951 - age_output_acc: 0.9940 - weight_output_acc: 0.9958 - bag_output_acc: 0.9959 - footwear_output_acc: 0.9957 - pose_output_acc: 0.9959 - emotion_output_acc: 0.9967 - val_loss: 19.7862 - val_gender_output_loss: 0.7882 - val_image_quality_output_loss: 1.9383 - val_age_output_loss: 2.7148 - val_weight_output_loss: 2.0390 - val_bag_output_loss: 1.7747 - val_footwear_output_loss: 1.6807 - val_pose_output_loss: 0.9242 - val_emotion_output_loss: 2.0110 - val_gender_output_acc: 0.7758 - val_image_quality_output_acc: 0.5074 - val_age_output_acc: 0.3442 - val_weight_output_acc: 0.5650 - val_bag_output_acc: 0.5848 - val_footwear_output_acc: 0.5928 - val_pose_output_acc: 0.7406 - val_emotion_output_acc: 0.6463
# Epoch 7/30
# 360/360 [==============================] - 81s 225ms/step - loss: 6.0324 - gender_output_loss: 0.0149 - image_quality_output_loss: 0.0189 - age_output_loss: 0.0221 - weight_output_loss: 0.0157 - bag_output_loss: 0.0161 - footwear_output_loss: 0.0178 - pose_output_loss: 0.0176 - emotion_output_loss: 0.0151 - gender_output_acc: 0.9966 - image_quality_output_acc: 0.9962 - age_output_acc: 0.9956 - weight_output_acc: 0.9967 - bag_output_acc: 0.9961 - footwear_output_acc: 0.9957 - pose_output_acc: 0.9951 - emotion_output_acc: 0.9962 - val_loss: 19.6984 - val_gender_output_loss: 0.7772 - val_image_quality_output_loss: 1.9332 - val_age_output_loss: 2.7258 - val_weight_output_loss: 2.0277 - val_bag_output_loss: 1.7457 - val_footwear_output_loss: 1.6901 - val_pose_output_loss: 0.9357 - val_emotion_output_loss: 1.9899 - val_gender_output_acc: 0.7788 - val_image_quality_output_acc: 0.4955 - val_age_output_acc: 0.3408 - val_weight_output_acc: 0.5675 - val_bag_output_acc: 0.5898 - val_footwear_output_acc: 0.5923 - val_pose_output_acc: 0.7421 - val_emotion_output_acc: 0.6468
# Epoch 8/30
# Epoch 7/30
# 360/360 [==============================] - 81s 226ms/step - loss: 5.9821 - gender_output_loss: 0.0140 - image_quality_output_loss: 0.0169 - age_output_loss: 0.0192 - weight_output_loss: 0.0154 - bag_output_loss: 0.0155 - footwear_output_loss: 0.0158 - pose_output_loss: 0.0181 - emotion_output_loss: 0.0152 - gender_output_acc: 0.9965 - image_quality_output_acc: 0.9964 - age_output_acc: 0.9952 - weight_output_acc: 0.9960 - bag_output_acc: 0.9964 - footwear_output_acc: 0.9964 - pose_output_acc: 0.9953 - emotion_output_acc: 0.9967 - val_loss: 19.9373 - val_gender_output_loss: 0.8130 - val_image_quality_output_loss: 2.0272 - val_age_output_loss: 2.8019 - val_weight_output_loss: 2.0212 - val_bag_output_loss: 1.7742 - val_footwear_output_loss: 1.7381 - val_pose_output_loss: 0.9536 - val_emotion_output_loss: 1.9770 - val_gender_output_acc: 0.7708 - val_image_quality_output_acc: 0.5060 - val_age_output_acc: 0.3517 - val_weight_output_acc: 0.5804 - val_bag_output_acc: 0.5863 - val_footwear_output_acc: 0.5809 - val_pose_output_acc: 0.7440 - val_emotion_output_acc: 0.6463
# Epoch 9/30
# 360/360 [==============================] - 81s 226ms/step - loss: 5.9235 - gender_output_loss: 0.0133 - image_quality_output_loss: 0.0142 - age_output_loss: 0.0195 - weight_output_loss: 0.0121 - bag_output_loss: 0.0146 - footwear_output_loss: 0.0157 - pose_output_loss: 0.0142 - emotion_output_loss: 0.0097 - gender_output_acc: 0.9965 - image_quality_output_acc: 0.9968 - age_output_acc: 0.9951 - weight_output_acc: 0.9980 - bag_output_acc: 0.9964 - footwear_output_acc: 0.9959 - pose_output_acc: 0.9962 - emotion_output_acc: 0.9983 - val_loss: 20.0137 - val_gender_output_loss: 0.8084 - val_image_quality_output_loss: 2.0675 - val_age_output_loss: 2.7934 - val_weight_output_loss: 2.0493 - val_bag_output_loss: 1.7966 - val_footwear_output_loss: 1.7436 - val_pose_output_loss: 0.9309 - val_emotion_output_loss: 2.0346 - val_gender_output_acc: 0.7773 - val_image_quality_output_acc: 0.5124 - val_age_output_acc: 0.3403 - val_weight_output_acc: 0.5635 - val_bag_output_acc: 0.5734 - val_footwear_output_acc: 0.5923 - val_pose_output_acc: 0.7470 - val_emotion_output_acc: 0.6488
# Epoch 10/30
# Epoch 9/30
# 360/360 [==============================] - 81s 226ms/step - loss: 5.8856 - gender_output_loss: 0.0140 - image_quality_output_loss: 0.0161 - age_output_loss: 0.0183 - weight_output_loss: 0.0127 - bag_output_loss: 0.0138 - footwear_output_loss: 0.0155 - pose_output_loss: 0.0158 - emotion_output_loss: 0.0105 - gender_output_acc: 0.9963 - image_quality_output_acc: 0.9964 - age_output_acc: 0.9961 - weight_output_acc: 0.9970 - bag_output_acc: 0.9970 - footwear_output_acc: 0.9961 - pose_output_acc: 0.9957 - emotion_output_acc: 0.9978 - val_loss: 20.0786 - val_gender_output_loss: 0.8004 - val_image_quality_output_loss: 2.0523 - val_age_output_loss: 2.8601 - val_weight_output_loss: 2.0856 - val_bag_output_loss: 1.8156 - val_footwear_output_loss: 1.7170 - val_pose_output_loss: 0.9674 - val_emotion_output_loss: 2.0323 - val_gender_output_acc: 0.7783 - val_image_quality_output_acc: 0.5010 - val_age_output_acc: 0.3393 - val_weight_output_acc: 0.5635 - val_bag_output_acc: 0.5833 - val_footwear_output_acc: 0.5898 - val_pose_output_acc: 0.7421 - val_emotion_output_acc: 0.6414
# Epoch 11/30
# 360/360 [==============================] - 80s 223ms/step - loss: 5.8212 - gender_output_loss: 0.0104 - image_quality_output_loss: 0.0130 - age_output_loss: 0.0155 - weight_output_loss: 0.0112 - bag_output_loss: 0.0114 - footwear_output_loss: 0.0122 - pose_output_loss: 0.0103 - emotion_output_loss: 0.0098 - gender_output_acc: 0.9982 - image_quality_output_acc: 0.9971 - age_output_acc: 0.9966 - weight_output_acc: 0.9975 - bag_output_acc: 0.9973 - footwear_output_acc: 0.9972 - pose_output_acc: 0.9975 - emotion_output_acc: 0.9978 - val_loss: 20.0620 - val_gender_output_loss: 0.8256 - val_image_quality_output_loss: 2.0456 - val_age_output_loss: 2.7768 - val_weight_output_loss: 2.0961 - val_bag_output_loss: 1.8284 - val_footwear_output_loss: 1.7529 - val_pose_output_loss: 0.9670 - val_emotion_output_loss: 2.0628 - val_gender_output_acc: 0.7773 - val_image_quality_output_acc: 0.5094 - val_age_output_acc: 0.3502 - val_weight_output_acc: 0.5605 - val_bag_output_acc: 0.5823 - val_footwear_output_acc: 0.5908 - val_pose_output_acc: 0.7401 - val_emotion_output_acc: 0.6498
# Epoch 12/30
# 360/360 [==============================] - 82s 228ms/step - loss: 5.7764 - gender_output_loss: 0.0116 - image_quality_output_loss: 0.0112 - age_output_loss: 0.0133 - weight_output_loss: 0.0113 - bag_output_loss: 0.0103 - footwear_output_loss: 0.0115 - pose_output_loss: 0.0118 - emotion_output_loss: 0.0090 - gender_output_acc: 0.9970 - image_quality_output_acc: 0.9972 - age_output_acc: 0.9973 - weight_output_acc: 0.9976 - bag_output_acc: 0.9977 - footwear_output_acc: 0.9975 - pose_output_acc: 0.9971 - emotion_output_acc: 0.9980 - val_loss: 20.1314 - val_gender_output_loss: 0.8194 - val_image_quality_output_loss: 2.0542 - val_age_output_loss: 2.8603 - val_weight_output_loss: 2.0939 - val_bag_output_loss: 1.7927 - val_footwear_output_loss: 1.7875 - val_pose_output_loss: 0.9589 - val_emotion_output_loss: 2.0983 - val_gender_output_acc: 0.7773 - val_image_quality_output_acc: 0.4995 - val_age_output_acc: 0.3403 - val_weight_output_acc: 0.5759 - val_bag_output_acc: 0.5774 - val_footwear_output_acc: 0.5799 - val_pose_output_acc: 0.7401 - val_emotion_output_acc: 0.6488
# Epoch 13/30
# 360/360 [==============================] - 81s 226ms/step - loss: 5.7323 - gender_output_loss: 0.0082 - image_quality_output_loss: 0.0114 - age_output_loss: 0.0147 - weight_output_loss: 0.0106 - bag_output_loss: 0.0115 - footwear_output_loss: 0.0129 - pose_output_loss: 0.0090 - emotion_output_loss: 0.0082 - gender_output_acc: 0.9981 - image_quality_output_acc: 0.9969 - age_output_acc: 0.9968 - weight_output_acc: 0.9974 - bag_output_acc: 0.9969 - footwear_output_acc: 0.9968 - pose_output_acc: 0.9981 - emotion_output_acc: 0.9983 - val_loss: 20.3708 - val_gender_output_loss: 0.8245 - val_image_quality_output_loss: 2.0534 - val_age_output_loss: 2.9108 - val_weight_output_loss: 2.1383 - val_bag_output_loss: 1.9022 - val_footwear_output_loss: 1.8200 - val_pose_output_loss: 1.0021 - val_emotion_output_loss: 2.0942 - val_gender_output_acc: 0.7827 - val_image_quality_output_acc: 0.5010 - val_age_output_acc: 0.3522 - val_weight_output_acc: 0.5694 - val_bag_output_acc: 0.5813 - val_footwear_output_acc: 0.5813 - val_pose_output_acc: 0.7391 - val_emotion_output_acc: 0.6409
# Epoch 14/30
# Epoch 13/30
# 360/360 [==============================] - 82s 227ms/step - loss: 5.6876 - gender_output_loss: 0.0099 - image_quality_output_loss: 0.0120 - age_output_loss: 0.0125 - weight_output_loss: 0.0100 - bag_output_loss: 0.0104 - footwear_output_loss: 0.0095 - pose_output_loss: 0.0091 - emotion_output_loss: 0.0089 - gender_output_acc: 0.9970 - image_quality_output_acc: 0.9970 - age_output_acc: 0.9971 - weight_output_acc: 0.9974 - bag_output_acc: 0.9977 - footwear_output_acc: 0.9980 - pose_output_acc: 0.9975 - emotion_output_acc: 0.9978 - val_loss: 20.0438 - val_gender_output_loss: 0.8260 - val_image_quality_output_loss: 2.0652 - val_age_output_loss: 2.8201 - val_weight_output_loss: 2.1216 - val_bag_output_loss: 1.8163 - val_footwear_output_loss: 1.7797 - val_pose_output_loss: 0.9567 - val_emotion_output_loss: 2.0729 - val_gender_output_acc: 0.7783 - val_image_quality_output_acc: 0.5045 - val_age_output_acc: 0.3378 - val_weight_output_acc: 0.5749 - val_bag_output_acc: 0.5789 - val_footwear_output_acc: 0.5838 - val_pose_output_acc: 0.7500 - val_emotion_output_acc: 0.6419
# Epoch 15/30
# 360/360 [==============================] - 82s 227ms/step - loss: 5.6416 - gender_output_loss: 0.0081 - image_quality_output_loss: 0.0099 - age_output_loss: 0.0121 - weight_output_loss: 0.0082 - bag_output_loss: 0.0094 - footwear_output_loss: 0.0109 - pose_output_loss: 0.0102 - emotion_output_loss: 0.0075 - gender_output_acc: 0.9979 - image_quality_output_acc: 0.9978 - age_output_acc: 0.9970 - weight_output_acc: 0.9985 - bag_output_acc: 0.9976 - footwear_output_acc: 0.9970 - pose_output_acc: 0.9975 - emotion_output_acc: 0.9985 - val_loss: 20.1246 - val_gender_output_loss: 0.8513 - val_image_quality_output_loss: 2.1107 - val_age_output_loss: 2.8343 - val_weight_output_loss: 2.1475 - val_bag_output_loss: 1.8483 - val_footwear_output_loss: 1.7999 - val_pose_output_loss: 0.9524 - val_emotion_output_loss: 2.0349 - val_gender_output_acc: 0.7788 - val_image_quality_output_acc: 0.5060 - val_age_output_acc: 0.3487 - val_weight_output_acc: 0.5699 - val_bag_output_acc: 0.5809 - val_footwear_output_acc: 0.5903 - val_pose_output_acc: 0.7470 - val_emotion_output_acc: 0.6374
# Epoch 16/30
# 360/360 [==============================] - 82s 227ms/step - loss: 5.6057 - gender_output_loss: 0.0110 - image_quality_output_loss: 0.0096 - age_output_loss: 0.0119 - weight_output_loss: 0.0086 - bag_output_loss: 0.0110 - footwear_output_loss: 0.0101 - pose_output_loss: 0.0104 - emotion_output_loss: 0.0076 - gender_output_acc: 0.9969 - image_quality_output_acc: 0.9977 - age_output_acc: 0.9977 - weight_output_acc: 0.9982 - bag_output_acc: 0.9979 - footwear_output_acc: 0.9971 - pose_output_acc: 0.9968 - emotion_output_acc: 0.9984 - val_loss: 20.3219 - val_gender_output_loss: 0.8527 - val_image_quality_output_loss: 2.1445 - val_age_output_loss: 2.8573 - val_weight_output_loss: 2.1211 - val_bag_output_loss: 1.9006 - val_footwear_output_loss: 1.8450 - val_pose_output_loss: 0.9779 - val_emotion_output_loss: 2.1172 - val_gender_output_acc: 0.7773 - val_image_quality_output_acc: 0.5079 - val_age_output_acc: 0.3472 - val_weight_output_acc: 0.5744 - val_bag_output_acc: 0.5818 - val_footwear_output_acc: 0.5928 - val_pose_output_acc: 0.7455 - val_emotion_output_acc: 0.6493
# Epoch 17/30
# 360/360 [==============================] - 81s 225ms/step - loss: 5.5554 - gender_output_loss: 0.0076 - image_quality_output_loss: 0.0100 - age_output_loss: 0.0103 - weight_output_loss: 0.0078 - bag_output_loss: 0.0092 - footwear_output_loss: 0.0079 - pose_output_loss: 0.0104 - emotion_output_loss: 0.0062 - gender_output_acc: 0.9978 - image_quality_output_acc: 0.9977 - age_output_acc: 0.9977 - weight_output_acc: 0.9983 - bag_output_acc: 0.9981 - footwear_output_acc: 0.9981 - pose_output_acc: 0.9971 - emotion_output_acc: 0.9990 - val_loss: 20.3247 - val_gender_output_loss: 0.8468 - val_image_quality_output_loss: 2.1177 - val_age_output_loss: 2.9004 - val_weight_output_loss: 2.1478 - val_bag_output_loss: 1.8953 - val_footwear_output_loss: 1.8295 - val_pose_output_loss: 1.0051 - val_emotion_output_loss: 2.1159 - val_gender_output_acc: 0.7753 - val_image_quality_output_acc: 0.5005 - val_age_output_acc: 0.3487 - val_weight_output_acc: 0.5739 - val_bag_output_acc: 0.5893 - val_footwear_output_acc: 0.5833 - val_pose_output_acc: 0.7436 - val_emotion_output_acc: 0.6493
# Epoch 18/30
# Epoch 17/30
# 360/360 [==============================] - 82s 226ms/step - loss: 5.5177 - gender_output_loss: 0.0067 - image_quality_output_loss: 0.0091 - age_output_loss: 0.0102 - weight_output_loss: 0.0084 - bag_output_loss: 0.0110 - footwear_output_loss: 0.0091 - pose_output_loss: 0.0100 - emotion_output_loss: 0.0065 - gender_output_acc: 0.9979 - image_quality_output_acc: 0.9974 - age_output_acc: 0.9983 - weight_output_acc: 0.9980 - bag_output_acc: 0.9974 - footwear_output_acc: 0.9972 - pose_output_acc: 0.9970 - emotion_output_acc: 0.9986 - val_loss: 20.3181 - val_gender_output_loss: 0.8472 - val_image_quality_output_loss: 2.1340 - val_age_output_loss: 2.9092 - val_weight_output_loss: 2.1576 - val_bag_output_loss: 1.8991 - val_footwear_output_loss: 1.8224 - val_pose_output_loss: 0.9919 - val_emotion_output_loss: 2.1296 - val_gender_output_acc: 0.7812 - val_image_quality_output_acc: 0.5055 - val_age_output_acc: 0.3408 - val_weight_output_acc: 0.5744 - val_bag_output_acc: 0.5833 - val_footwear_output_acc: 0.5888 - val_pose_output_acc: 0.7376 - val_emotion_output_acc: 0.6438
# Epoch 19/30
# 360/360 [==============================] - 82s 227ms/step - loss: 5.4728 - gender_output_loss: 0.0069 - image_quality_output_loss: 0.0075 - age_output_loss: 0.0099 - weight_output_loss: 0.0070 - bag_output_loss: 0.0078 - footwear_output_loss: 0.0083 - pose_output_loss: 0.0106 - emotion_output_loss: 0.0070 - gender_output_acc: 0.9983 - image_quality_output_acc: 0.9984 - age_output_acc: 0.9978 - weight_output_acc: 0.9984 - bag_output_acc: 0.9981 - footwear_output_acc: 0.9984 - pose_output_acc: 0.9972 - emotion_output_acc: 0.9984 - val_loss: 20.1938 - val_gender_output_loss: 0.8479 - val_image_quality_output_loss: 2.1248 - val_age_output_loss: 2.9162 - val_weight_output_loss: 2.1513 - val_bag_output_loss: 1.8627 - val_footwear_output_loss: 1.8179 - val_pose_output_loss: 0.9942 - val_emotion_output_loss: 2.0905 - val_gender_output_acc: 0.7793 - val_image_quality_output_acc: 0.5050 - val_age_output_acc: 0.3462 - val_weight_output_acc: 0.5868 - val_bag_output_acc: 0.5818 - val_footwear_output_acc: 0.5838 - val_pose_output_acc: 0.7371 - val_emotion_output_acc: 0.6319
# Epoch 20/30
# 360/360 [==============================] - 82s 227ms/step - loss: 5.4405 - gender_output_loss: 0.0070 - image_quality_output_loss: 0.0080 - age_output_loss: 0.0129 - weight_output_loss: 0.0085 - bag_output_loss: 0.0091 - footwear_output_loss: 0.0083 - pose_output_loss: 0.0115 - emotion_output_loss: 0.0062 - gender_output_acc: 0.9986 - image_quality_output_acc: 0.9976 - age_output_acc: 0.9965 - weight_output_acc: 0.9978 - bag_output_acc: 0.9978 - footwear_output_acc: 0.9977 - pose_output_acc: 0.9971 - emotion_output_acc: 0.9987 - val_loss: 20.2878 - val_gender_output_loss: 0.8511 - val_image_quality_output_loss: 2.1535 - val_age_output_loss: 2.9245 - val_weight_output_loss: 2.1410 - val_bag_output_loss: 1.9125 - val_footwear_output_loss: 1.8484 - val_pose_output_loss: 0.9831 - val_emotion_output_loss: 2.1239 - val_gender_output_acc: 0.7773 - val_image_quality_output_acc: 0.5040 - val_age_output_acc: 0.3542 - val_weight_output_acc: 0.5620 - val_bag_output_acc: 0.5828 - val_footwear_output_acc: 0.5883 - val_pose_output_acc: 0.7307 - val_emotion_output_acc: 0.6434
# Epoch 21/30
#
# 205/360 [================>.............] - ETA: 31s - loss: 5.4041 - gender_output_loss: 0.0061 - image_quality_output_loss: 0.0095 - age_output_loss: 0.0107 - weight_output_loss: 0.0074 - bag_output_loss: 0.0088 - footwear_output_loss: 0.0057 - pose_output_loss: 0.0106 - emotion_output_loss: 0.0062 - gender_output_acc: 0.9989 - image_quality_output_acc: 0.9982 - age_output_acc: 0.9982 - weight_output_acc: 0.9977 - bag_output_acc: 0.9979 - footwear_output_acc: 0.9991 - pose_output_acc: 0.9973 - emotion_output_acc: 0.9980

# %%
ckpt_callback = ModelCheckpoint(filepath='test_curr.h5', monitor='val_loss',save_best_only=True , save_weights_only=True, mode='auto',period=10)
lr_manager = OneCycleLR(samples=train_df.shape[0], epochs=10, batch_size=16,
                    steps=16, max_lr=0.0125,
                    end_percentage=0.1, scale_percentage=None,
                    maximum_momentum=None, minimum_momentum=None)

# %%
from keras.models import load_model
#weights.{epoch:02d}-{val_loss:.2f}.h5

model2.load_weights('temp_curr_1.h5')
#model = load_model('partly_trained.h5')
#model_curr = load_model('weights.10-91.53.h5')

# %%
model2.compile(loss=losses,
              optimizer=SGD(lr=0.01, momentum = 0.009),loss_weights=lossWeights,
              metrics=['accuracy'])
#model2.summary()

# %%
model2.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=30,
    verbose=1,callbacks=[ckpt_callback]
   # preprocessing_function=get_random_eraser(v_l=0, v_h=16),
)
# Out:
# Epoch 1/30
# 360/360 [==============================] - 104s 289ms/step - loss: 288.0994 - gender_output_loss: 0.6531 - image_quality_output_loss: 0.9289 - age_output_loss: 1.4394 - weight_output_loss: 0.9915 - bag_output_loss: 0.9158 - footwear_output_loss: 0.9514 - pose_output_loss: 0.9157 - emotion_output_loss: 0.9160 - gender_output_acc: 0.6179 - image_quality_output_acc: 0.5527 - age_output_acc: 0.3882 - weight_output_acc: 0.6329 - bag_output_acc: 0.5581 - footwear_output_acc: 0.5604 - pose_output_acc: 0.6165 - emotion_output_acc: 0.7104 - val_loss: 268.0901 - val_gender_output_loss: 0.6591 - val_image_quality_output_loss: 0.9215 - val_age_output_loss: 1.4126 - val_weight_output_loss: 0.9922 - val_bag_output_loss: 0.8918 - val_footwear_output_loss: 0.9490 - val_pose_output_loss: 0.9040 - val_emotion_output_loss: 0.9032 - val_gender_output_acc: 0.6141 - val_image_quality_output_acc: 0.5600 - val_age_output_acc: 0.4038 - val_weight_output_acc: 0.6364 - val_bag_output_acc: 0.5694 - val_footwear_output_acc: 0.5635 - val_pose_output_acc: 0.6195 - val_emotion_output_acc: 0.7178
# Epoch 2/30
# 360/360 [==============================] - 97s 269ms/step - loss: 250.0765 - gender_output_loss: 0.6369 - image_quality_output_loss: 0.9109 - age_output_loss: 1.4294 - weight_output_loss: 0.9832 - bag_output_loss: 0.9088 - footwear_output_loss: 0.9338 - pose_output_loss: 0.9003 - emotion_output_loss: 0.9069 - gender_output_acc: 0.6277 - image_quality_output_acc: 0.5635 - age_output_acc: 0.3894 - weight_output_acc: 0.6319 - bag_output_acc: 0.5655 - footwear_output_acc: 0.5670 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7107 - val_loss: 233.1243 - val_gender_output_loss: 0.6471 - val_image_quality_output_loss: 1.1698 - val_age_output_loss: 1.4121 - val_weight_output_loss: 0.9831 - val_bag_output_loss: 0.9071 - val_footwear_output_loss: 0.9664 - val_pose_output_loss: 0.9081 - val_emotion_output_loss: 0.8995 - val_gender_output_acc: 0.6205 - val_image_quality_output_acc: 0.4107 - val_age_output_acc: 0.3938 - val_weight_output_acc: 0.6359 - val_bag_output_acc: 0.5580 - val_footwear_output_acc: 0.5397 - val_pose_output_acc: 0.6186 - val_emotion_output_acc: 0.7178
# Epoch 3/30
# 360/360 [==============================] - 97s 269ms/step - loss: 217.1751 - gender_output_loss: 0.6159 - image_quality_output_loss: 0.8979 - age_output_loss: 1.4181 - weight_output_loss: 0.9738 - bag_output_loss: 0.8971 - footwear_output_loss: 0.9179 - pose_output_loss: 0.8790 - emotion_output_loss: 0.9011 - gender_output_acc: 0.6533 - image_quality_output_acc: 0.5690 - age_output_acc: 0.3911 - weight_output_acc: 0.6343 - bag_output_acc: 0.5677 - footwear_output_acc: 0.5786 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7110 - val_loss: 202.3482 - val_gender_output_loss: 0.6249 - val_image_quality_output_loss: 0.9108 - val_age_output_loss: 1.4159 - val_weight_output_loss: 0.9807 - val_bag_output_loss: 0.8819 - val_footwear_output_loss: 0.9817 - val_pose_output_loss: 0.8862 - val_emotion_output_loss: 0.8949 - val_gender_output_acc: 0.6394 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3800 - val_weight_output_acc: 0.6354 - val_bag_output_acc: 0.5729 - val_footwear_output_acc: 0.5283 - val_pose_output_acc: 0.6210 - val_emotion_output_acc: 0.7178
# Epoch 4/30
# Epoch 3/30
# 360/360 [==============================] - 98s 271ms/step - loss: 188.6964 - gender_output_loss: 0.5885 - image_quality_output_loss: 0.8874 - age_output_loss: 1.4035 - weight_output_loss: 0.9639 - bag_output_loss: 0.8842 - footwear_output_loss: 0.9022 - pose_output_loss: 0.8527 - emotion_output_loss: 0.8938 - gender_output_acc: 0.6853 - image_quality_output_acc: 0.5714 - age_output_acc: 0.4009 - weight_output_acc: 0.6341 - bag_output_acc: 0.5818 - footwear_output_acc: 0.5848 - pose_output_acc: 0.6276 - emotion_output_acc: 0.7103 - val_loss: 176.1250 - val_gender_output_loss: 0.6496 - val_image_quality_output_loss: 0.9260 - val_age_output_loss: 1.4207 - val_weight_output_loss: 1.0155 - val_bag_output_loss: 0.9219 - val_footwear_output_loss: 0.9442 - val_pose_output_loss: 0.9185 - val_emotion_output_loss: 0.8935 - val_gender_output_acc: 0.6225 - val_image_quality_output_acc: 0.5382 - val_age_output_acc: 0.4058 - val_weight_output_acc: 0.6364 - val_bag_output_acc: 0.5308 - val_footwear_output_acc: 0.5580 - val_pose_output_acc: 0.6176 - val_emotion_output_acc: 0.7178
# Epoch 5/30
# 360/360 [==============================] - 98s 271ms/step - loss: 164.0310 - gender_output_loss: 0.5642 - image_quality_output_loss: 0.8691 - age_output_loss: 1.3870 - weight_output_loss: 0.9509 - bag_output_loss: 0.8730 - footwear_output_loss: 0.8829 - pose_output_loss: 0.8175 - emotion_output_loss: 0.8805 - gender_output_acc: 0.7046 - image_quality_output_acc: 0.5881 - age_output_acc: 0.4056 - weight_output_acc: 0.6378 - bag_output_acc: 0.5860 - footwear_output_acc: 0.5961 - pose_output_acc: 0.6413 - emotion_output_acc: 0.7107 - val_loss: 153.2302 - val_gender_output_loss: 0.6766 - val_image_quality_output_loss: 0.9137 - val_age_output_loss: 1.4195 - val_weight_output_loss: 0.9737 - val_bag_output_loss: 0.8777 - val_footwear_output_loss: 0.9410 - val_pose_output_loss: 0.8591 - val_emotion_output_loss: 0.9017 - val_gender_output_acc: 0.5893 - val_image_quality_output_acc: 0.5709 - val_age_output_acc: 0.3780 - val_weight_output_acc: 0.6369 - val_bag_output_acc: 0.5809 - val_footwear_output_acc: 0.5585 - val_pose_output_acc: 0.6295 - val_emotion_output_acc: 0.7173
# Epoch 6/30
# Epoch 5/30
# 360/360 [==============================] - 97s 270ms/step - loss: 142.6497 - gender_output_loss: 0.5294 - image_quality_output_loss: 0.8579 - age_output_loss: 1.3622 - weight_output_loss: 0.9382 - bag_output_loss: 0.8573 - footwear_output_loss: 0.8505 - pose_output_loss: 0.7674 - emotion_output_loss: 0.8700 - gender_output_acc: 0.7323 - image_quality_output_acc: 0.5961 - age_output_acc: 0.4176 - weight_output_acc: 0.6364 - bag_output_acc: 0.6024 - footwear_output_acc: 0.6105 - pose_output_acc: 0.6655 - emotion_output_acc: 0.7109 - val_loss: 133.8872 - val_gender_output_loss: 0.5884 - val_image_quality_output_loss: 1.1977 - val_age_output_loss: 1.4232 - val_weight_output_loss: 0.9949 - val_bag_output_loss: 0.9945 - val_footwear_output_loss: 0.9542 - val_pose_output_loss: 0.8170 - val_emotion_output_loss: 0.9241 - val_gender_output_acc: 0.6781 - val_image_quality_output_acc: 0.3586 - val_age_output_acc: 0.3720 - val_weight_output_acc: 0.6364 - val_bag_output_acc: 0.4767 - val_footwear_output_acc: 0.5496 - val_pose_output_acc: 0.6424 - val_emotion_output_acc: 0.7178
# Epoch 7/30
# Epoch 6/30
# 360/360 [==============================] - 98s 271ms/step - loss: 164.0310 - gender_output_loss: 0.5642 - image_quality_output_loss: 0.8691 - age_output_loss: 1.3870 - weight_output_loss: 0.9509 - bag_output_loss: 0.8730 - footwear_output_loss: 0.8829 - pose_output_loss: 0.8175 - emotion_output_loss: 0.8805 - gender_output_acc: 0.7046 - image_quality_output_acc: 0.5881 - age_output_acc: 0.4056 - weight_output_acc: 0.6378 - bag_output_acc: 0.5860 - footwear_output_acc: 0.5961 - pose_output_acc: 0.6413 - emotion_output_acc: 0.7107 - val_loss: 153.2302 - val_gender_output_loss: 0.6766 - val_image_quality_output_loss: 0.9137 - val_age_output_loss: 1.4195 - val_weight_output_loss: 0.9737 - val_bag_output_loss: 0.8777 - val_footwear_output_loss: 0.9410 - val_pose_output_loss: 0.8591 - val_emotion_output_loss: 0.9017 - val_gender_output_acc: 0.5893 - val_image_quality_output_acc: 0.5709 - val_age_output_acc: 0.3780 - val_weight_output_acc: 0.6369 - val_bag_output_acc: 0.5809 - val_footwear_output_acc: 0.5585 - val_pose_output_acc: 0.6295 - val_emotion_output_acc: 0.7173
# 360/360 [==============================] - 97s 270ms/step - loss: 124.1172 - gender_output_loss: 0.4868 - image_quality_output_loss: 0.8376 - age_output_loss: 1.3402 - weight_output_loss: 0.9244 - bag_output_loss: 0.8357 - footwear_output_loss: 0.8242 - pose_output_loss: 0.7006 - emotion_output_loss: 0.8545 - gender_output_acc: 0.7612 - image_quality_output_acc: 0.6105 - age_output_acc: 0.4267 - weight_output_acc: 0.6421 - bag_output_acc: 0.6210 - footwear_output_acc: 0.6299 - pose_output_acc: 0.7017 - emotion_output_acc: 0.7106 - val_loss: 116.5455 - val_gender_output_loss: 0.5987 - val_image_quality_output_loss: 0.9867 - val_age_output_loss: 1.4133 - val_weight_output_loss: 1.0597 - val_bag_output_loss: 0.8770 - val_footwear_output_loss: 0.9125 - val_pose_output_loss: 0.8000 - val_emotion_output_loss: 0.8934 - val_gender_output_acc: 0.6855 - val_image_quality_output_acc: 0.5303 - val_age_output_acc: 0.4077 - val_weight_output_acc: 0.5223 - val_bag_output_acc: 0.5858 - val_footwear_output_acc: 0.5903 - val_pose_output_acc: 0.6577 - val_emotion_output_acc: 0.7178
# Epoch 8/30
# 360/360 [==============================] - 96s 267ms/step - loss: 108.0524 - gender_output_loss: 0.4390 - image_quality_output_loss: 0.8186 - age_output_loss: 1.3064 - weight_output_loss: 0.9056 - bag_output_loss: 0.8161 - footwear_output_loss: 0.7833 - pose_output_loss: 0.6296 - emotion_output_loss: 0.8371 - gender_output_acc: 0.7976 - image_quality_output_acc: 0.6194 - age_output_acc: 0.4457 - weight_output_acc: 0.6488 - bag_output_acc: 0.6413 - footwear_output_acc: 0.6477 - pose_output_acc: 0.7377 - emotion_output_acc: 0.7126 - val_loss: 102.3692 - val_gender_output_loss: 0.6003 - val_image_quality_output_loss: 1.1076 - val_age_output_loss: 1.4045 - val_weight_output_loss: 0.9936 - val_bag_output_loss: 0.8931 - val_footwear_output_loss: 1.1224 - val_pose_output_loss: 0.9700 - val_emotion_output_loss: 0.9251 - val_gender_output_acc: 0.6895 - val_image_quality_output_acc: 0.5342 - val_age_output_acc: 0.3755 - val_weight_output_acc: 0.6210 - val_bag_output_acc: 0.5714 - val_footwear_output_acc: 0.4940 - val_pose_output_acc: 0.6652 - val_emotion_output_acc: 0.7138
# Epoch 9/30
# 360/360 [==============================] - 95s 265ms/step - loss: 94.1215 - gender_output_loss: 0.3912 - image_quality_output_loss: 0.7883 - age_output_loss: 1.2679 - weight_output_loss: 0.8790 - bag_output_loss: 0.7802 - footwear_output_loss: 0.7442 - pose_output_loss: 0.5523 - emotion_output_loss: 0.8116 - gender_output_acc: 0.8273 - image_quality_output_acc: 0.6428 - age_output_acc: 0.4720 - weight_output_acc: 0.6586 - bag_output_acc: 0.6630 - footwear_output_acc: 0.6725 - pose_output_acc: 0.7760 - emotion_output_acc: 0.7150 - val_loss: 91.3734 - val_gender_output_loss: 1.5596 - val_image_quality_output_loss: 1.0445 - val_age_output_loss: 1.4747 - val_weight_output_loss: 1.0225 - val_bag_output_loss: 1.0675 - val_footwear_output_loss: 1.5256 - val_pose_output_loss: 0.9918 - val_emotion_output_loss: 0.9433 - val_gender_output_acc: 0.4856 - val_image_quality_output_acc: 0.5129 - val_age_output_acc: 0.4092 - val_weight_output_acc: 0.5680 - val_bag_output_acc: 0.4494 - val_footwear_output_acc: 0.4152 - val_pose_output_acc: 0.5293 - val_emotion_output_acc: 0.7138
#
# Epoch 10/30
# 360/360 [==============================] - 92s 256ms/step - loss: 82.0739 - gender_output_loss: 0.3414 - image_quality_output_loss: 0.7614 - age_output_loss: 1.2176 - weight_output_loss: 0.8470 - bag_output_loss: 0.7491 - footwear_output_loss: 0.6941 - pose_output_loss: 0.4728 - emotion_output_loss: 0.7825 - gender_output_acc: 0.8506 - image_quality_output_acc: 0.6614 - age_output_acc: 0.4912 - weight_output_acc: 0.6677 - bag_output_acc: 0.6789 - footwear_output_acc: 0.7013 - pose_output_acc: 0.8151 - emotion_output_acc: 0.7188 - val_loss: 81.1106 - val_gender_output_loss: 1.3328 - val_image_quality_output_loss: 1.1302 - val_age_output_loss: 1.7976 - val_weight_output_loss: 1.2619 - val_bag_output_loss: 1.3320 - val_footwear_output_loss: 1.3930 - val_pose_output_loss: 0.9370 - val_emotion_output_loss: 1.0063 - val_gender_output_acc: 0.5888 - val_image_quality_output_acc: 0.4038 - val_age_output_acc: 0.4053 - val_weight_output_acc: 0.6379 - val_bag_output_acc: 0.4315 - val_footwear_output_acc: 0.4410 - val_pose_output_acc: 0.6394 - val_emotion_output_acc: 0.6126
# Epoch 11/30
# 360/360 [==============================] - 97s 271ms/step - loss: 71.6826 - gender_output_loss: 0.2978 - image_quality_output_loss: 0.7229 - age_output_loss: 1.1590 - weight_output_loss: 0.8141 - bag_output_loss: 0.7075 - footwear_output_loss: 0.6487 - pose_output_loss: 0.4040 - emotion_output_loss: 0.7493 - gender_output_acc: 0.8694 - image_quality_output_acc: 0.6811 - age_output_acc: 0.5274 - weight_output_acc: 0.6826 - bag_output_acc: 0.7064 - footwear_output_acc: 0.7190 - pose_output_acc: 0.8414 - emotion_output_acc: 0.7293 - val_loss: 70.5218 - val_gender_output_loss: 0.7409 - val_image_quality_output_loss: 1.0530 - val_age_output_loss: 1.6612 - val_weight_output_loss: 1.0749 - val_bag_output_loss: 0.9559 - val_footwear_output_loss: 1.3373 - val_pose_output_loss: 1.0555 - val_emotion_output_loss: 0.9866 - val_gender_output_acc: 0.6761 - val_image_quality_output_acc: 0.5620 - val_age_output_acc: 0.3120 - val_weight_output_acc: 0.5575 - val_bag_output_acc: 0.5863 - val_footwear_output_acc: 0.5094 - val_pose_output_acc: 0.6885 - val_emotion_output_acc: 0.6801
# Epoch 12/30
# Epoch 11/30
# 360/360 [==============================] - 98s 272ms/step - loss: 62.7125 - gender_output_loss: 0.2742 - image_quality_output_loss: 0.6604 - age_output_loss: 1.0834 - weight_output_loss: 0.7580 - bag_output_loss: 0.6618 - footwear_output_loss: 0.5976 - pose_output_loss: 0.3544 - emotion_output_loss: 0.7147 - gender_output_acc: 0.8849 - image_quality_output_acc: 0.7168 - age_output_acc: 0.5614 - weight_output_acc: 0.7008 - bag_output_acc: 0.7298 - footwear_output_acc: 0.7461 - pose_output_acc: 0.8604 - emotion_output_acc: 0.7375 - val_loss: 63.1832 - val_gender_output_loss: 0.6276 - val_image_quality_output_loss: 1.1066 - val_age_output_loss: 2.0699 - val_weight_output_loss: 1.1745 - val_bag_output_loss: 1.0457 - val_footwear_output_loss: 1.3552 - val_pose_output_loss: 1.0844 - val_emotion_output_loss: 0.9659 - val_gender_output_acc: 0.6855 - val_image_quality_output_acc: 0.5635 - val_age_output_acc: 0.4092 - val_weight_output_acc: 0.6300 - val_bag_output_acc: 0.5104 - val_footwear_output_acc: 0.4082 - val_pose_output_acc: 0.5273 - val_emotion_output_acc: 0.6830
# Epoch 13/30
# 360/360 [==============================] - 97s 271ms/step - loss: 54.9930 - gender_output_loss: 0.2514 - image_quality_output_loss: 0.6136 - age_output_loss: 0.9844 - weight_output_loss: 0.6993 - bag_output_loss: 0.6139 - footwear_output_loss: 0.5494 - pose_output_loss: 0.3063 - emotion_output_loss: 0.6714 - gender_output_acc: 0.8970 - image_quality_output_acc: 0.7411 - age_output_acc: 0.6134 - weight_output_acc: 0.7280 - bag_output_acc: 0.7466 - footwear_output_acc: 0.7674 - pose_output_acc: 0.8828 - emotion_output_acc: 0.7536 - val_loss: 56.2655 - val_gender_output_loss: 0.6696 - val_image_quality_output_loss: 1.2160 - val_age_output_loss: 1.7466 - val_weight_output_loss: 1.3386 - val_bag_output_loss: 0.9854 - val_footwear_output_loss: 1.0163 - val_pose_output_loss: 1.0757 - val_emotion_output_loss: 1.1984 - val_gender_output_acc: 0.7178 - val_image_quality_output_acc: 0.4082 - val_age_output_acc: 0.2917 - val_weight_output_acc: 0.3899 - val_bag_output_acc: 0.5903 - val_footwear_output_acc: 0.5317 - val_pose_output_acc: 0.5546 - val_emotion_output_acc: 0.4702
# Epoch 14/30
# Epoch 13/30
# 360/360 [==============================] - 99s 274ms/step - loss: 48.3306 - gender_output_loss: 0.2258 - image_quality_output_loss: 0.5595 - age_output_loss: 0.8900 - weight_output_loss: 0.6289 - bag_output_loss: 0.5580 - footwear_output_loss: 0.4952 - pose_output_loss: 0.2794 - emotion_output_loss: 0.6116 - gender_output_acc: 0.9062 - image_quality_output_acc: 0.7680 - age_output_acc: 0.6508 - weight_output_acc: 0.7576 - bag_output_acc: 0.7742 - footwear_output_acc: 0.7982 - pose_output_acc: 0.8945 - emotion_output_acc: 0.7769 - val_loss: 53.0105 - val_gender_output_loss: 0.9290 - val_image_quality_output_loss: 1.1426 - val_age_output_loss: 3.3684 - val_weight_output_loss: 1.3834 - val_bag_output_loss: 1.1877 - val_footwear_output_loss: 1.1861 - val_pose_output_loss: 1.4459 - val_emotion_output_loss: 1.0663 - val_gender_output_acc: 0.6314 - val_image_quality_output_acc: 0.5347 - val_age_output_acc: 0.1949 - val_weight_output_acc: 0.5918 - val_bag_output_acc: 0.4097 - val_footwear_output_acc: 0.5099 - val_pose_output_acc: 0.4787 - val_emotion_output_acc: 0.6404
# Epoch 15/30
# 359/360 [============================>.] - ETA: 0s - loss: 42.6299 - gender_output_loss: 0.2149 - image_quality_output_loss: 0.4974 - age_output_loss: 0.7857 - weight_output_loss: 0.5565 - bag_output_loss: 0.5015 - footwear_output_loss: 0.4598 - pose_output_loss: 0.2601 - emotion_output_loss: 0.5571 - gender_output_acc: 0.9113 - image_quality_output_acc: 0.7962 - age_output_acc: 0.6985 - weight_output_acc: 0.7851 - bag_output_acc: 0.7983 - footwear_output_acc: 0.8115 - pose_output_acc: 0.9002 - emotion_output_acc: 0.7942Epoch 15/30
# 360/360 [==============================] - 99s 275ms/step - loss: 42.6241 - gender_output_loss: 0.2148 - image_quality_output_loss: 0.4976 - age_output_loss: 0.7853 - weight_output_loss: 0.5562 - bag_output_loss: 0.5021 - footwear_output_loss: 0.4603 - pose_output_loss: 0.2600 - emotion_output_loss: 0.5575 - gender_output_acc: 0.9113 - image_quality_output_acc: 0.7960 - age_output_acc: 0.6988 - weight_output_acc: 0.7852 - bag_output_acc: 0.7981 - footwear_output_acc: 0.8113 - pose_output_acc: 0.9003 - emotion_output_acc: 0.7939 - val_loss: 47.4897 - val_gender_output_loss: 1.6043 - val_image_quality_output_loss: 1.1021 - val_age_output_loss: 2.1063 - val_weight_output_loss: 1.2436 - val_bag_output_loss: 1.0765 - val_footwear_output_loss: 1.0615 - val_pose_output_loss: 1.7671 - val_emotion_output_loss: 1.1027 - val_gender_output_acc: 0.5843 - val_image_quality_output_acc: 0.4886 - val_age_output_acc: 0.2788 - val_weight_output_acc: 0.4742 - val_bag_output_acc: 0.5501 - val_footwear_output_acc: 0.5655 - val_pose_output_acc: 0.6438 - val_emotion_output_acc: 0.6141
# Epoch 16/30
# 360/360 [==============================] - 98s 273ms/step - loss: 37.7459 - gender_output_loss: 0.1959 - image_quality_output_loss: 0.4515 - age_output_loss: 0.6996 - weight_output_loss: 0.5029 - bag_output_loss: 0.4444 - footwear_output_loss: 0.4195 - pose_output_loss: 0.2403 - emotion_output_loss: 0.5052 - gender_output_acc: 0.9201 - image_quality_output_acc: 0.8142 - age_output_acc: 0.7337 - weight_output_acc: 0.8059 - bag_output_acc: 0.8244 - footwear_output_acc: 0.8273 - pose_output_acc: 0.9086 - emotion_output_acc: 0.8140 - val_loss: 45.4597 - val_gender_output_loss: 0.6916 - val_image_quality_output_loss: 1.8613 - val_age_output_loss: 2.5288 - val_weight_output_loss: 1.9096 - val_bag_output_loss: 1.9276 - val_footwear_output_loss: 1.8414 - val_pose_output_loss: 1.0706 - val_emotion_output_loss: 1.3464 - val_gender_output_acc: 0.7128 - val_image_quality_output_acc: 0.5729 - val_age_output_acc: 0.3695 - val_weight_output_acc: 0.6339 - val_bag_output_acc: 0.4529 - val_footwear_output_acc: 0.4008 - val_pose_output_acc: 0.6999 - val_emotion_output_acc: 0.5972
# Epoch 17/30
# 360/360 [==============================] - 98s 272ms/step - loss: 33.6099 - gender_output_loss: 0.1961 - image_quality_output_loss: 0.4200 - age_output_loss: 0.6331 - weight_output_loss: 0.4341 - bag_output_loss: 0.4120 - footwear_output_loss: 0.3876 - pose_output_loss: 0.2383 - emotion_output_loss: 0.4454 - gender_output_acc: 0.9212 - image_quality_output_acc: 0.8273 - age_output_acc: 0.7615 - weight_output_acc: 0.8332 - bag_output_acc: 0.8386 - footwear_output_acc: 0.8469 - pose_output_acc: 0.9126 - emotion_output_acc: 0.8379 - val_loss: 43.8272 - val_gender_output_loss: 1.6297 - val_image_quality_output_loss: 1.2537 - val_age_output_loss: 2.6673 - val_weight_output_loss: 1.8298 - val_bag_output_loss: 1.0879 - val_footwear_output_loss: 1.9129 - val_pose_output_loss: 3.4214 - val_emotion_output_loss: 1.2804 - val_gender_output_acc: 0.5367 - val_image_quality_output_acc: 0.4142 - val_age_output_acc: 0.2331 - val_weight_output_acc: 0.3095 - val_bag_output_acc: 0.5531 - val_footwear_output_acc: 0.5179 - val_pose_output_acc: 0.2555 - val_emotion_output_acc: 0.5258
# Epoch 18/30
# 360/360 [==============================] - 97s 270ms/step - loss: 29.9297 - gender_output_loss: 0.1764 - image_quality_output_loss: 0.3816 - age_output_loss: 0.5433 - weight_output_loss: 0.3927 - bag_output_loss: 0.3592 - footwear_output_loss: 0.3358 - pose_output_loss: 0.2155 - emotion_output_loss: 0.3805 - gender_output_acc: 0.9319 - image_quality_output_acc: 0.8470 - age_output_acc: 0.7986 - weight_output_acc: 0.8496 - bag_output_acc: 0.8596 - footwear_output_acc: 0.8667 - pose_output_acc: 0.9205 - emotion_output_acc: 0.8623 - val_loss: 47.8804 - val_gender_output_loss: 0.8993 - val_image_quality_output_loss: 3.7278 - val_age_output_loss: 5.6416 - val_weight_output_loss: 3.0656 - val_bag_output_loss: 1.6208 - val_footwear_output_loss: 3.9166 - val_pose_output_loss: 1.1338 - val_emotion_output_loss: 2.1894 - val_gender_output_acc: 0.6925 - val_image_quality_output_acc: 0.3269 - val_age_output_acc: 0.2351 - val_weight_output_acc: 0.3229 - val_bag_output_acc: 0.4772 - val_footwear_output_acc: 0.4950 - val_pose_output_acc: 0.6880 - val_emotion_output_acc: 0.5501
# Epoch 19/30
# 360/360 [==============================] - 96s 268ms/step - loss: 26.8910 - gender_output_loss: 0.1739 - image_quality_output_loss: 0.3432 - age_output_loss: 0.5039 - weight_output_loss: 0.3495 - bag_output_loss: 0.3182 - footwear_output_loss: 0.3329 - pose_output_loss: 0.2002 - emotion_output_loss: 0.3613 - gender_output_acc: 0.9293 - image_quality_output_acc: 0.8646 - age_output_acc: 0.8105 - weight_output_acc: 0.8686 - bag_output_acc: 0.8794 - footwear_output_acc: 0.8700 - pose_output_acc: 0.9260 - emotion_output_acc: 0.8698 - val_loss: 45.1457 - val_gender_output_loss: 1.6624 - val_image_quality_output_loss: 2.1186 - val_age_output_loss: 2.7825 - val_weight_output_loss: 2.7991 - val_bag_output_loss: 4.9778 - val_footwear_output_loss: 1.9517 - val_pose_output_loss: 1.6731 - val_emotion_output_loss: 4.1213 - val_gender_output_acc: 0.6017 - val_image_quality_output_acc: 0.5561 - val_age_output_acc: 0.2793 - val_weight_output_acc: 0.3705 - val_bag_output_acc: 0.1300 - val_footwear_output_acc: 0.5099 - val_pose_output_acc: 0.6766 - val_emotion_output_acc: 0.1548
# Epoch 19/30Epoch 20/30
# 360/360 [==============================] - 94s 261ms/step - loss: 24.2079 - gender_output_loss: 0.1618 - image_quality_output_loss: 0.3249 - age_output_loss: 0.4634 - weight_output_loss: 0.3211 - bag_output_loss: 0.2982 - footwear_output_loss: 0.2969 - pose_output_loss: 0.1930 - emotion_output_loss: 0.3009 - gender_output_acc: 0.9361 - image_quality_output_acc: 0.8731 - age_output_acc: 0.8293 - weight_output_acc: 0.8804 - bag_output_acc: 0.8851 - footwear_output_acc: 0.8871 - pose_output_acc: 0.9291 - emotion_output_acc: 0.8901 - val_loss: 38.0789 - val_gender_output_loss: 1.5516 - val_image_quality_output_loss: 3.8047 - val_age_output_loss: 2.5443 - val_weight_output_loss: 1.7849 - val_bag_output_loss: 1.8544 - val_footwear_output_loss: 2.1774 - val_pose_output_loss: 1.2576 - val_emotion_output_loss: 2.3230 - val_gender_output_acc: 0.5655 - val_image_quality_output_acc: 0.2356 - val_age_output_acc: 0.3115 - val_weight_output_acc: 0.6245 - val_bag_output_acc: 0.3194 - val_footwear_output_acc: 0.4921 - val_pose_output_acc: 0.6255 - val_emotion_output_acc: 0.4663
# Epoch 21/30
# 360/360 [==============================] - 96s 267ms/step - loss: 22.0069 - gender_output_loss: 0.1474 - image_quality_output_loss: 0.3175 - age_output_loss: 0.4444 - weight_output_loss: 0.3145 - bag_output_loss: 0.2861 - footwear_output_loss: 0.2826 - pose_output_loss: 0.1935 - emotion_output_loss: 0.2888 - gender_output_acc: 0.9438 - image_quality_output_acc: 0.8745 - age_output_acc: 0.8391 - weight_output_acc: 0.8812 - bag_output_acc: 0.8891 - footwear_output_acc: 0.8891 - pose_output_acc: 0.9279 - emotion_output_acc: 0.8969 - val_loss: 33.4757 - val_gender_output_loss: 2.0070 - val_image_quality_output_loss: 1.5825 - val_age_output_loss: 2.4980 - val_weight_output_loss: 2.0339 - val_bag_output_loss: 1.4597 - val_footwear_output_loss: 1.8844 - val_pose_output_loss: 1.4099 - val_emotion_output_loss: 1.7806 - val_gender_output_acc: 0.5972 - val_image_quality_output_acc: 0.4395 - val_age_output_acc: 0.3001 - val_weight_output_acc: 0.5288 - val_bag_output_acc: 0.5625 - val_footwear_output_acc: 0.4196 - val_pose_output_acc: 0.6106 - val_emotion_output_acc: 0.6776
# Epoch 22/30
# 360/360 [==============================] - 95s 264ms/step - loss: 20.0691 - gender_output_loss: 0.1527 - image_quality_output_loss: 0.3010 - age_output_loss: 0.4184 - weight_output_loss: 0.2929 - bag_output_loss: 0.2708 - footwear_output_loss: 0.2708 - pose_output_loss: 0.1894 - emotion_output_loss: 0.2717 - gender_output_acc: 0.9383 - image_quality_output_acc: 0.8846 - age_output_acc: 0.8470 - weight_output_acc: 0.8880 - bag_output_acc: 0.8944 - footwear_output_acc: 0.8975 - pose_output_acc: 0.9326 - emotion_output_acc: 0.8971 - val_loss: 33.5815 - val_gender_output_loss: 0.7401 - val_image_quality_output_loss: 2.5002 - val_age_output_loss: 4.7795 - val_weight_output_loss: 1.8589 - val_bag_output_loss: 1.5467 - val_footwear_output_loss: 1.5417 - val_pose_output_loss: 1.4416 - val_emotion_output_loss: 2.0640 - val_gender_output_acc: 0.7054 - val_image_quality_output_acc: 0.2932 - val_age_output_acc: 0.2068 - val_weight_output_acc: 0.6096 - val_bag_output_acc: 0.4618 - val_footwear_output_acc: 0.5208 - val_pose_output_acc: 0.6830 - val_emotion_output_acc: 0.3249
# Epoch 23/30
# 360/360 [==============================] - 95s 265ms/step - loss: 18.3812 - gender_output_loss: 0.1465 - image_quality_output_loss: 0.2987 - age_output_loss: 0.4107 - weight_output_loss: 0.2718 - bag_output_loss: 0.2682 - footwear_output_loss: 0.2529 - pose_output_loss: 0.1706 - emotion_output_loss: 0.2555 - gender_output_acc: 0.9415 - image_quality_output_acc: 0.8816 - age_output_acc: 0.8487 - weight_output_acc: 0.8975 - bag_output_acc: 0.8967 - footwear_output_acc: 0.9043 - pose_output_acc: 0.9358 - emotion_output_acc: 0.9077 - val_loss: 45.0601 - val_gender_output_loss: 2.8526 - val_image_quality_output_loss: 7.9306 - val_age_output_loss: 3.9598 - val_weight_output_loss: 2.8013 - val_bag_output_loss: 1.7735 - val_footwear_output_loss: 2.5557 - val_pose_output_loss: 1.4508 - val_emotion_output_loss: 6.1099 - val_gender_output_acc: 0.5813 - val_image_quality_output_acc: 0.2644 - val_age_output_acc: 0.2168 - val_weight_output_acc: 0.5933 - val_bag_output_acc: 0.5878 - val_footwear_output_acc: 0.4454 - val_pose_output_acc: 0.6711 - val_emotion_output_acc: 0.1419
# Epoch 24/30
# 360/360 [==============================] - 95s 265ms/step - loss: 18.3812 - gender_output_loss: 0.1465 - image_quality_output_loss: 0.2987 - age_output_loss: 0.4107 - weight_output_loss: 0.2718 - bag_output_loss: 0.2682 - footwear_output_loss: 0.2529 - pose_output_loss: 0.1706 - emotion_output_loss: 0.2555 - gender_output_acc: 0.9415 - image_quality_output_acc: 0.8816 - age_output_acc: 0.8487 - weight_output_acc: 0.8975 - bag_output_acc: 0.8967 - footwear_output_acc: 0.9043 - pose_output_acc: 0.9358 - emotion_output_acc: 0.9077 - val_loss: 45.0601 - val_gender_output_loss: 2.8526 - val_image_quality_output_loss: 7.9306 - val_age_output_loss: 3.9598 - val_weight_output_loss: 2.8013 - val_bag_output_loss: 1.7735 - val_footwear_output_loss: 2.5557 - val_pose_output_loss: 1.4508 - val_emotion_output_loss: 6.1099 - val_gender_output_acc: 0.5813 - val_image_quality_output_acc: 0.2644 - val_age_output_acc: 0.2168 - val_weight_output_acc: 0.5933 - val_bag_output_acc: 0.5878 - val_footwear_output_acc: 0.4454 - val_pose_output_acc: 0.6711 - val_emotion_output_acc: 0.1419
# Epoch 24/30
# 360/360 [==============================] - 95s 263ms/step - loss: 16.8974 - gender_output_loss: 0.1510 - image_quality_output_loss: 0.2815 - age_output_loss: 0.3741 - weight_output_loss: 0.2633 - bag_output_loss: 0.2469 - footwear_output_loss: 0.2651 - pose_output_loss: 0.1659 - emotion_output_loss: 0.2340 - gender_output_acc: 0.9392 - image_quality_output_acc: 0.8903 - age_output_acc: 0.8633 - weight_output_acc: 0.9033 - bag_output_acc: 0.9023 - footwear_output_acc: 0.8974 - pose_output_acc: 0.9367 - emotion_output_acc: 0.9153 - val_loss: 31.5852 - val_gender_output_loss: 0.8449 - val_image_quality_output_loss: 1.8171 - val_age_output_loss: 3.3601 - val_weight_output_loss: 2.8368 - val_bag_output_loss: 2.8676 - val_footwear_output_loss: 2.5745 - val_pose_output_loss: 1.0633 - val_emotion_output_loss: 1.8977 - val_gender_output_acc: 0.7143 - val_image_quality_output_acc: 0.4008 - val_age_output_acc: 0.2515 - val_weight_output_acc: 0.2996 - val_bag_output_acc: 0.5769 - val_footwear_output_acc: 0.4420 - val_pose_output_acc: 0.7088 - val_emotion_output_acc: 0.6830
# Epoch 25/30
# 360/360 [==============================] - 95s 265ms/step - loss: 15.5891 - gender_output_loss: 0.1361 - image_quality_output_loss: 0.2720 - age_output_loss: 0.3599 - weight_output_loss: 0.2576 - bag_output_loss: 0.2451 - footwear_output_loss: 0.2312 - pose_output_loss: 0.1586 - emotion_output_loss: 0.2315 - gender_output_acc: 0.9451 - image_quality_output_acc: 0.8977 - age_output_acc: 0.8662 - weight_output_acc: 0.9023 - bag_output_acc: 0.9076 - footwear_output_acc: 0.9112 - pose_output_acc: 0.9432 - emotion_output_acc: 0.9148 - val_loss: 29.5166 - val_gender_output_loss: 0.8841 - val_image_quality_output_loss: 1.4806 - val_age_output_loss: 2.6206 - val_weight_output_loss: 1.7951 - val_bag_output_loss: 3.1463 - val_footwear_output_loss: 1.6635 - val_pose_output_loss: 1.9309 - val_emotion_output_loss: 2.8094 - val_gender_output_acc: 0.7103 - val_image_quality_output_acc: 0.4856 - val_age_output_acc: 0.2331 - val_weight_output_acc: 0.4360 - val_bag_output_acc: 0.3958 - val_footwear_output_acc: 0.4911 - val_pose_output_acc: 0.5699 - val_emotion_output_acc: 0.3929
# Epoch 25/30
# Epoch 26/30
# 360/360 [==============================] - 94s 262ms/step - loss: 14.4811 - gender_output_loss: 0.1336 - image_quality_output_loss: 0.2494 - age_output_loss: 0.3390 - weight_output_loss: 0.2451 - bag_output_loss: 0.2387 - footwear_output_loss: 0.2413 - pose_output_loss: 0.1635 - emotion_output_loss: 0.2352 - gender_output_acc: 0.9485 - image_quality_output_acc: 0.9036 - age_output_acc: 0.8775 - weight_output_acc: 0.9092 - bag_output_acc: 0.9111 - footwear_output_acc: 0.9057 - pose_output_acc: 0.9375 - emotion_output_acc: 0.9168 - val_loss: 36.5555 - val_gender_output_loss: 2.0376 - val_image_quality_output_loss: 3.0966 - val_age_output_loss: 6.5893 - val_weight_output_loss: 2.5848 - val_bag_output_loss: 2.9444 - val_footwear_output_loss: 3.2330 - val_pose_output_loss: 1.4372 - val_emotion_output_loss: 2.4292 - val_gender_output_acc: 0.6176 - val_image_quality_output_acc: 0.3512 - val_age_output_acc: 0.2614 - val_weight_output_acc: 0.5928 - val_bag_output_acc: 0.5749 - val_footwear_output_acc: 0.5828 - val_pose_output_acc: 0.5615 - val_emotion_output_acc: 0.5556
# Epoch 27/30
# 360/360 [==============================] - 94s 261ms/step - loss: 13.4732 - gender_output_loss: 0.1272 - image_quality_output_loss: 0.2412 - age_output_loss: 0.3490 - weight_output_loss: 0.2357 - bag_output_loss: 0.2132 - footwear_output_loss: 0.2315 - pose_output_loss: 0.1470 - emotion_output_loss: 0.2154 - gender_output_acc: 0.9509 - image_quality_output_acc: 0.9071 - age_output_acc: 0.8714 - weight_output_acc: 0.9144 - bag_output_acc: 0.9213 - footwear_output_acc: 0.9127 - pose_output_acc: 0.9447 - emotion_output_acc: 0.9247 - val_loss: 35.7523 - val_gender_output_loss: 2.2912 - val_image_quality_output_loss: 3.8329 - val_age_output_loss: 5.0721 - val_weight_output_loss: 3.0934 - val_bag_output_loss: 2.1521 - val_footwear_output_loss: 2.9796 - val_pose_output_loss: 2.3096 - val_emotion_output_loss: 2.6836 - val_gender_output_acc: 0.5476 - val_image_quality_output_acc: 0.3110 - val_age_output_acc: 0.2872 - val_weight_output_acc: 0.4142 - val_bag_output_acc: 0.4812 - val_footwear_output_acc: 0.3418 - val_pose_output_acc: 0.5030 - val_emotion_output_acc: 0.7168
# Epoch 28/30
# 360/360 [==============================] - 94s 262ms/step - loss: 12.7278 - gender_output_loss: 0.1352 - image_quality_output_loss: 0.2587 - age_output_loss: 0.3492 - weight_output_loss: 0.2392 - bag_output_loss: 0.2292 - footwear_output_loss: 0.2329 - pose_output_loss: 0.1515 - emotion_output_loss: 0.2110 - gender_output_acc: 0.9467 - image_quality_output_acc: 0.8995 - age_output_acc: 0.8724 - weight_output_acc: 0.9120 - bag_output_acc: 0.9135 - footwear_output_acc: 0.9117 - pose_output_acc: 0.9442 - emotion_output_acc: 0.9241 - val_loss: 40.2904 - val_gender_output_loss: 2.0336 - val_image_quality_output_loss: 5.3495 - val_age_output_loss: 6.4559 - val_weight_output_loss: 3.8155 - val_bag_output_loss: 3.2420 - val_footwear_output_loss: 4.4773 - val_pose_output_loss: 1.3037 - val_emotion_output_loss: 3.0166 - val_gender_output_acc: 0.6106 - val_image_quality_output_acc: 0.5779 - val_age_output_acc: 0.2118 - val_weight_output_acc: 0.6354 - val_bag_output_acc: 0.5873 - val_footwear_output_acc: 0.2679 - val_pose_output_acc: 0.6994 - val_emotion_output_acc: 0.6582
# Epoch 29/30
# 360/360 [==============================] - 96s 266ms/step - loss: 11.8668 - gender_output_loss: 0.1167 - image_quality_output_loss: 0.2329 - age_output_loss: 0.3063 - weight_output_loss: 0.2284 - bag_output_loss: 0.2045 - footwear_output_loss: 0.2142 - pose_output_loss: 0.1513 - emotion_output_loss: 0.2087 - gender_output_acc: 0.9559 - image_quality_output_acc: 0.9112 - age_output_acc: 0.8879 - weight_output_acc: 0.9168 - bag_output_acc: 0.9239 - footwear_output_acc: 0.9182 - pose_output_acc: 0.9448 - emotion_output_acc: 0.9243 - val_loss: 26.5315 - val_gender_output_loss: 0.7577 - val_image_quality_output_loss: 2.0639 - val_age_output_loss: 3.0929 - val_weight_output_loss: 1.9079 - val_bag_output_loss: 3.0735 - val_footwear_output_loss: 2.7271 - val_pose_output_loss: 1.0461 - val_emotion_output_loss: 1.9393 - val_gender_output_acc: 0.7326 - val_image_quality_output_acc: 0.3943 - val_age_output_acc: 0.2604 - val_weight_output_acc: 0.4673 - val_bag_output_acc: 0.5754 - val_footwear_output_acc: 0.3705 - val_pose_output_acc: 0.7093 - val_emotion_output_acc: 0.5064
# Epoch 30/30
# 360/360 [==============================] - 93s 258ms/step - loss: 11.2932 - gender_output_loss: 0.1250 - image_quality_output_loss: 0.2439 - age_output_loss: 0.3251 - weight_output_loss: 0.2262 - bag_output_loss: 0.2136 - footwear_output_loss: 0.2078 - pose_output_loss: 0.1500 - emotion_output_loss: 0.2076 - gender_output_acc: 0.9503 - image_quality_output_acc: 0.9074 - age_output_acc: 0.8813 - weight_output_acc: 0.9174 - bag_output_acc: 0.9180 - footwear_output_acc: 0.9227 - pose_output_acc: 0.9454 - emotion_output_acc: 0.9271 - val_loss: 30.3421 - val_gender_output_loss: 1.8389 - val_image_quality_output_loss: 2.1033 - val_age_output_loss: 4.8990 - val_weight_output_loss: 2.3929 - val_bag_output_loss: 2.2166 - val_footwear_output_loss: 3.3371 - val_pose_output_loss: 2.3952 - val_emotion_output_loss: 1.8112 - val_gender_output_acc: 0.6012 - val_image_quality_output_acc: 0.3512 - val_age_output_acc: 0.1230 - val_weight_output_acc: 0.3095 - val_bag_output_acc: 0.5193 - val_footwear_output_acc: 0.2951 - val_pose_output_acc: 0.4856 - val_emotion_output_acc: 0.6434

# %%
from keras.models import load_model

model2.load_weights('test_curr.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.01, momentum = 0.009),loss_weights=lossWeights,
              metrics=['accuracy'])

results = model2.evaluate(valid_gen)
print(dict(zip(model2.metrics_names,results)))
# Out:
# 63/63 [==============================] - 12s 187ms/step
# {'loss': 26.55498168582008, 'gender_output_loss': 0.7565779350106678, 'image_quality_output_loss': 2.058303780025906, 'age_output_loss': 3.090690616577391, 'weight_output_loss': 1.9115128271163455, 'bag_output_loss': 3.086181076746138, 'footwear_output_loss': 2.727973816886781, 'pose_output_loss': 1.0448831239389995, 'emotion_output_loss': 1.9557750963029408, 'gender_output_acc': 0.7346230158730159, 'image_quality_output_acc': 0.3958333333333333, 'age_output_acc': 0.25892857142857145, 'weight_output_acc': 0.46726190476190477, 'bag_output_acc': 0.5744047619047619, 'footwear_output_acc': 0.3715277777777778, 'pose_output_acc': 0.7078373015873016, 'emotion_output_acc': 0.5034722222222222}

# %%
ckpt_callback = ModelCheckpoint(filepath='test_curr_1.h5', monitor='val_loss',save_best_only=True , save_weights_only=True, mode='auto',period=10)
lr_manager = OneCycleLR(samples=train_df.shape[0], epochs=10, batch_size=16,
                    steps=16, max_lr=0.0125,
                    end_percentage=0.1, scale_percentage=None,
                    maximum_momentum=None, minimum_momentum=None)

model2.load_weights('test_curr.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.005, momentum = 0.00009),loss_weights=lossWeights,
              metrics=['accuracy'])


model2.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=50,
    verbose=1,callbacks=[ckpt_callback]
   # preprocessing_function=get_random_eraser(v_l=0, v_h=16),
)
# Out:
# Epoch 1/50
# 359/360 [============================>.] - ETA: 0s - loss: 10.2821 - gender_output_loss: 0.0560 - image_quality_output_loss: 0.0963 - age_output_loss: 0.1180 - weight_output_loss: 0.0926 - bag_output_loss: 0.0813 - footwear_output_loss: 0.0829 - pose_output_loss: 0.0583 - emotion_output_loss: 0.0758 - gender_output_acc: 0.9806 - image_quality_output_acc: 0.9657 - age_output_acc: 0.9616 - weight_output_acc: 0.9688 - bag_output_acc: 0.9745 - footwear_output_acc: 0.9723 - pose_output_acc: 0.9808 - emotion_output_acc: 0.9771Epoch 1/50
# 360/360 [==============================] - 101s 282ms/step - loss: 10.2812 - gender_output_loss: 0.0559 - image_quality_output_loss: 0.0962 - age_output_loss: 0.1182 - weight_output_loss: 0.0924 - bag_output_loss: 0.0817 - footwear_output_loss: 0.0827 - pose_output_loss: 0.0583 - emotion_output_loss: 0.0756 - gender_output_acc: 0.9806 - image_quality_output_acc: 0.9657 - age_output_acc: 0.9615 - weight_output_acc: 0.9688 - bag_output_acc: 0.9744 - footwear_output_acc: 0.9724 - pose_output_acc: 0.9808 - emotion_output_acc: 0.9772 - val_loss: 24.5401 - val_gender_output_loss: 1.0360 - val_image_quality_output_loss: 1.9444 - val_age_output_loss: 3.3261 - val_weight_output_loss: 1.8070 - val_bag_output_loss: 1.9198 - val_footwear_output_loss: 1.8054 - val_pose_output_loss: 1.0373 - val_emotion_output_loss: 2.3437 - val_gender_output_acc: 0.7158 - val_image_quality_output_acc: 0.5392 - val_age_output_acc: 0.3750 - val_weight_output_acc: 0.5327 - val_bag_output_acc: 0.6042 - val_footwear_output_acc: 0.5312 - val_pose_output_acc: 0.7118 - val_emotion_output_acc: 0.6999
# Epoch 2/50
# Epoch 1/50
# 360/360 [==============================] - 94s 261ms/step - loss: 9.2581 - gender_output_loss: 0.0244 - image_quality_output_loss: 0.0360 - age_output_loss: 0.0430 - weight_output_loss: 0.0276 - bag_output_loss: 0.0313 - footwear_output_loss: 0.0346 - pose_output_loss: 0.0228 - emotion_output_loss: 0.0251 - gender_output_acc: 0.9930 - image_quality_output_acc: 0.9883 - age_output_acc: 0.9866 - weight_output_acc: 0.9932 - bag_output_acc: 0.9898 - footwear_output_acc: 0.9891 - pose_output_acc: 0.9937 - emotion_output_acc: 0.9935 - val_loss: 23.5989 - val_gender_output_loss: 0.8504 - val_image_quality_output_loss: 1.9138 - val_age_output_loss: 3.2410 - val_weight_output_loss: 1.9697 - val_bag_output_loss: 1.6603 - val_footwear_output_loss: 2.1169 - val_pose_output_loss: 1.0573 - val_emotion_output_loss: 2.0731 - val_gender_output_acc: 0.7485 - val_image_quality_output_acc: 0.5208 - val_age_output_acc: 0.3775 - val_weight_output_acc: 0.5466 - val_bag_output_acc: 0.5670 - val_footwear_output_acc: 0.5952 - val_pose_output_acc: 0.7386 - val_emotion_output_acc: 0.4732
# Epoch 3/50
# 360/360 [==============================] - 95s 263ms/step - loss: 8.6263 - gender_output_loss: 0.0190 - image_quality_output_loss: 0.0321 - age_output_loss: 0.0309 - weight_output_loss: 0.0185 - bag_output_loss: 0.0296 - footwear_output_loss: 0.0258 - pose_output_loss: 0.0203 - emotion_output_loss: 0.0195 - gender_output_acc: 0.9941 - image_quality_output_acc: 0.9898 - age_output_acc: 0.9905 - weight_output_acc: 0.9950 - bag_output_acc: 0.9898 - footwear_output_acc: 0.9930 - pose_output_acc: 0.9948 - emotion_output_acc: 0.9947 - val_loss: 24.5271 - val_gender_output_loss: 1.6623 - val_image_quality_output_loss: 2.2320 - val_age_output_loss: 2.9441 - val_weight_output_loss: 2.4880 - val_bag_output_loss: 1.8441 - val_footwear_output_loss: 2.0845 - val_pose_output_loss: 1.0918 - val_emotion_output_loss: 2.0254 - val_gender_output_acc: 0.6721 - val_image_quality_output_acc: 0.4802 - val_age_output_acc: 0.3194 - val_weight_output_acc: 0.4792 - val_bag_output_acc: 0.5962 - val_footwear_output_acc: 0.5317 - val_pose_output_acc: 0.7083 - val_emotion_output_acc: 0.6632
# Epoch 4/50
#
# 360/360 [==============================] - 95s 264ms/step - loss: 8.0852 - gender_output_loss: 0.0204 - image_quality_output_loss: 0.0317 - age_output_loss: 0.0302 - weight_output_loss: 0.0231 - bag_output_loss: 0.0289 - footwear_output_loss: 0.0249 - pose_output_loss: 0.0168 - emotion_output_loss: 0.0175 - gender_output_acc: 0.9934 - image_quality_output_acc: 0.9889 - age_output_acc: 0.9915 - weight_output_acc: 0.9923 - bag_output_acc: 0.9910 - footwear_output_acc: 0.9919 - pose_output_acc: 0.9946 - emotion_output_acc: 0.9952 - val_loss: 24.8831 - val_gender_output_loss: 1.2582 - val_image_quality_output_loss: 2.2488 - val_age_output_loss: 3.6802 - val_weight_output_loss: 2.3359 - val_bag_output_loss: 2.4373 - val_footwear_output_loss: 1.9180 - val_pose_output_loss: 1.3131 - val_emotion_output_loss: 2.0522 - val_gender_output_acc: 0.7312 - val_image_quality_output_acc: 0.5094 - val_age_output_acc: 0.3269 - val_weight_output_acc: 0.5129 - val_bag_output_acc: 0.6106 - val_footwear_output_acc: 0.5511 - val_pose_output_acc: 0.6796 - val_emotion_output_acc: 0.6349
# Epoch 5/50
# 360/360 [==============================] - 92s 254ms/step - loss: 7.5852 - gender_output_loss: 0.0196 - image_quality_output_loss: 0.0309 - age_output_loss: 0.0279 - weight_output_loss: 0.0243 - bag_output_loss: 0.0275 - footwear_output_loss: 0.0251 - pose_output_loss: 0.0185 - emotion_output_loss: 0.0139 - gender_output_acc: 0.9944 - image_quality_output_acc: 0.9899 - age_output_acc: 0.9923 - weight_output_acc: 0.9925 - bag_output_acc: 0.9912 - footwear_output_acc: 0.9923 - pose_output_acc: 0.9942 - emotion_output_acc: 0.9964 - val_loss: 26.3120 - val_gender_output_loss: 1.4022 - val_image_quality_output_loss: 2.8301 - val_age_output_loss: 3.7588 - val_weight_output_loss: 3.2927 - val_bag_output_loss: 2.1962 - val_footwear_output_loss: 2.0921 - val_pose_output_loss: 1.2238 - val_emotion_output_loss: 2.3517 - val_gender_output_acc: 0.6806 - val_image_quality_output_acc: 0.4311 - val_age_output_acc: 0.3735 - val_weight_output_acc: 0.3919 - val_bag_output_acc: 0.5734 - val_footwear_output_acc: 0.5635 - val_pose_output_acc: 0.7222 - val_emotion_output_acc: 0.6815
# Epoch 6/50
# 360/360 [==============================] - 95s 265ms/step - loss: 7.2178 - gender_output_loss: 0.0247 - image_quality_output_loss: 0.0420 - age_output_loss: 0.0421 - weight_output_loss: 0.0373 - bag_output_loss: 0.0360 - footwear_output_loss: 0.0321 - pose_output_loss: 0.0270 - emotion_output_loss: 0.0234 - gender_output_acc: 0.9923 - image_quality_output_acc: 0.9855 - age_output_acc: 0.9865 - weight_output_acc: 0.9867 - bag_output_acc: 0.9872 - footwear_output_acc: 0.9897 - pose_output_acc: 0.9918 - emotion_output_acc: 0.9929 - val_loss: 27.8224 - val_gender_output_loss: 0.8548 - val_image_quality_output_loss: 2.3031 - val_age_output_loss: 4.7536 - val_weight_output_loss: 3.1046 - val_bag_output_loss: 1.8831 - val_footwear_output_loss: 4.7115 - val_pose_output_loss: 1.3569 - val_emotion_output_loss: 2.0962 - val_gender_output_acc: 0.7406 - val_image_quality_output_acc: 0.5317 - val_age_output_acc: 0.3899 - val_weight_output_acc: 0.6275 - val_bag_output_acc: 0.5769 - val_footwear_output_acc: 0.4747 - val_pose_output_acc: 0.6657 - val_emotion_output_acc: 0.6205
# Epoch 7/50
# 360/360 [==============================] - 96s 266ms/step - loss: 6.9831 - gender_output_loss: 0.0309 - image_quality_output_loss: 0.0675 - age_output_loss: 0.0751 - weight_output_loss: 0.0534 - bag_output_loss: 0.0542 - footwear_output_loss: 0.0425 - pose_output_loss: 0.0318 - emotion_output_loss: 0.0438 - gender_output_acc: 0.9884 - image_quality_output_acc: 0.9771 - age_output_acc: 0.9745 - weight_output_acc: 0.9816 - bag_output_acc: 0.9794 - footwear_output_acc: 0.9853 - pose_output_acc: 0.9891 - emotion_output_acc: 0.9856 - val_loss: 28.8153 - val_gender_output_loss: 1.1293 - val_image_quality_output_loss: 2.3156 - val_age_output_loss: 6.7015 - val_weight_output_loss: 2.5993 - val_bag_output_loss: 3.0949 - val_footwear_output_loss: 1.9984 - val_pose_output_loss: 1.5537 - val_emotion_output_loss: 2.9895 - val_gender_output_acc: 0.7287 - val_image_quality_output_acc: 0.5382 - val_age_output_acc: 0.2108 - val_weight_output_acc: 0.3953 - val_bag_output_acc: 0.3730 - val_footwear_output_acc: 0.5308 - val_pose_output_acc: 0.7083 - val_emotion_output_acc: 0.7034
# Epoch 8/50
# 360/360 [==============================] - 95s 265ms/step - loss: 6.8854 - gender_output_loss: 0.0444 - image_quality_output_loss: 0.0787 - age_output_loss: 0.1073 - weight_output_loss: 0.0808 - bag_output_loss: 0.0812 - footwear_output_loss: 0.0753 - pose_output_loss: 0.0566 - emotion_output_loss: 0.0627 - gender_output_acc: 0.9857 - image_quality_output_acc: 0.9706 - age_output_acc: 0.9618 - weight_output_acc: 0.9727 - bag_output_acc: 0.9715 - footwear_output_acc: 0.9734 - pose_output_acc: 0.9800 - emotion_output_acc: 0.9772 - val_loss: 23.4392 - val_gender_output_loss: 0.9142 - val_image_quality_output_loss: 2.2162 - val_age_output_loss: 2.9584 - val_weight_output_loss: 2.5319 - val_bag_output_loss: 2.0771 - val_footwear_output_loss: 2.6320 - val_pose_output_loss: 1.1023 - val_emotion_output_loss: 2.8149 - val_gender_output_acc: 0.7321 - val_image_quality_output_acc: 0.4221 - val_age_output_acc: 0.3180 - val_weight_output_acc: 0.3681 - val_bag_output_acc: 0.5556 - val_footwear_output_acc: 0.5417 - val_pose_output_acc: 0.7083 - val_emotion_output_acc: 0.7024
# Epoch 9/50
# 360/360 [==============================] - 95s 264ms/step - loss: 6.8931 - gender_output_loss: 0.0616 - image_quality_output_loss: 0.1088 - age_output_loss: 0.1426 - weight_output_loss: 0.1108 - bag_output_loss: 0.1006 - footwear_output_loss: 0.1105 - pose_output_loss: 0.0674 - emotion_output_loss: 0.0925 - gender_output_acc: 0.9761 - image_quality_output_acc: 0.9591 - age_output_acc: 0.9507 - weight_output_acc: 0.9588 - bag_output_acc: 0.9625 - footwear_output_acc: 0.9577 - pose_output_acc: 0.9750 - emotion_output_acc: 0.9668 - val_loss: 27.3046 - val_gender_output_loss: 1.8877 - val_image_quality_output_loss: 2.2449 - val_age_output_loss: 4.3267 - val_weight_output_loss: 3.0660 - val_bag_output_loss: 2.2548 - val_footwear_output_loss: 2.4395 - val_pose_output_loss: 1.5090 - val_emotion_output_loss: 3.5494 - val_gender_output_acc: 0.6434 - val_image_quality_output_acc: 0.4444 - val_age_output_acc: 0.3542 - val_weight_output_acc: 0.4514 - val_bag_output_acc: 0.5853 - val_footwear_output_acc: 0.4782 - val_pose_output_acc: 0.7148 - val_emotion_output_acc: 0.2902
# Epoch 10/50
# 360/360 [==============================] - 93s 259ms/step - loss: 6.7400 - gender_output_loss: 0.0562 - image_quality_output_loss: 0.1063 - age_output_loss: 0.1492 - weight_output_loss: 0.1100 - bag_output_loss: 0.1028 - footwear_output_loss: 0.1037 - pose_output_loss: 0.0748 - emotion_output_loss: 0.1053 - gender_output_acc: 0.9791 - image_quality_output_acc: 0.9600 - age_output_acc: 0.9464 - weight_output_acc: 0.9606 - bag_output_acc: 0.9637 - footwear_output_acc: 0.9643 - pose_output_acc: 0.9748 - emotion_output_acc: 0.9628 - val_loss: 21.7912 - val_gender_output_loss: 1.3803 - val_image_quality_output_loss: 1.8968 - val_age_output_loss: 3.5607 - val_weight_output_loss: 1.9139 - val_bag_output_loss: 1.6505 - val_footwear_output_loss: 2.1084 - val_pose_output_loss: 1.5895 - val_emotion_output_loss: 1.8343 - val_gender_output_acc: 0.6855 - val_image_quality_output_acc: 0.5025 - val_age_output_acc: 0.2867 - val_weight_output_acc: 0.5045 - val_bag_output_acc: 0.5585 - val_footwear_output_acc: 0.5526 - val_pose_output_acc: 0.5828 - val_emotion_output_acc: 0.6543
# Epoch 10/50
# Epoch 11/50
# 360/360 [==============================] - 88s 245ms/step - loss: 6.5204 - gender_output_loss: 0.0619 - image_quality_output_loss: 0.1041 - age_output_loss: 0.1449 - weight_output_loss: 0.0937 - bag_output_loss: 0.0947 - footwear_output_loss: 0.1074 - pose_output_loss: 0.0636 - emotion_output_loss: 0.0924 - gender_output_acc: 0.9764 - image_quality_output_acc: 0.9628 - age_output_acc: 0.9504 - weight_output_acc: 0.9652 - bag_output_acc: 0.9665 - footwear_output_acc: 0.9603 - pose_output_acc: 0.9768 - emotion_output_acc: 0.9688 - val_loss: 24.0901 - val_gender_output_loss: 1.2758 - val_image_quality_output_loss: 2.2984 - val_age_output_loss: 3.6298 - val_weight_output_loss: 4.3832 - val_bag_output_loss: 1.7390 - val_footwear_output_loss: 1.8391 - val_pose_output_loss: 1.1440 - val_emotion_output_loss: 2.1008 - val_gender_output_acc: 0.6806 - val_image_quality_output_acc: 0.4320 - val_age_output_acc: 0.3388 - val_weight_output_acc: 0.2862 - val_bag_output_acc: 0.5342 - val_footwear_output_acc: 0.5565 - val_pose_output_acc: 0.6840 - val_emotion_output_acc: 0.5407
# Epoch 12/50
# 360/360 [==============================] - 94s 261ms/step - loss: 6.3102 - gender_output_loss: 0.0563 - image_quality_output_loss: 0.1081 - age_output_loss: 0.1242 - weight_output_loss: 0.0866 - bag_output_loss: 0.0999 - footwear_output_loss: 0.0945 - pose_output_loss: 0.0635 - emotion_output_loss: 0.0954 - gender_output_acc: 0.9787 - image_quality_output_acc: 0.9619 - age_output_acc: 0.9542 - weight_output_acc: 0.9689 - bag_output_acc: 0.9648 - footwear_output_acc: 0.9659 - pose_output_acc: 0.9775 - emotion_output_acc: 0.9649 - val_loss: 31.1018 - val_gender_output_loss: 1.0449 - val_image_quality_output_loss: 3.0122 - val_age_output_loss: 5.8476 - val_weight_output_loss: 4.0278 - val_bag_output_loss: 3.9654 - val_footwear_output_loss: 3.2570 - val_pose_output_loss: 1.5016 - val_emotion_output_loss: 2.9370 - val_gender_output_acc: 0.7316 - val_image_quality_output_acc: 0.4182 - val_age_output_acc: 0.2679 - val_weight_output_acc: 0.6349 - val_bag_output_acc: 0.2664 - val_footwear_output_acc: 0.5392 - val_pose_output_acc: 0.6954 - val_emotion_output_acc: 0.5888
# Epoch 13/50
# 360/360 [==============================] - 93s 259ms/step - loss: 6.0869 - gender_output_loss: 0.0498 - image_quality_output_loss: 0.0971 - age_output_loss: 0.1222 - weight_output_loss: 0.0938 - bag_output_loss: 0.0915 - footwear_output_loss: 0.0883 - pose_output_loss: 0.0572 - emotion_output_loss: 0.0733 - gender_output_acc: 0.9812 - image_quality_output_acc: 0.9660 - age_output_acc: 0.9563 - weight_output_acc: 0.9662 - bag_output_acc: 0.9662 - footwear_output_acc: 0.9680 - pose_output_acc: 0.9809 - emotion_output_acc: 0.9738 - val_loss: 29.4910 - val_gender_output_loss: 1.4755 - val_image_quality_output_loss: 2.8043 - val_age_output_loss: 3.3893 - val_weight_output_loss: 3.1415 - val_bag_output_loss: 1.8542 - val_footwear_output_loss: 6.8194 - val_pose_output_loss: 1.5905 - val_emotion_output_loss: 3.0798 - val_gender_output_acc: 0.6825 - val_image_quality_output_acc: 0.5575 - val_age_output_acc: 0.3611 - val_weight_output_acc: 0.4325 - val_bag_output_acc: 0.5079 - val_footwear_output_acc: 0.2490 - val_pose_output_acc: 0.7108 - val_emotion_output_acc: 0.6959
# Epoch 14/50
# 360/360 [==============================] - 93s 259ms/step - loss: 5.9733 - gender_output_loss: 0.0544 - image_quality_output_loss: 0.1153 - age_output_loss: 0.1385 - weight_output_loss: 0.0928 - bag_output_loss: 0.0913 - footwear_output_loss: 0.0879 - pose_output_loss: 0.0585 - emotion_output_loss: 0.0807 - gender_output_acc: 0.9804 - image_quality_output_acc: 0.9566 - age_output_acc: 0.9504 - weight_output_acc: 0.9682 - bag_output_acc: 0.9680 - footwear_output_acc: 0.9668 - pose_output_acc: 0.9799 - emotion_output_acc: 0.9734 - val_loss: 23.9097 - val_gender_output_loss: 1.0024 - val_image_quality_output_loss: 2.4150 - val_age_output_loss: 3.0253 - val_weight_output_loss: 2.3083 - val_bag_output_loss: 3.5060 - val_footwear_output_loss: 2.0238 - val_pose_output_loss: 1.4281 - val_emotion_output_loss: 3.0099 - val_gender_output_acc: 0.7247 - val_image_quality_output_acc: 0.4578 - val_age_output_acc: 0.3393 - val_weight_output_acc: 0.4777 - val_bag_output_acc: 0.4588 - val_footwear_output_acc: 0.5129 - val_pose_output_acc: 0.7153 - val_emotion_output_acc: 0.7078
# Epoch 15/50
# 360/360 [==============================] - 92s 257ms/step - loss: 5.8931 - gender_output_loss: 0.0540 - image_quality_output_loss: 0.1105 - age_output_loss: 0.1467 - weight_output_loss: 0.1065 - bag_output_loss: 0.1050 - footwear_output_loss: 0.0939 - pose_output_loss: 0.0709 - emotion_output_loss: 0.0862 - gender_output_acc: 0.9813 - image_quality_output_acc: 0.9592 - age_output_acc: 0.9504 - weight_output_acc: 0.9625 - bag_output_acc: 0.9621 - footwear_output_acc: 0.9648 - pose_output_acc: 0.9757 - emotion_output_acc: 0.9699 - val_loss: 31.3761 - val_gender_output_loss: 0.9395 - val_image_quality_output_loss: 3.5111 - val_age_output_loss: 5.4626 - val_weight_output_loss: 3.2815 - val_bag_output_loss: 7.2169 - val_footwear_output_loss: 2.0662 - val_pose_output_loss: 1.3664 - val_emotion_output_loss: 2.4615 - val_gender_output_acc: 0.7287 - val_image_quality_output_acc: 0.5685 - val_age_output_acc: 0.1885 - val_weight_output_acc: 0.3988 - val_bag_output_acc: 0.1235 - val_footwear_output_acc: 0.4866 - val_pose_output_acc: 0.6384 - val_emotion_output_acc: 0.6558
# Epoch 16/50
# 360/360 [==============================] - 93s 257ms/step - loss: 5.7340 - gender_output_loss: 0.0526 - image_quality_output_loss: 0.1161 - age_output_loss: 0.1313 - weight_output_loss: 0.0916 - bag_output_loss: 0.0907 - footwear_output_loss: 0.0965 - pose_output_loss: 0.0661 - emotion_output_loss: 0.0928 - gender_output_acc: 0.9806 - image_quality_output_acc: 0.9570 - age_output_acc: 0.9543 - weight_output_acc: 0.9655 - bag_output_acc: 0.9669 - footwear_output_acc: 0.9653 - pose_output_acc: 0.9777 - emotion_output_acc: 0.9667 - val_loss: 27.9920 - val_gender_output_loss: 1.9757 - val_image_quality_output_loss: 2.1500 - val_age_output_loss: 4.0193 - val_weight_output_loss: 4.2551 - val_bag_output_loss: 2.6215 - val_footwear_output_loss: 3.5559 - val_pose_output_loss: 1.4233 - val_emotion_output_loss: 3.0452 - val_gender_output_acc: 0.6513 - val_image_quality_output_acc: 0.4573 - val_age_output_acc: 0.3571 - val_weight_output_acc: 0.3284 - val_bag_output_acc: 0.3978 - val_footwear_output_acc: 0.4692 - val_pose_output_acc: 0.7068 - val_emotion_output_acc: 0.6875
# 360/360 [==============================] - 92s 257ms/step - loss: 5.8931 - gender_output_loss: 0.0540 - image_quality_output_loss: 0.1105 - age_output_loss: 0.1467 - weight_output_loss: 0.1065 - bag_output_loss: 0.1050 - footwear_output_loss: 0.0939 - pose_output_loss: 0.0709 - emotion_output_loss: 0.0862 - gender_output_acc: 0.9813 - image_quality_output_acc: 0.9592 - age_output_acc: 0.9504 - weight_output_acc: 0.9625 - bag_output_acc: 0.9621 - footwear_output_acc: 0.9648 - pose_output_acc: 0.9757 - emotion_output_acc: 0.9699 - val_loss: 31.3761 - val_gender_output_loss: 0.9395 - val_image_quality_output_loss: 3.5111 - val_age_output_loss: 5.4626 - val_weight_output_loss: 3.2815 - val_bag_output_loss: 7.2169 - val_footwear_output_loss: 2.0662 - val_pose_output_loss: 1.3664 - val_emotion_output_loss: 2.4615 - val_gender_output_acc: 0.7287 - val_image_quality_output_acc: 0.5685 - val_age_output_acc: 0.1885 - val_weight_output_acc: 0.3988 - val_bag_output_acc: 0.1235 - val_footwear_output_acc: 0.4866 - val_pose_output_acc: 0.6384 - val_emotion_output_acc: 0.6558
# Epoch 17/50
# 360/360 [==============================] - 94s 261ms/step - loss: 5.5583 - gender_output_loss: 0.0530 - image_quality_output_loss: 0.0914 - age_output_loss: 0.1345 - weight_output_loss: 0.0942 - bag_output_loss: 0.0813 - footwear_output_loss: 0.0905 - pose_output_loss: 0.0542 - emotion_output_loss: 0.0876 - gender_output_acc: 0.9809 - image_quality_output_acc: 0.9674 - age_output_acc: 0.9517 - weight_output_acc: 0.9674 - bag_output_acc: 0.9710 - footwear_output_acc: 0.9675 - pose_output_acc: 0.9817 - emotion_output_acc: 0.9690 - val_loss: 25.3199 - val_gender_output_loss: 1.0579 - val_image_quality_output_loss: 5.2935 - val_age_output_loss: 3.9711 - val_weight_output_loss: 2.1966 - val_bag_output_loss: 2.1957 - val_footwear_output_loss: 2.1358 - val_pose_output_loss: 1.3894 - val_emotion_output_loss: 2.2659 - val_gender_output_acc: 0.7381 - val_image_quality_output_acc: 0.2961 - val_age_output_acc: 0.2540 - val_weight_output_acc: 0.5258 - val_bag_output_acc: 0.5536 - val_footwear_output_acc: 0.4762 - val_pose_output_acc: 0.6731 - val_emotion_output_acc: 0.6438
# Epoch 18/50
# 360/360 [==============================] - 95s 265ms/step - loss: 5.4221 - gender_output_loss: 0.0531 - image_quality_output_loss: 0.1028 - age_output_loss: 0.1248 - weight_output_loss: 0.0899 - bag_output_loss: 0.0898 - footwear_output_loss: 0.0917 - pose_output_loss: 0.0575 - emotion_output_loss: 0.0698 - gender_output_acc: 0.9799 - image_quality_output_acc: 0.9630 - age_output_acc: 0.9566 - weight_output_acc: 0.9672 - bag_output_acc: 0.9661 - footwear_output_acc: 0.9671 - pose_output_acc: 0.9778 - emotion_output_acc: 0.9753 - val_loss: 30.0201 - val_gender_output_loss: 1.1981 - val_image_quality_output_loss: 3.4292 - val_age_output_loss: 5.0583 - val_weight_output_loss: 4.0510 - val_bag_output_loss: 2.7797 - val_footwear_output_loss: 2.4002 - val_pose_output_loss: 3.9883 - val_emotion_output_loss: 2.4122 - val_gender_output_acc: 0.7123 - val_image_quality_output_acc: 0.5595 - val_age_output_acc: 0.1806 - val_weight_output_acc: 0.3522 - val_bag_output_acc: 0.4792 - val_footwear_output_acc: 0.5739 - val_pose_output_acc: 0.4524 - val_emotion_output_acc: 0.5585
# Epoch 19/50
# 360/360 [==============================] - 95s 264ms/step - loss: 5.4263 - gender_output_loss: 0.0622 - image_quality_output_loss: 0.1038 - age_output_loss: 0.1534 - weight_output_loss: 0.1022 - bag_output_loss: 0.0923 - footwear_output_loss: 0.0915 - pose_output_loss: 0.0756 - emotion_output_loss: 0.0928 - gender_output_acc: 0.9773 - image_quality_output_acc: 0.9637 - age_output_acc: 0.9440 - weight_output_acc: 0.9623 - bag_output_acc: 0.9668 - footwear_output_acc: 0.9672 - pose_output_acc: 0.9727 - emotion_output_acc: 0.9693 - val_loss: 22.7827 - val_gender_output_loss: 1.0239 - val_image_quality_output_loss: 1.9536 - val_age_output_loss: 3.9212 - val_weight_output_loss: 2.0712 - val_bag_output_loss: 3.2902 - val_footwear_output_loss: 1.9510 - val_pose_output_loss: 1.2737 - val_emotion_output_loss: 2.6727 - val_gender_output_acc: 0.7093 - val_image_quality_output_acc: 0.4628 - val_age_output_acc: 0.3973 - val_weight_output_acc: 0.4653 - val_bag_output_acc: 0.3423 - val_footwear_output_acc: 0.4936 - val_pose_output_acc: 0.7123 - val_emotion_output_acc: 0.6910
#
# Epoch 20/50
# 360/360 [==============================] - 94s 262ms/step - loss: 5.3082 - gender_output_loss: 0.0564 - image_quality_output_loss: 0.1099 - age_output_loss: 0.1372 - weight_output_loss: 0.0962 - bag_output_loss: 0.0879 - footwear_output_loss: 0.0995 - pose_output_loss: 0.0677 - emotion_output_loss: 0.0828 - gender_output_acc: 0.9794 - image_quality_output_acc: 0.9591 - age_output_acc: 0.9502 - weight_output_acc: 0.9665 - bag_output_acc: 0.9667 - footwear_output_acc: 0.9630 - pose_output_acc: 0.9746 - emotion_output_acc: 0.9714 - val_loss: 23.6979 - val_gender_output_loss: 0.9511 - val_image_quality_output_loss: 3.0883 - val_age_output_loss: 4.1286 - val_weight_output_loss: 2.3891 - val_bag_output_loss: 1.7790 - val_footwear_output_loss: 2.0473 - val_pose_output_loss: 2.7911 - val_emotion_output_loss: 1.9893 - val_gender_output_acc: 0.7247 - val_image_quality_output_acc: 0.3661 - val_age_output_acc: 0.3373 - val_weight_output_acc: 0.3934 - val_bag_output_acc: 0.5223 - val_footwear_output_acc: 0.5164 - val_pose_output_acc: 0.4395 - val_emotion_output_acc: 0.5248
# Epoch 21/50
# 360/360 [==============================] - 95s 264ms/step - loss: 5.2615 - gender_output_loss: 0.0652 - image_quality_output_loss: 0.1043 - age_output_loss: 0.1415 - weight_output_loss: 0.1006 - bag_output_loss: 0.1084 - footwear_output_loss: 0.0909 - pose_output_loss: 0.0777 - emotion_output_loss: 0.0909 - gender_output_acc: 0.9743 - image_quality_output_acc: 0.9617 - age_output_acc: 0.9492 - weight_output_acc: 0.9633 - bag_output_acc: 0.9600 - footwear_output_acc: 0.9657 - pose_output_acc: 0.9732 - emotion_output_acc: 0.9661 - val_loss: 31.8072 - val_gender_output_loss: 1.4456 - val_image_quality_output_loss: 2.5318 - val_age_output_loss: 6.1097 - val_weight_output_loss: 3.1860 - val_bag_output_loss: 2.0651 - val_footwear_output_loss: 3.8393 - val_pose_output_loss: 1.7562 - val_emotion_output_loss: 6.4121 - val_gender_output_acc: 0.6905 - val_image_quality_output_acc: 0.4688 - val_age_output_acc: 0.3948 - val_weight_output_acc: 0.5818 - val_bag_output_acc: 0.5595 - val_footwear_output_acc: 0.5184 - val_pose_output_acc: 0.6562 - val_emotion_output_acc: 0.1101
# Epoch 22/50
# 360/360 [==============================] - 93s 257ms/step - loss: 5.1192 - gender_output_loss: 0.0500 - image_quality_output_loss: 0.0953 - age_output_loss: 0.1404 - weight_output_loss: 0.0913 - bag_output_loss: 0.0926 - footwear_output_loss: 0.0903 - pose_output_loss: 0.0618 - emotion_output_loss: 0.0891 - gender_output_acc: 0.9831 - image_quality_output_acc: 0.9640 - age_output_acc: 0.9503 - weight_output_acc: 0.9674 - bag_output_acc: 0.9651 - footwear_output_acc: 0.9683 - pose_output_acc: 0.9780 - emotion_output_acc: 0.9666 - val_loss: 36.1674 - val_gender_output_loss: 4.3072 - val_image_quality_output_loss: 4.2434 - val_age_output_loss: 4.7385 - val_weight_output_loss: 4.7660 - val_bag_output_loss: 2.4547 - val_footwear_output_loss: 2.6615 - val_pose_output_loss: 1.9974 - val_emotion_output_loss: 6.6239 - val_gender_output_acc: 0.5640 - val_image_quality_output_acc: 0.3274 - val_age_output_acc: 0.2912 - val_weight_output_acc: 0.2778 - val_bag_output_acc: 0.5804 - val_footwear_output_acc: 0.4727 - val_pose_output_acc: 0.6885 - val_emotion_output_acc: 0.1969
# Epoch 23/50
# Epoch 22/50
# 360/360 [==============================] - 94s 260ms/step - loss: 5.0351 - gender_output_loss: 0.0530 - image_quality_output_loss: 0.1132 - age_output_loss: 0.1306 - weight_output_loss: 0.0946 - bag_output_loss: 0.0831 - footwear_output_loss: 0.0886 - pose_output_loss: 0.0656 - emotion_output_loss: 0.0817 - gender_output_acc: 0.9805 - image_quality_output_acc: 0.9571 - age_output_acc: 0.9546 - weight_output_acc: 0.9643 - bag_output_acc: 0.9705 - footwear_output_acc: 0.9687 - pose_output_acc: 0.9770 - emotion_output_acc: 0.9722 - val_loss: 25.3028 - val_gender_output_loss: 2.0078 - val_image_quality_output_loss: 2.1412 - val_age_output_loss: 3.9572 - val_weight_output_loss: 2.5667 - val_bag_output_loss: 2.1279 - val_footwear_output_loss: 4.3404 - val_pose_output_loss: 1.4526 - val_emotion_output_loss: 2.4174 - val_gender_output_acc: 0.6250 - val_image_quality_output_acc: 0.5397 - val_age_output_acc: 0.2991 - val_weight_output_acc: 0.4449 - val_bag_output_acc: 0.4936 - val_footwear_output_acc: 0.3428 - val_pose_output_acc: 0.6582 - val_emotion_output_acc: 0.6101
# Epoch 24/50
# 360/360 [==============================] - 94s 262ms/step - loss: 4.9757 - gender_output_loss: 0.0610 - image_quality_output_loss: 0.1099 - age_output_loss: 0.1211 - weight_output_loss: 0.0929 - bag_output_loss: 0.0951 - footwear_output_loss: 0.1038 - pose_output_loss: 0.0644 - emotion_output_loss: 0.0819 - gender_output_acc: 0.9775 - image_quality_output_acc: 0.9596 - age_output_acc: 0.9563 - weight_output_acc: 0.9678 - bag_output_acc: 0.9643 - footwear_output_acc: 0.9624 - pose_output_acc: 0.9799 - emotion_output_acc: 0.9714 - val_loss: 27.0055 - val_gender_output_loss: 1.1471 - val_image_quality_output_loss: 3.2418 - val_age_output_loss: 4.4175 - val_weight_output_loss: 2.7253 - val_bag_output_loss: 1.9485 - val_footwear_output_loss: 4.6129 - val_pose_output_loss: 1.2383 - val_emotion_output_loss: 3.4496 - val_gender_output_acc: 0.7272 - val_image_quality_output_acc: 0.3988 - val_age_output_acc: 0.3214 - val_weight_output_acc: 0.4692 - val_bag_output_acc: 0.5794 - val_footwear_output_acc: 0.5015 - val_pose_output_acc: 0.6801 - val_emotion_output_acc: 0.4315
# Epoch 25/50
#
# 360/360 [==============================] - 96s 266ms/step - loss: 4.9072 - gender_output_loss: 0.0565 - image_quality_output_loss: 0.1027 - age_output_loss: 0.1235 - weight_output_loss: 0.1043 - bag_output_loss: 0.1038 - footwear_output_loss: 0.0879 - pose_output_loss: 0.0561 - emotion_output_loss: 0.0911 - gender_output_acc: 0.9777 - image_quality_output_acc: 0.9630 - age_output_acc: 0.9559 - weight_output_acc: 0.9622 - bag_output_acc: 0.9615 - footwear_output_acc: 0.9680 - pose_output_acc: 0.9802 - emotion_output_acc: 0.9665 - val_loss: 23.5116 - val_gender_output_loss: 1.0199 - val_image_quality_output_loss: 2.4381 - val_age_output_loss: 3.6986 - val_weight_output_loss: 2.7650 - val_bag_output_loss: 2.6651 - val_footwear_output_loss: 2.5759 - val_pose_output_loss: 1.6136 - val_emotion_output_loss: 2.5758 - val_gender_output_acc: 0.7202 - val_image_quality_output_acc: 0.4172 - val_age_output_acc: 0.3353 - val_weight_output_acc: 0.6141 - val_bag_output_acc: 0.4008 - val_footwear_output_acc: 0.5040 - val_pose_output_acc: 0.7009 - val_emotion_output_acc: 0.4142
# Epoch 26/50
# 360/360 [==============================] - 96s 266ms/step - loss: 4.8351 - gender_output_loss: 0.0491 - image_quality_output_loss: 0.1086 - age_output_loss: 0.1426 - weight_output_loss: 0.0908 - bag_output_loss: 0.0910 - footwear_output_loss: 0.0936 - pose_output_loss: 0.0656 - emotion_output_loss: 0.0756 - gender_output_acc: 0.9816 - image_quality_output_acc: 0.9587 - age_output_acc: 0.9491 - weight_output_acc: 0.9664 - bag_output_acc: 0.9690 - footwear_output_acc: 0.9655 - pose_output_acc: 0.9752 - emotion_output_acc: 0.9737 - val_loss: 31.1446 - val_gender_output_loss: 1.4886 - val_image_quality_output_loss: 2.3761 - val_age_output_loss: 4.3673 - val_weight_output_loss: 3.0575 - val_bag_output_loss: 3.2922 - val_footwear_output_loss: 6.9640 - val_pose_output_loss: 2.3081 - val_emotion_output_loss: 3.1937 - val_gender_output_acc: 0.7009 - val_image_quality_output_acc: 0.5203 - val_age_output_acc: 0.3438 - val_weight_output_acc: 0.5451 - val_bag_output_acc: 0.3676 - val_footwear_output_acc: 0.2470 - val_pose_output_acc: 0.6776 - val_emotion_output_acc: 0.7029
# Epoch 27/50
# 360/360 [==============================] - 97s 271ms/step - loss: 4.7460 - gender_output_loss: 0.0594 - image_quality_output_loss: 0.0972 - age_output_loss: 0.1366 - weight_output_loss: 0.0915 - bag_output_loss: 0.0843 - footwear_output_loss: 0.0830 - pose_output_loss: 0.0629 - emotion_output_loss: 0.0773 - gender_output_acc: 0.9780 - image_quality_output_acc: 0.9656 - age_output_acc: 0.9506 - weight_output_acc: 0.9668 - bag_output_acc: 0.9690 - footwear_output_acc: 0.9688 - pose_output_acc: 0.9773 - emotion_output_acc: 0.9747 - val_loss: 21.7908 - val_gender_output_loss: 1.6650 - val_image_quality_output_loss: 2.1170 - val_age_output_loss: 3.0812 - val_weight_output_loss: 3.2126 - val_bag_output_loss: 2.0158 - val_footwear_output_loss: 2.0754 - val_pose_output_loss: 1.3119 - val_emotion_output_loss: 2.2759 - val_gender_output_acc: 0.6696 - val_image_quality_output_acc: 0.5322 - val_age_output_acc: 0.3224 - val_weight_output_acc: 0.3175 - val_bag_output_acc: 0.5615 - val_footwear_output_acc: 0.4970 - val_pose_output_acc: 0.7103 - val_emotion_output_acc: 0.5947
# Epoch 28/50
# 360/360 [==============================] - 98s 272ms/step - loss: 4.7318 - gender_output_loss: 0.0536 - image_quality_output_loss: 0.1121 - age_output_loss: 0.1364 - weight_output_loss: 0.1009 - bag_output_loss: 0.0920 - footwear_output_loss: 0.0936 - pose_output_loss: 0.0674 - emotion_output_loss: 0.0732 - gender_output_acc: 0.9803 - image_quality_output_acc: 0.9605 - age_output_acc: 0.9523 - weight_output_acc: 0.9639 - bag_output_acc: 0.9676 - footwear_output_acc: 0.9666 - pose_output_acc: 0.9756 - emotion_output_acc: 0.9739 - val_loss: 19.9215 - val_gender_output_loss: 0.8865 - val_image_quality_output_loss: 2.7002 - val_age_output_loss: 3.1919 - val_weight_output_loss: 2.1407 - val_bag_output_loss: 2.0567 - val_footwear_output_loss: 1.7461 - val_pose_output_loss: 1.0926 - val_emotion_output_loss: 2.1280 - val_gender_output_acc: 0.7460 - val_image_quality_output_acc: 0.3765 - val_age_output_acc: 0.3631 - val_weight_output_acc: 0.4221 - val_bag_output_acc: 0.5496 - val_footwear_output_acc: 0.5556 - val_pose_output_acc: 0.6870 - val_emotion_output_acc: 0.6642
# Epoch 29/50
# 360/360 [==============================] - 98s 273ms/step - loss: 4.5958 - gender_output_loss: 0.0481 - image_quality_output_loss: 0.0942 - age_output_loss: 0.1250 - weight_output_loss: 0.0775 - bag_output_loss: 0.0790 - footwear_output_loss: 0.0834 - pose_output_loss: 0.0585 - emotion_output_loss: 0.0942 - gender_output_acc: 0.9826 - image_quality_output_acc: 0.9663 - age_output_acc: 0.9549 - weight_output_acc: 0.9725 - bag_output_acc: 0.9714 - footwear_output_acc: 0.9689 - pose_output_acc: 0.9792 - emotion_output_acc: 0.9665 - val_loss: 24.4475 - val_gender_output_loss: 1.4364 - val_image_quality_output_loss: 3.6792 - val_age_output_loss: 3.9624 - val_weight_output_loss: 3.6947 - val_bag_output_loss: 2.1397 - val_footwear_output_loss: 2.0762 - val_pose_output_loss: 1.1868 - val_emotion_output_loss: 2.3586 - val_gender_output_acc: 0.6830 - val_image_quality_output_acc: 0.5709 - val_age_output_acc: 0.3537 - val_weight_output_acc: 0.4742 - val_bag_output_acc: 0.4320 - val_footwear_output_acc: 0.5461 - val_pose_output_acc: 0.7098 - val_emotion_output_acc: 0.6503
# Epoch 30/50
# 360/360 [==============================] - 98s 271ms/step - loss: 4.5507 - gender_output_loss: 0.0562 - image_quality_output_loss: 0.0898 - age_output_loss: 0.1249 - weight_output_loss: 0.0919 - bag_output_loss: 0.0902 - footwear_output_loss: 0.0815 - pose_output_loss: 0.0615 - emotion_output_loss: 0.0784 - gender_output_acc: 0.9798 - image_quality_output_acc: 0.9671 - age_output_acc: 0.9588 - weight_output_acc: 0.9662 - bag_output_acc: 0.9692 - footwear_output_acc: 0.9713 - pose_output_acc: 0.9784 - emotion_output_acc: 0.9731 - val_loss: 26.6568 - val_gender_output_loss: 1.4962 - val_image_quality_output_loss: 2.2757 - val_age_output_loss: 5.1947 - val_weight_output_loss: 2.9763 - val_bag_output_loss: 2.4898 - val_footwear_output_loss: 3.7655 - val_pose_output_loss: 1.7680 - val_emotion_output_loss: 2.8330 - val_gender_output_acc: 0.6473 - val_image_quality_output_acc: 0.4836 - val_age_output_acc: 0.3934 - val_weight_output_acc: 0.5670 - val_bag_output_acc: 0.5744 - val_footwear_output_acc: 0.5942 - val_pose_output_acc: 0.5650 - val_emotion_output_acc: 0.6925
# Epoch 31/50
# 360/360 [==============================] - 98s 272ms/step - loss: 4.5399 - gender_output_loss: 0.0501 - image_quality_output_loss: 0.0939 - age_output_loss: 0.1248 - weight_output_loss: 0.0917 - bag_output_loss: 0.0976 - footwear_output_loss: 0.0849 - pose_output_loss: 0.0734 - emotion_output_loss: 0.0972 - gender_output_acc: 0.9817 - image_quality_output_acc: 0.9665 - age_output_acc: 0.9560 - weight_output_acc: 0.9697 - bag_output_acc: 0.9649 - footwear_output_acc: 0.9691 - pose_output_acc: 0.9737 - emotion_output_acc: 0.9666 - val_loss: 23.5944 - val_gender_output_loss: 0.9260 - val_image_quality_output_loss: 2.3553 - val_age_output_loss: 6.1017 - val_weight_output_loss: 2.7655 - val_bag_output_loss: 2.4654 - val_footwear_output_loss: 1.9819 - val_pose_output_loss: 1.1506 - val_emotion_output_loss: 2.0270 - val_gender_output_acc: 0.7426 - val_image_quality_output_acc: 0.4727 - val_age_output_acc: 0.1930 - val_weight_output_acc: 0.2991 - val_bag_output_acc: 0.4777 - val_footwear_output_acc: 0.5392 - val_pose_output_acc: 0.6791 - val_emotion_output_acc: 0.5784
# Epoch 32/50
# 360/360 [==============================] - 98s 273ms/step - loss: 4.4723 - gender_output_loss: 0.0542 - image_quality_output_loss: 0.1059 - age_output_loss: 0.1093 - weight_output_loss: 0.0897 - bag_output_loss: 0.0860 - footwear_output_loss: 0.0957 - pose_output_loss: 0.0626 - emotion_output_loss: 0.0771 - gender_output_acc: 0.9809 - image_quality_output_acc: 0.9629 - age_output_acc: 0.9618 - weight_output_acc: 0.9670 - bag_output_acc: 0.9690 - footwear_output_acc: 0.9663 - pose_output_acc: 0.9789 - emotion_output_acc: 0.9715 - val_loss: 30.0011 - val_gender_output_loss: 0.9458 - val_image_quality_output_loss: 2.5629 - val_age_output_loss: 6.6400 - val_weight_output_loss: 2.7294 - val_bag_output_loss: 4.0507 - val_footwear_output_loss: 2.4916 - val_pose_output_loss: 1.8090 - val_emotion_output_loss: 4.9955 - val_gender_output_acc: 0.7460 - val_image_quality_output_acc: 0.4246 - val_age_output_acc: 0.2609 - val_weight_output_acc: 0.4067 - val_bag_output_acc: 0.5739 - val_footwear_output_acc: 0.4767 - val_pose_output_acc: 0.5923 - val_emotion_output_acc: 0.2421
# Epoch 33/50
# 360/360 [==============================] - 98s 273ms/step - loss: 4.5037 - gender_output_loss: 0.0512 - image_quality_output_loss: 0.1053 - age_output_loss: 0.1457 - weight_output_loss: 0.1105 - bag_output_loss: 0.0973 - footwear_output_loss: 0.0901 - pose_output_loss: 0.0644 - emotion_output_loss: 0.0863 - gender_output_acc: 0.9818 - image_quality_output_acc: 0.9608 - age_output_acc: 0.9498 - weight_output_acc: 0.9603 - bag_output_acc: 0.9655 - footwear_output_acc: 0.9691 - pose_output_acc: 0.9766 - emotion_output_acc: 0.9698 - val_loss: 26.7090 - val_gender_output_loss: 1.7452 - val_image_quality_output_loss: 2.6541 - val_age_output_loss: 3.9066 - val_weight_output_loss: 2.9902 - val_bag_output_loss: 5.6398 - val_footwear_output_loss: 2.1038 - val_pose_output_loss: 1.4284 - val_emotion_output_loss: 2.4931 - val_gender_output_acc: 0.6310 - val_image_quality_output_acc: 0.4390 - val_age_output_acc: 0.3214 - val_weight_output_acc: 0.5759 - val_bag_output_acc: 0.3532 - val_footwear_output_acc: 0.5675 - val_pose_output_acc: 0.6731 - val_emotion_output_acc: 0.6682
# Epoch 34/50
# 360/360 [==============================] - 98s 272ms/step - loss: 4.4156 - gender_output_loss: 0.0588 - image_quality_output_loss: 0.0986 - age_output_loss: 0.1288 - weight_output_loss: 0.0959 - bag_output_loss: 0.0912 - footwear_output_loss: 0.0875 - pose_output_loss: 0.0637 - emotion_output_loss: 0.0764 - gender_output_acc: 0.9796 - image_quality_output_acc: 0.9640 - age_output_acc: 0.9562 - weight_output_acc: 0.9649 - bag_output_acc: 0.9655 - footwear_output_acc: 0.9701 - pose_output_acc: 0.9781 - emotion_output_acc: 0.9740 - val_loss: 36.0408 - val_gender_output_loss: 1.3980 - val_image_quality_output_loss: 2.7091 - val_age_output_loss: 4.1817 - val_weight_output_loss: 5.9548 - val_bag_output_loss: 2.7907 - val_footwear_output_loss: 2.3997 - val_pose_output_loss: 4.5830 - val_emotion_output_loss: 8.3195 - val_gender_output_acc: 0.6825 - val_image_quality_output_acc: 0.4593 - val_age_output_acc: 0.3586 - val_weight_output_acc: 0.2713 - val_bag_output_acc: 0.5208 - val_footwear_output_acc: 0.4737 - val_pose_output_acc: 0.3849 - val_emotion_output_acc: 0.1587
# Epoch 35/50
#  - 98s 273ms/step - loss: 4.5037 - gender_output_loss: 0.0512 - image_quality_output_loss: 0.1053 - age_output_loss: 0.1457 - weight_output_loss: 0.1105 - bag_output_loss: 0.0973 - footwear_output_loss: 0.0901 - pose_output_loss: 0.0644 - emotion_output_loss: 0.0863 - gender_output_acc: 0.9818 - image_quality_output_acc: 0.9608 - age_output_acc: 0.9498 - weight_output_acc: 0.9603 - bag_output_acc: 0.9655 - footwear_output_acc: 0.9691 - pose_output_acc: 0.9766 - emotion_output_acc: 0.9698 - val_loss: 26.7090 - val_gender_output_loss: 1.7452 - val_image_quality_output_loss: 2.6541 - val_age_output_loss: 3.9066 - val_weight_output_loss: 2.9902 - val_bag_output_loss: 5.6398 - val_footwear_output_loss: 2.1038 - val_pose_output_loss: 1.4284 - val_emotion_output_loss: 2.4931 - val_gender_output_acc: 0.6310 - val_image_quality_output_acc: 0.4390 - val_age_output_acc: 0.3214 - val_weight_output_acc: 0.5759 - val_bag_output_acc: 0.3532 - val_footwear_output_acc: 0.5675 - val_pose_output_acc: 0.6731 - val_emotion_output_acc: 0.6682
# 360/360 [==============================] - 99s 275ms/step - loss: 4.2970 - gender_output_loss: 0.0532 - image_quality_output_loss: 0.0967 - age_output_loss: 0.1125 - weight_output_loss: 0.0809 - bag_output_loss: 0.0729 - footwear_output_loss: 0.0804 - pose_output_loss: 0.0605 - emotion_output_loss: 0.0708 - gender_output_acc: 0.9789 - image_quality_output_acc: 0.9653 - age_output_acc: 0.9593 - weight_output_acc: 0.9721 - bag_output_acc: 0.9744 - footwear_output_acc: 0.9709 - pose_output_acc: 0.9788 - emotion_output_acc: 0.9741 - val_loss: 22.8044 - val_gender_output_loss: 1.0896 - val_image_quality_output_loss: 2.5934 - val_age_output_loss: 3.6126 - val_weight_output_loss: 3.9991 - val_bag_output_loss: 2.0252 - val_footwear_output_loss: 2.2526 - val_pose_output_loss: 1.3278 - val_emotion_output_loss: 2.2581 - val_gender_output_acc: 0.7178 - val_image_quality_output_acc: 0.3953 - val_age_output_acc: 0.3105 - val_weight_output_acc: 0.2917 - val_bag_output_acc: 0.5580 - val_footwear_output_acc: 0.5575 - val_pose_output_acc: 0.6334 - val_emotion_output_acc: 0.5838
# Epoch 36/50
# 360/360 [==============================] - 98s 272ms/step - loss: 4.2250 - gender_output_loss: 0.0497 - image_quality_output_loss: 0.0917 - age_output_loss: 0.1090 - weight_output_loss: 0.0752 - bag_output_loss: 0.0827 - footwear_output_loss: 0.0759 - pose_output_loss: 0.0505 - emotion_output_loss: 0.0784 - gender_output_acc: 0.9834 - image_quality_output_acc: 0.9660 - age_output_acc: 0.9613 - weight_output_acc: 0.9738 - bag_output_acc: 0.9701 - footwear_output_acc: 0.9721 - pose_output_acc: 0.9838 - emotion_output_acc: 0.9729 - val_loss: 23.6530 - val_gender_output_loss: 1.0100 - val_image_quality_output_loss: 2.2398 - val_age_output_loss: 4.5788 - val_weight_output_loss: 3.1967 - val_bag_output_loss: 2.2603 - val_footwear_output_loss: 3.0733 - val_pose_output_loss: 1.2996 - val_emotion_output_loss: 2.3994 - val_gender_output_acc: 0.7188 - val_image_quality_output_acc: 0.4836 - val_age_output_acc: 0.1954 - val_weight_output_acc: 0.6210 - val_bag_output_acc: 0.5268 - val_footwear_output_acc: 0.4196 - val_pose_output_acc: 0.7346 - val_emotion_output_acc: 0.6285
# Epoch 37/50
# 360/360 [==============================] - 99s 275ms/step - loss: 4.1980 - gender_output_loss: 0.0485 - image_quality_output_loss: 0.0923 - age_output_loss: 0.1363 - weight_output_loss: 0.0773 - bag_output_loss: 0.0668 - footwear_output_loss: 0.0794 - pose_output_loss: 0.0584 - emotion_output_loss: 0.0766 - gender_output_acc: 0.9823 - image_quality_output_acc: 0.9669 - age_output_acc: 0.9491 - weight_output_acc: 0.9734 - bag_output_acc: 0.9765 - footwear_output_acc: 0.9701 - pose_output_acc: 0.9793 - emotion_output_acc: 0.9728 - val_loss: 28.9182 - val_gender_output_loss: 2.0890 - val_image_quality_output_loss: 2.8508 - val_age_output_loss: 4.0389 - val_weight_output_loss: 6.9612 - val_bag_output_loss: 2.1581 - val_footwear_output_loss: 2.6174 - val_pose_output_loss: 1.4136 - val_emotion_output_loss: 3.2292 - val_gender_output_acc: 0.6369 - val_image_quality_output_acc: 0.5074 - val_age_output_acc: 0.3046 - val_weight_output_acc: 0.2475 - val_bag_output_acc: 0.5322 - val_footwear_output_acc: 0.4926 - val_pose_output_acc: 0.6577 - val_emotion_output_acc: 0.6771
# Epoch 38/50
# 360/360 [==============================] - 99s 276ms/step - loss: 4.2025 - gender_output_loss: 0.0495 - image_quality_output_loss: 0.0977 - age_output_loss: 0.1155 - weight_output_loss: 0.0920 - bag_output_loss: 0.0788 - footwear_output_loss: 0.0949 - pose_output_loss: 0.0542 - emotion_output_loss: 0.0794 - gender_output_acc: 0.9836 - image_quality_output_acc: 0.9629 - age_output_acc: 0.9595 - weight_output_acc: 0.9682 - bag_output_acc: 0.9705 - footwear_output_acc: 0.9662 - pose_output_acc: 0.9806 - emotion_output_acc: 0.9714 - val_loss: 32.0396 - val_gender_output_loss: 1.7865 - val_image_quality_output_loss: 7.5127 - val_age_output_loss: 4.8599 - val_weight_output_loss: 3.9893 - val_bag_output_loss: 2.7506 - val_footwear_output_loss: 2.8364 - val_pose_output_loss: 1.8139 - val_emotion_output_loss: 2.9592 - val_gender_output_acc: 0.6409 - val_image_quality_output_acc: 0.1935 - val_age_output_acc: 0.3819 - val_weight_output_acc: 0.6300 - val_bag_output_acc: 0.4137 - val_footwear_output_acc: 0.5615 - val_pose_output_acc: 0.6687 - val_emotion_output_acc: 0.4534
# Epoch 39/50
# Epoch 38/50
# 360/360 [==============================] - 100s 278ms/step - loss: 4.1664 - gender_output_loss: 0.0522 - image_quality_output_loss: 0.0901 - age_output_loss: 0.1296 - weight_output_loss: 0.0879 - bag_output_loss: 0.0877 - footwear_output_loss: 0.0772 - pose_output_loss: 0.0565 - emotion_output_loss: 0.0771 - gender_output_acc: 0.9814 - image_quality_output_acc: 0.9656 - age_output_acc: 0.9543 - weight_output_acc: 0.9681 - bag_output_acc: 0.9676 - footwear_output_acc: 0.9719 - pose_output_acc: 0.9806 - emotion_output_acc: 0.9733 - val_loss: 26.9959 - val_gender_output_loss: 1.0694 - val_image_quality_output_loss: 3.2343 - val_age_output_loss: 3.4835 - val_weight_output_loss: 2.6012 - val_bag_output_loss: 2.1375 - val_footwear_output_loss: 2.6883 - val_pose_output_loss: 1.3317 - val_emotion_output_loss: 6.9449 - val_gender_output_acc: 0.7113 - val_image_quality_output_acc: 0.5471 - val_age_output_acc: 0.3051 - val_weight_output_acc: 0.5580 - val_bag_output_acc: 0.5789 - val_footwear_output_acc: 0.5714 - val_pose_output_acc: 0.7019 - val_emotion_output_acc: 0.1250
# Epoch 40/50
# 360/360 [==============================] - 99s 276ms/step - loss: 4.2122 - gender_output_loss: 0.0579 - image_quality_output_loss: 0.0903 - age_output_loss: 0.1280 - weight_output_loss: 0.0957 - bag_output_loss: 0.0970 - footwear_output_loss: 0.1063 - pose_output_loss: 0.0694 - emotion_output_loss: 0.0785 - gender_output_acc: 0.9786 - image_quality_output_acc: 0.9660 - age_output_acc: 0.9551 - weight_output_acc: 0.9649 - bag_output_acc: 0.9616 - footwear_output_acc: 0.9606 - pose_output_acc: 0.9759 - emotion_output_acc: 0.9730 - val_loss: 33.4495 - val_gender_output_loss: 1.5713 - val_image_quality_output_loss: 2.6723 - val_age_output_loss: 7.1544 - val_weight_output_loss: 2.5422 - val_bag_output_loss: 2.8763 - val_footwear_output_loss: 2.6493 - val_pose_output_loss: 7.4508 - val_emotion_output_loss: 3.0349 - val_gender_output_acc: 0.6979 - val_image_quality_output_acc: 0.5030 - val_age_output_acc: 0.2267 - val_weight_output_acc: 0.4921 - val_bag_output_acc: 0.5699 - val_footwear_output_acc: 0.4916 - val_pose_output_acc: 0.2808 - val_emotion_output_acc: 0.6156
# Epoch 40/50Epoch 41/50
# 360/360 [==============================] - 99s 274ms/step - loss: 4.1550 - gender_output_loss: 0.0467 - image_quality_output_loss: 0.1071 - age_output_loss: 0.1193 - weight_output_loss: 0.0934 - bag_output_loss: 0.0842 - footwear_output_loss: 0.0858 - pose_output_loss: 0.0618 - emotion_output_loss: 0.0812 - gender_output_acc: 0.9836 - image_quality_output_acc: 0.9616 - age_output_acc: 0.9581 - weight_output_acc: 0.9664 - bag_output_acc: 0.9691 - footwear_output_acc: 0.9691 - pose_output_acc: 0.9780 - emotion_output_acc: 0.9692 - val_loss: 24.0548 - val_gender_output_loss: 1.3599 - val_image_quality_output_loss: 3.1085 - val_age_output_loss: 4.8620 - val_weight_output_loss: 2.3991 - val_bag_output_loss: 2.4501 - val_footwear_output_loss: 2.8052 - val_pose_output_loss: 1.2526 - val_emotion_output_loss: 2.3467 - val_gender_output_acc: 0.7029 - val_image_quality_output_acc: 0.5308 - val_age_output_acc: 0.2247 - val_weight_output_acc: 0.5342 - val_bag_output_acc: 0.5615 - val_footwear_output_acc: 0.5377 - val_pose_output_acc: 0.7192 - val_emotion_output_acc: 0.5794
# Epoch 41/50Epoch 42/50
# 360/360 [==============================] - 99s 275ms/step - loss: 4.1287 - gender_output_loss: 0.0559 - image_quality_output_loss: 0.0915 - age_output_loss: 0.1217 - weight_output_loss: 0.0905 - bag_output_loss: 0.0863 - footwear_output_loss: 0.0777 - pose_output_loss: 0.0614 - emotion_output_loss: 0.0919 - gender_output_acc: 0.9783 - image_quality_output_acc: 0.9664 - age_output_acc: 0.9574 - weight_output_acc: 0.9663 - bag_output_acc: 0.9681 - footwear_output_acc: 0.9734 - pose_output_acc: 0.9776 - emotion_output_acc: 0.9678 - val_loss: 26.3516 - val_gender_output_loss: 2.0991 - val_image_quality_output_loss: 2.6585 - val_age_output_loss: 3.8271 - val_weight_output_loss: 3.5315 - val_bag_output_loss: 2.2154 - val_footwear_output_loss: 4.9266 - val_pose_output_loss: 1.2892 - val_emotion_output_loss: 2.3575 - val_gender_output_acc: 0.6612 - val_image_quality_output_acc: 0.4916 - val_age_output_acc: 0.2723 - val_weight_output_acc: 0.3433 - val_bag_output_acc: 0.5570 - val_footwear_output_acc: 0.3056 - val_pose_output_acc: 0.7168 - val_emotion_output_acc: 0.6359
# Epoch 43/50
# Epoch 42/50
# 360/360 [==============================] - 100s 278ms/step - loss: 3.9970 - gender_output_loss: 0.0455 - image_quality_output_loss: 0.0882 - age_output_loss: 0.1142 - weight_output_loss: 0.0798 - bag_output_loss: 0.0734 - footwear_output_loss: 0.0665 - pose_output_loss: 0.0538 - emotion_output_loss: 0.0651 - gender_output_acc: 0.9839 - image_quality_output_acc: 0.9681 - age_output_acc: 0.9597 - weight_output_acc: 0.9688 - bag_output_acc: 0.9731 - footwear_output_acc: 0.9746 - pose_output_acc: 0.9826 - emotion_output_acc: 0.9762 - val_loss: 26.4492 - val_gender_output_loss: 1.0713 - val_image_quality_output_loss: 2.4214 - val_age_output_loss: 6.3776 - val_weight_output_loss: 3.1244 - val_bag_output_loss: 2.7093 - val_footwear_output_loss: 2.3437 - val_pose_output_loss: 2.2489 - val_emotion_output_loss: 2.7530 - val_gender_output_acc: 0.7312 - val_image_quality_output_acc: 0.5079 - val_age_output_acc: 0.3998 - val_weight_output_acc: 0.5213 - val_bag_output_acc: 0.5977 - val_footwear_output_acc: 0.5332 - val_pose_output_acc: 0.5992 - val_emotion_output_acc: 0.5451
# Epoch 44/50
#
# 360/360 [==============================] - 101s 281ms/step - loss: 4.0631 - gender_output_loss: 0.0578 - image_quality_output_loss: 0.0960 - age_output_loss: 0.1194 - weight_output_loss: 0.0973 - bag_output_loss: 0.0789 - footwear_output_loss: 0.0895 - pose_output_loss: 0.0630 - emotion_output_loss: 0.0754 - gender_output_acc: 0.9780 - image_quality_output_acc: 0.9663 - age_output_acc: 0.9576 - weight_output_acc: 0.9651 - bag_output_acc: 0.9712 - footwear_output_acc: 0.9663 - pose_output_acc: 0.9774 - emotion_output_acc: 0.9717 - val_loss: 22.7579 - val_gender_output_loss: 1.0128 - val_image_quality_output_loss: 3.4677 - val_age_output_loss: 3.9863 - val_weight_output_loss: 2.3901 - val_bag_output_loss: 2.7979 - val_footwear_output_loss: 1.8436 - val_pose_output_loss: 1.3488 - val_emotion_output_loss: 2.5252 - val_gender_output_acc: 0.7455 - val_image_quality_output_acc: 0.3368 - val_age_output_acc: 0.3800 - val_weight_output_acc: 0.4742 - val_bag_output_acc: 0.5823 - val_footwear_output_acc: 0.5476 - val_pose_output_acc: 0.6429 - val_emotion_output_acc: 0.6205
# Epoch 45/50
# 360/360 [==============================] - 100s 278ms/step - loss: 3.9898 - gender_output_loss: 0.0482 - image_quality_output_loss: 0.0857 - age_output_loss: 0.1109 - weight_output_loss: 0.0877 - bag_output_loss: 0.0828 - footwear_output_loss: 0.0828 - pose_output_loss: 0.0569 - emotion_output_loss: 0.0730 - gender_output_acc: 0.9814 - image_quality_output_acc: 0.9687 - age_output_acc: 0.9609 - weight_output_acc: 0.9684 - bag_output_acc: 0.9698 - footwear_output_acc: 0.9691 - pose_output_acc: 0.9804 - emotion_output_acc: 0.9747 - val_loss: 26.6649 - val_gender_output_loss: 2.2793 - val_image_quality_output_loss: 3.5556 - val_age_output_loss: 3.9223 - val_weight_output_loss: 2.9252 - val_bag_output_loss: 2.1674 - val_footwear_output_loss: 2.9424 - val_pose_output_loss: 1.6123 - val_emotion_output_loss: 3.9019 - val_gender_output_acc: 0.6399 - val_image_quality_output_acc: 0.5446 - val_age_output_acc: 0.3180 - val_weight_output_acc: 0.5853 - val_bag_output_acc: 0.5818 - val_footwear_output_acc: 0.5923 - val_pose_output_acc: 0.6875 - val_emotion_output_acc: 0.3735
# Epoch 46/50
# 360/360 [==============================] - 99s 276ms/step - loss: 3.9923 - gender_output_loss: 0.0538 - image_quality_output_loss: 0.0918 - age_output_loss: 0.1202 - weight_output_loss: 0.0764 - bag_output_loss: 0.0776 - footwear_output_loss: 0.0909 - pose_output_loss: 0.0606 - emotion_output_loss: 0.0795 - gender_output_acc: 0.9802 - image_quality_output_acc: 0.9677 - age_output_acc: 0.9570 - weight_output_acc: 0.9727 - bag_output_acc: 0.9717 - footwear_output_acc: 0.9662 - pose_output_acc: 0.9782 - emotion_output_acc: 0.9719 - val_loss: 25.1124 - val_gender_output_loss: 1.1446 - val_image_quality_output_loss: 3.0156 - val_age_output_loss: 3.5542 - val_weight_output_loss: 4.0200 - val_bag_output_loss: 3.2877 - val_footwear_output_loss: 2.1611 - val_pose_output_loss: 2.0063 - val_emotion_output_loss: 2.5833 - val_gender_output_acc: 0.7168 - val_image_quality_output_acc: 0.5521 - val_age_output_acc: 0.3566 - val_weight_output_acc: 0.6295 - val_bag_output_acc: 0.4549 - val_footwear_output_acc: 0.5069 - val_pose_output_acc: 0.7034 - val_emotion_output_acc: 0.5675
# Epoch 47/50
# 360/360 [==============================] - 99s 275ms/step - loss: 3.9228 - gender_output_loss: 0.0439 - image_quality_output_loss: 0.0880 - age_output_loss: 0.1181 - weight_output_loss: 0.0871 - bag_output_loss: 0.0722 - footwear_output_loss: 0.0753 - pose_output_loss: 0.0548 - emotion_output_loss: 0.0722 - gender_output_acc: 0.9839 - image_quality_output_acc: 0.9681 - age_output_acc: 0.9577 - weight_output_acc: 0.9694 - bag_output_acc: 0.9742 - footwear_output_acc: 0.9735 - pose_output_acc: 0.9820 - emotion_output_acc: 0.9736 - val_loss: 24.9408 - val_gender_output_loss: 0.9966 - val_image_quality_output_loss: 2.4015 - val_age_output_loss: 4.3969 - val_weight_output_loss: 2.3706 - val_bag_output_loss: 2.2790 - val_footwear_output_loss: 3.1178 - val_pose_output_loss: 3.1186 - val_emotion_output_loss: 2.9517 - val_gender_output_acc: 0.7386 - val_image_quality_output_acc: 0.4826 - val_age_output_acc: 0.3165 - val_weight_output_acc: 0.4425 - val_bag_output_acc: 0.4970 - val_footwear_output_acc: 0.5119 - val_pose_output_acc: 0.4370 - val_emotion_output_acc: 0.3472
# Epoch 48/50
# 360/360 [==============================] - 100s 278ms/step - loss: 3.8818 - gender_output_loss: 0.0532 - image_quality_output_loss: 0.0858 - age_output_loss: 0.1053 - weight_output_loss: 0.0739 - bag_output_loss: 0.0822 - footwear_output_loss: 0.0750 - pose_output_loss: 0.0568 - emotion_output_loss: 0.0656 - gender_output_acc: 0.9800 - image_quality_output_acc: 0.9674 - age_output_acc: 0.9617 - weight_output_acc: 0.9737 - bag_output_acc: 0.9702 - footwear_output_acc: 0.9735 - pose_output_acc: 0.9798 - emotion_output_acc: 0.9758 - val_loss: 27.1795 - val_gender_output_loss: 3.3696 - val_image_quality_output_loss: 3.3128 - val_age_output_loss: 4.8172 - val_weight_output_loss: 2.9344 - val_bag_output_loss: 2.0653 - val_footwear_output_loss: 3.1196 - val_pose_output_loss: 1.6563 - val_emotion_output_loss: 2.6269 - val_gender_output_acc: 0.5600 - val_image_quality_output_acc: 0.5689 - val_age_output_acc: 0.3948 - val_weight_output_acc: 0.5848 - val_bag_output_acc: 0.5680 - val_footwear_output_acc: 0.5407 - val_pose_output_acc: 0.7113 - val_emotion_output_acc: 0.5441
# Epoch 49/50
# 359/360 [============================>.] - ETA: 0s - loss: 3.8584 - gender_output_loss: 0.0418 - image_quality_output_loss: 0.0912 - age_output_loss: 0.1069 - weight_output_loss: 0.0775 - bag_output_loss: 0.0841 - footwear_output_loss: 0.0777 - pose_output_loss: 0.0578 - emotion_output_loss: 0.0672 - gender_output_acc: 0.9834 - image_quality_output_acc: 0.9662 - age_output_acc: 0.9635 - weight_output_acc: 0.9730 - bag_output_acc: 0.9696 - footwear_output_acc: 0.9730 - pose_output_acc: 0.9801 - emotion_output_acc: 0.9760Epoch 49/50
# 360/360 [==============================] - 100s 278ms/step - loss: 3.8596 - gender_output_loss: 0.0419 - image_quality_output_loss: 0.0910 - age_output_loss: 0.1080 - weight_output_loss: 0.0774 - bag_output_loss: 0.0841 - footwear_output_loss: 0.0776 - pose_output_loss: 0.0580 - emotion_output_loss: 0.0674 - gender_output_acc: 0.9833 - image_quality_output_acc: 0.9663 - age_output_acc: 0.9632 - weight_output_acc: 0.9731 - bag_output_acc: 0.9696 - footwear_output_acc: 0.9731 - pose_output_acc: 0.9799 - emotion_output_acc: 0.9759 - val_loss: 28.3801 - val_gender_output_loss: 0.9760 - val_image_quality_output_loss: 3.4936 - val_age_output_loss: 4.8133 - val_weight_output_loss: 3.8997 - val_bag_output_loss: 3.5170 - val_footwear_output_loss: 2.5633 - val_pose_output_loss: 1.8207 - val_emotion_output_loss: 4.0430 - val_gender_output_acc: 0.7351 - val_image_quality_output_acc: 0.4568 - val_age_output_acc: 0.4067 - val_weight_output_acc: 0.6270 - val_bag_output_acc: 0.3269 - val_footwear_output_acc: 0.4668 - val_pose_output_acc: 0.6989 - val_emotion_output_acc: 0.7168
# Epoch 50/50
# 360/360 [==============================] - 100s 279ms/step - loss: 3.8653 - gender_output_loss: 0.0397 - image_quality_output_loss: 0.0929 - age_output_loss: 0.1328 - weight_output_loss: 0.0742 - bag_output_loss: 0.0756 - footwear_output_loss: 0.0744 - pose_output_loss: 0.0594 - emotion_output_loss: 0.0788 - gender_output_acc: 0.9860 - image_quality_output_acc: 0.9653 - age_output_acc: 0.9521 - weight_output_acc: 0.9722 - bag_output_acc: 0.9719 - footwear_output_acc: 0.9740 - pose_output_acc: 0.9810 - emotion_output_acc: 0.9704 - val_loss: 25.9282 - val_gender_output_loss: 1.0262 - val_image_quality_output_loss: 2.1589 - val_age_output_loss: 3.1439 - val_weight_output_loss: 2.7720 - val_bag_output_loss: 1.9088 - val_footwear_output_loss: 2.0604 - val_pose_output_loss: 1.3585 - val_emotion_output_loss: 8.2584 - val_gender_output_acc: 0.7192 - val_image_quality_output_acc: 0.5342 - val_age_output_acc: 0.3378 - val_weight_output_acc: 0.4578 - val_bag_output_acc: 0.5461 - val_footwear_output_acc: 0.5590 - val_pose_output_acc: 0.7029 - val_emotion_output_acc: 0.0923

# %%
results = model2.evaluate(valid_gen)
print(dict(zip(model2.metrics_names,results)))
# Out:
# 63/63 [==============================] - 8s 121ms/step
# {'loss': 19.730398117549836, 'gender_output_loss': 0.29294300942666945, 'image_quality_output_loss': 0.47623238239496474, 'age_output_loss': 2.0786735424919733, 'weight_output_loss': 1.8288595037800925, 'bag_output_loss': 0.48266333294293234, 'footwear_output_loss': 0.6212138371571662, 'pose_output_loss': 0.21429175871705253, 'emotion_output_loss': 1.1704149056994726, 'gender_output_acc': 0.8908730158730159, 'image_quality_output_acc': 0.8665674603174603, 'age_output_acc': 0.6180555555555556, 'weight_output_acc': 0.7093253968253969, 'bag_output_acc': 0.8377976190476191, 'footwear_output_acc': 0.841765873015873, 'pose_output_acc': 0.9360119047619048, 'emotion_output_acc': 0.6567460317460317}

# %%
from keras.models import load_model

model2.load_weights('temp_curr_4.h5')
model2.compile(loss=losses,
              optimizer=SGD(lr=0.005, momentum = 0.009),loss_weights=lossWeights,
              metrics=['accuracy'])

results = model2.evaluate(valid_gen)
print(dict(zip(model2.metrics_names,results)))
# Out:
# 63/63 [==============================] - 8s 129ms/step
# {'loss': 3.1685615002162875, 'gender_output_loss': 0.025104161104421124, 'image_quality_output_loss': 0.027291489772150748, 'age_output_loss': 0.061538544645690495, 'weight_output_loss': 0.047837957563705645, 'bag_output_loss': 0.04387020724070247, 'footwear_output_loss': 0.033439659221570876, 'pose_output_loss': 0.02171594636110101, 'emotion_output_loss': 0.033711058326483155, 'gender_output_acc': 0.9945436507936508, 'image_quality_output_acc': 0.9935515873015873, 'age_output_acc': 0.9861111111111112, 'weight_output_acc': 0.9910714285714286, 'bag_output_acc': 0.9910714285714286, 'footwear_output_acc': 0.9920634920634921, 'pose_output_acc': 0.9935515873015873, 'emotion_output_acc': 0.9930555555555556}
